# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunaeee/upstage/blob/main/GPT_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydantic-settings
# !pip install pathlib
# !pip install rouge

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()

# %%
from pydantic_settings import BaseSettings
import pandas as pd
import openai
from openai import OpenAI
import json
from pathlib import Path
from rouge import Rouge

# %%
class Settings(BaseSettings):
    openai_api_key: str

    class Config:
        env_file = ".env"
        env_file_encoding = "utf-8"

settings = Settings()

# %%
# OpenAI API 키 설정
openai.api_key = settings.openai_api_key

# 데이터 로드
train_file = '/data/ephemeral/home/data/train.csv'
dev_file = '/data/ephemeral/home/data/dev.csv'
submission_file = '/data/ephemeral/home/data/sample_submission.csv'
test_file = '/data/ephemeral/home/data/test.csv'

train_df = pd.read_csv(train_file)
dev_df = pd.read_csv(dev_file)
submission_df = pd.read_csv(submission_file)
test_df = pd.read_csv(test_file)

# 'fname' 기준으로 'dialogue' 매핑
submission_df = submission_df.merge(test_df[['fname', 'dialogue']], on='fname', how='left')

# %%
submission_df = pd.read_csv(submission_file)
submission_df = submission_df.merge(test_df[['fname', 'dialogue']], on='fname', how='left')

# %%
def convert_to_chat_format(df, output_path):
    with open(output_path, 'w') as f:
        for _, row in df.iterrows():
            json.dump({
                "messages": [
                    {"role": "system", "content": "You summarize dialogues in a formal written style with a slight awkwardness, mimicking English-to-Korean translation, while capturing all key details."},
                    {"role": "user", "content": row['dialogue']},
                    {"role": "assistant", "content": row['summary']}
                ]
            }, f)
            f.write('\n')

# %%
convert_to_chat_format(train_df, '/data/ephemeral/home/data/train.jsonl')
convert_to_chat_format(dev_df, '/data/ephemeral/home/data/dev.jsonl')

# %%
client = OpenAI(
    api_key = settings.openai_api_key
)

train_data_file = client.files.create(
    file=Path("/data/ephemeral/home/data/train.jsonl"),
    purpose="fine-tune",
)
validation_data_file = client.files.create(
    file=Path("/data/ephemeral/home/data/dev.jsonl"),
    purpose="fine-tune",
)

print(f"File ID: {train_data_file.id}")
print(f"File ID: {validation_data_file.id}")
# Out:
# File ID: file-HQcAjWtiaygkk52hF2cyxn
# File ID: file-LV7wLFLMTowV8MVvLTncQj

# %%
def fine_tune(train_file_id, validation_file_id):
    try:
        # 파인 튜닝 작업을 생성하고 결과를 저장합니다.
        fine_tune_job = client.fine_tuning.jobs.create(
            model="gpt-3.5-turbo",
            training_file=train_file_id,
            validation_file = validation_file_id
        )

        # 생성된 파인 튜닝 작업의 ID를 사용하여 상태를 검색합니다.
        job_id = fine_tune_job.id  # 작업 ID를 얻습니다.
        print(f"Fine-tune job ID: {job_id}")  # 작업 ID를 출력합니다.

        # 작업 ID를 사용하여 파인 튜닝 작업의 상태를 검색합니다.
        job_status = client.fine_tuning.jobs.retrieve(job_id)
        print(job_status)  # 작업 상태를 출력합니다.

    except openai.APIConnectionError as e:
        print("The server could not be reached")
        print(e.__cause__)
    except openai.RateLimitError as e:
        print("A 429 status code was received; we should back off a bit.")
    except openai.APIStatusError as e:
        print("Another non-200-range status code was received")
        print(e.status_code)
        print(e.response)

# %%
fine_tune(train_data_file.id, validation_data_file.id)
# Out:
# Fine-tune job ID: ftjob-LFJKHw7jhAZsYIWs9sSnbJYZ
# FineTuningJob(id='ftjob-LFJKHw7jhAZsYIWs9sSnbJYZ', created_at=1732605145, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-U97IeTnyW6WqCetlCsDti76h', result_files=[], seed=761283474, status='validating_files', trained_tokens=None, training_file='file-YYoNTQNRv1DysSLa7cq9LL', validation_file='file-SfScyHqZ4dQWJsd5GE4vjC', estimated_finish=None, integrations=[], user_provided_suffix=None)

# %%
fine_tuned_model = client.fine_tuning.jobs.retrieve("ftjob-LFJKHw7jhAZsYIWs9sSnbJYZ").fine_tuned_model
print(f"Fine-tuned model ID: {fine_tuned_model}")
# Out:
# Fine-tuned model ID: ft:gpt-3.5-turbo-0125:personal::AXkfQa75

# %%
def summarize_with_gpt(dialogue, index=None):
    try:
        if index is not None:
            print(f"Processing index: {index}")
        response = openai.chat.completions.create(
            model= fine_tuned_model,
            messages=[
                {"role": "system", "content": (
                    "You are a summarization assistant specializing in generating Korean summaries that feel like machine-translated text from English. "
                    "The summaries should retain an unnatural, translated style. Avoid overly fluent Korean sentences, and include slightly awkward expressions typical of translations. "
                    "Make sure to include key details from the dialogue."
                    "Make sure the summary is concise and does not exceed 21 words. Retain only the most important details while keeping a translated, unnatural tone."
                    "\n\nImportant Guidelines:\n"
                    "- Retain details like actions, reasons, and emotions mentioned in the dialogue.\n"
                    "- Ensure the summary feels like it was directly translated from English to Korean without polishing.\n"
                    "- The summary length should be proportional to the dialogue content, avoiding overly short summaries."
                    "\n\nHere are some examples of the desired style:\n"
                    "\nExample 1:"
                    "\nDialogue:\n"
                    "#Person1#: 주문하시겠습니까?"
                    "#Person2#: 아직 결정하지 못했습니다. 조금 더 시간을 주실 수 있나요?"
                    "#Person1#: 네, 천천히 결정하셔도 됩니다."
                    "#Person2#: 먼저 음료를 가져다 주실 수 있나요? 맥주 두 병을 원합니다."
                    "#Person1#: 알겠습니다."
                    "#Person2#: 오늘의 특선 메뉴를 알려주실 수 있나요?"
                    "#Person1#: 오늘의 특선 메뉴는 스테이크입니다."
                    "#Person2#: 그럼 이 스테이크 디너를 주문하겠습니다."
                    "#Person1#: 스테이크와 함께 드실 것은 무엇인가요?"
                    "#Person2#: 완두콩과 당근입니다."
                    "#Person1#: 알겠습니다. 디저트로 무엇을 드시겠습니까?"
                    "#Person2#: 아이스크림 부탁드립니다."
                    "\nSummary:\n"
                    "#Person1#은 #Person2#의 주문을 받아 맥주 두 병, 스테이크 디너, 그리고 아이스크림을 준비합니다."
                    "\nExample 2:"
                    "\nDialogue:\n"
                    "#Person1#: 요즘 모든 사람들이 다이어트를 하는 것 같아요. 그걸 눈치채셨나요?"
                    "#Person2#: 모두가 그 얘기를 하는 것 같아요, 특히 여자들이요."
                    "#Person1#: 제 친구가 고구마 다이어트를 했어요. 아침에 고구마를 먹고, 점심에 고구마를 먹고, 저녁에 또 고구마를 먹었어요."
                    "#Person2#: 그건 건강에 안 좋아요. 그는 체중을 줄였나요?"
                    "#Person1#: 네. 하지만 그는 오래 가지 못했어요. 어느 날 그는 아파서 병원에 실려갔어요. 의사가 그를 일주일 동안 병원에 머물게 했어요."
                    "#Person2#: 그런 일이 있었다니 정말 안타깝네요. 체중을 줄이고 싶다면 너무 많이 먹지 않되, 모든 종류의 음식, 채소, 과일 등을 먹어야 한다고 생각해요. 그리고 운동도 더 많이 해야 해요."
                    "#Person1#: 저도 그렇게 생각해요."
                    "\nSummary:\n"
                    "#Person1#은 #Person2#에게 #Person1#의 친구가 다이어트를 하다가 아파진 경험을 이야기한다. #Person2#는 사람들이 체중을 줄이려면 균형 잡힌 식단을 섭취하고 운동을 더 많이 해야 한다고 생각한다."
                    "\nExample 3:\n"
                    "Dialogue:\n"
                    "#Person1#: 크레이그, 너는 어떤 일을 하고 있니?"
                    "#Person2#: 나는 아직 학생이야."
                    "#Person1#: 어느 학교에 다니니?"
                    "#Person2#: 보스턴 대학교."
                    "#Person1#: 좋은 학교네. 무슨 공부를 하니?"
                    "#Person2#: 나는 영어, 수학, 역사를 공부하고 있어. 전공은 영어야."
                    "#Person1#: 얼마나 오래 영어를 공부해 왔니?"
                    "#Person2#: 6년 이상이야."
                    "#Person1#: 오랜 시간이네."
                    "#Person2#: 그래, 나는 고등학교 때부터 영어를 배우기 시작했어."
                    "#Person1#: 어쩐지 영어를 그렇게 잘하더라니."
                    "#Person2#: 사실, 그렇게 좋지는 않아. 읽는 건 할 수 있지만 말하기는 잘 못해. 연습할 기회가 많지 않았거든."
                    "#Person1#: 알겠어. 다른 사람들과 대화하는 것이 매우 중요하니까."
                    "#Person2#: 그래, 하지만 아직 여기서 많은 친구들을 사귀지 못했어."
                    "#Person1#: 오늘 밤에 내 아파트에서 파티를 열 건데. 와봐."
                    "#Person2#: 초대해줘서 고마워. 기꺼이 참석하겠어."
                    "\nSummary:\n"
                    "크레이그는 수년간의 영어 학습 경험이 있지만, 연습의 부족으로 인해 영어를 잘 말하지 못한다. #Person1#은 오늘 밤 파티에 크레이그를 초대한다."
                    "\nExample 4:"
                    "\nDialogue:\n"
                    "#Person1#: 아직 학생이신가요?"
                    "#Person2#: 네, 그런데 저는 다음 달에 상해 금융 무역 학교를 졸업할 예정입니다."
                    "#Person1#: 정말로 훌륭한 캐셔가 될 수 있을 거라고 확신하나요?"
                    "#Person2#: 확신합니다. 제 전공은 통계학이고, 제가 수강한 모든 과목에서 우수한 성적을 받았습니다."
                    "#Person1#: 그건 이론적인 기초에 불과합니다. 혹시 전에 큰 금액의 현금을 다뤄본 경험이 있나요?"
                    "#Person2#: 네, 아버지가 사업을 하셔서 저는 매 휴가마다 재무 부서에서 일할 기회가 있었습니다."
                    "#Person1#: 좋습니다. 당신은 좋은 캐셔가 될 것 같습니다."
                    "#Person2#: 감사합니다."
                    "\nSummary:\n"
                    "#Person2#는 #Person1#에게 우수한 성적을 얻었으며 실무 경험도 쌓았다고 말합니다. #Person1#는 #Person2#가 성공적인 캐셔가 될 것이라고 생각합니다."
                    )},
                {"role": "user", "content": f"Here is a dialogue in Korean:\n\n{dialogue}\n\nPlease summarize it in a way that feels like a machine-translated summary from English."}
                ],
            max_tokens=180,
            temperature=0.5
        )
        summary = response.choices[0].message.content.strip()
        print(f"Summary for index {index}: {summary}")  # 요약 결과 출력
        return summary
    except Exception as e:
        print(f"Error during summarization: {e}")
        return ""
# Out:
#   Cell In[51], line 62
#     "#Person2#: 초대해줘서 고마워. 기꺼이 참석하겠어."\n
#                                        ^
# SyntaxError: unexpected character after line continuation character

# %%
def compute_metrics(predictions, references):
    rouge = Rouge()
    results = rouge.get_scores(predictions, references, avg=True)
    return {key: value["f"] for key, value in results.items()}


# 개발 데이터셋 평가
dev_df['predicted_summary'] = dev_df['dialogue'].apply(summarize_with_gpt)
metrics = compute_metrics(dev_df['predicted_summary'].tolist(), dev_df['summary'].tolist())
print("ROUGE Scores:", metrics)
# Out:
# Summary for index None: #Person1#은 #Person2#의 호흡이 힘들 때마다 가슴이 무겁게 느껴져서 #Person2#를 폐 전문의에게 보내 천식에 대한 검사를 받게 할 것이다.
# Summary for index None: #Person1#은 지미에게 운동을 제안하지만, 지미는 다리가 아파서 거절한다. #Person1#은 그들의 운동 스케줄을 바꾸고 싶어하며, 지미는 동의한다.
# Summary for index None: #Person1#은 더 이상 건강에 해로운 음식을 먹지 않기로 결정했고, #Person2#는 더 건강한 음식을 먹기 시작했다.
# Summary for index None: #Person1#은 UFO를 믿지 않지만 #Person2#는 UFO를 믿는다. #Person2#는 #Person1#에게 꿈에서 UFO를 본다고 말하고, UFO가 지구에 오지 않는다고 말한다.
# Summary for index None: #Person1#은 학교에 가지 않았지만, #Person2#는 영화 보러 갈 계획이다. #Person1#은 #Person2#에게 혼자 가라고 말하지만, #Person2#는 혼자 가고 싶지 않다.
# Summary for index None: #Person1#은 #Person2#에게 담배를 끊으라고 요청하지만, #Person2#는 끊는 것이 어렵다고 생각한다. #Person1#은 #Person2#를 설득하고, #Person2#는 끊기로 결정한다.
# Summary for index None: 셰리는 화이트 씨에게 나가기 전에 서명해야 할 것들을 요청하고, 화이트 씨는 그것들을 서명합니다.
# Summary for index None: #Person1#은 카렌에게 해변에서의 주말을 묻는다. 카렌은 해변을 따라 조깅하고 배구를 했지만 수영은 하지 않았다. #Person1#은 그것이 편안해 보인다.
# Summary for index None: #Person1#은 #Person2#에게 취미에 대해 묻는다. #Person2#는 야외에서 사진 찍는 것을 좋아한다.
# Summary for index None: #Person1#은 빌 게이츠의 집을 인터넷에서 본 적이 있고, #Person2#에게 그 집의 모습을 설명합니다. #Person1#은 오래된 집에서 살고 싶어하며, #Person2#는 #Person1#에게 오래된 집을 현대적인 방식으로 꾸미는 것이 좋을지 묻습니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#의 삶이 지쳤다고 말하고, #Person2#는 #Person1#이 맞을지도 모른다고 생각한다.
# Summary for index None: #Person1#은 광고가 너무 많다고 생각하고, 기업들이 광고에 돈을 쓰지 않아도 된다고 생각합니다. #Person2#는 광고가 도시를 살아있게 만든다고 생각하고, 광고의 어떤 형태는 짜증난다고 생각합니다.
# Summary for index None: #Person2#는 데이트에서 또 거절당했고, #Person1#에게 기술을 가르쳐 달라고 요청했다. #Person1#는 #Person2#에게 운동을 해보라고 제안했다. #Person2#는 더 강하고 건강한 몸을 가질 수 있을 것이라고 생각한다.
# Summary for index None: #Person1#은 여성들이 가장 뛰어난 스포츠와 가장 좋아하는 스포츠에 대해 #Person2#에게 묻습니다. #Person2#는 여성과 남성은 모든 면에서 다르기 때문에 비교할 수 없다고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 항상 따뜻한 도시, 항상 더운 도시, 비가 많이 오는 도시, 그리고 추운 도시에 대해 이야기합니다.
# Summary for index None: 조지 씨는 줄리아에게 그녀의 성과를 고려하여 월급을 인상하겠다고 말한다. 줄리아는 감사의 뜻을 표현하고 최선을 다하겠다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 그 자리를 얻지 못했다고 말한다. #Person2#는 실망한다. #Person1#은 #Person2#에게 계속 열심히 일하라고 조언한다.
# Summary for index None: 사라는 아빠가 짐을 싸는 것을 도와주려 했지만, 사라는 가볍게 여행하고 싶어서 거절했다.
# Summary for index None: #Person1#은 #Person2#의 가방을 보관해주기로 결정했습니다. #Person2#는 감사의 표시를 합니다.
# Summary for index None: 머피씨는 브래드에게 그의 작업이 정리가 되어 있지 않다고 말한다. 브래드는 다시 작업할 것이다.
# Summary for index None: #Person1#은 맥주를 마시면 노래를 더 잘 부를 수 있다고 말하고, #Person2#는 맥주를 충분히 마시면 외국어를 더 잘 할 수 있다고 말한다.
# Summary for index None: #Person1#은 치 양이 병원에서 지루함을 느끼지 않도록 도와주기 위해 치 양에게 잡지를 선물합니다.
# Summary for index None: 에이미는 아침 내내 기침을 하고 있고, #Person1#은 그녀가 현지 기후에 적응하지 못한 것 같다고 생각한다. #Person1#은 약을 가져다줄 것이다.
# Summary for index None: #Person1#은 #Person2#에게 스테이크, 베이크드 포테이토, 크림 양파 수프, 아이스티에 레몬을 주문하고, #Person2#는 디저트를 건너뛸 것입니다.
# Summary for index None: #Person1#은 연간 휴가를 기다리고 있지만 #Person2#는 12월까지 휴가를 가지 못한다.
# Summary for index None: #Person1#은 와인을 흘려 걸레를 요청했다. #Person2#는 종이 냅킨을 가져다 주었다.
# Summary for index None: #Person2#는 네트워크가 느려서 이메일로 설명서를 보내는 데 실패했다. #Person1#은 #Person2#에게 파일을 여러 부분으로 나누어 보내는 방법을 알려준다.
# Summary for index None: #Person1#은 빌에게 새로운 파일 캐비닛과 사무실에서 필요한 작은 물건들을 사러 같이 가자고 제안한다.
# Summary for index None: #Person2#는 #Person1#에게 건강식품에 대한 몇 가지 조언을 제공합니다. #Person1#는 놀라워하고 #Person2#에게 감사합니다.
# Summary for index None: #Person1#과 #Person2#는 결혼식을 보면서 행복해하고, #Person1#은 약혼식 준비를 시작했다.
# Summary for index None: #Person1#과 #Person2#는 역사 시험을 위해 벼락치기 공부를 하고 있습니다. 그들은 잠시 휴식을 취하고 싶어하며, #Person1#은 #Person2#에게 맥주를 가져다줍니다. #Person2#는 클래식 음악을 좋아하지만, #Person1#은 그것을 좋아하지 않습니다.
# Summary for index None: #Person1#은 유전 공학에 관한 책을 찾고 있지만 #Person2#은 모두 팔렸다고 말한다. #Person2#은 #Person1#에게 다음 주에 다시 오라고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 버스가 중국 국립 도서관으로 가는지 물어본다. #Person2#는 #Person1#에게 알려줄 것이다.
# Summary for index None: #Person1#은 브랜든 부인에게 직장을 잃었다고 말하고, 브랜든 부인은 그에게 기말고사 때문에 긴장하고 있다고 말한다.
# Summary for index None: 존 키트는 귀가 아파서 안더슨 박사를 만나고 싶어합니다. #Person1#은 그에게 내일 아침 열 시에 박사를 만날 수 있다고 말하고, 그의 병원 등록을 위해 여권을 가져오라고 조언합니다.
# Summary for index None: #Person1#은 #Person2#에게 등산을 제안하지만 #Person2#는 뱀을 무서워합니다. #Person1#은 #Person2#에게 걱정하지 말라고 말합니다.
# Summary for index None: 게리는 캐롤라인에게 청혼하고 싶어하지만, 앤은 두 번째 데이트를 먼저 신청하는 것이 좋다고 생각한다.
# Summary for index None: #Person2#는 더 많은 방이 필요하다. #Person1#은 침실 3개짜리 아파트를 추천한다.
# Summary for index None: 존이 이브에게 전화하여 비디오 레코더로 인해 손상된 테이프에 대한 보상을 요청합니다. 그녀는 존에게 법률 고문인 슈로더 부인을 연결해 줄 것입니다.
# Summary for index None: #Person1#은 #Person2#에게 레인보우 레스토랑까지 가는 방법을 물어봅니다.
# Summary for index None: #Person1#은 아담에게 학교를 구경시키고, #Person1#은 그 학교에 대해 부러워하며, 아담은 #Person1#이 그 학교에 입학할 수 있을 것이라고 믿는다.
# Summary for index None: #Person1#은 길을 잃었고, #Person2#에게 길을 물어본다. #Person2#는 #Person1#에게 중앙부서 매점과 국립 은행으로 가는 방법을 알려준다.
# Summary for index None: #Person1#은 #Person2#에게 한 여성이 돈을 요청했지만 나중에 거짓말을 했다고 말한다. #Person2#는 #Person1#이 여전히 순진하다고 생각한다.
# Summary for index None: #Person1#은 주방에서 사용할 수 있는 큰 프라이팬을 찾고 있습니다. #Person2#는 #Person1#에게 알루미늄 팬을 추천하고, #Person1#은 그것을 사기로 결정합니다.
# Summary for index None: 게리와 #Person2#는 서로 오해하고 영화를 놓쳤다. #Person2#는 영화를 보고 싶지 않아한다.
# Summary for index None: 다니엘은 매니저 직책에 지원하고 #Person2#에게 자신을 소개합니다. #Person2#는 다니엘에게 이번 주 안에 직무에 대해 알려줄 것이라고 말합니다.
# Summary for index None: #Person1#은 루시에게 러스티를 찾는 데 도움을 주고, 결국 러스티를 찾아내서 루시에게 큰 신세를 졌다.
# Summary for index None: #Person1#이 휴대폰을 샀지만 작동하지 않아서 패트릭에게 도움을 청하고, 그는 #Person1#에게 어떻게 켜는지 알려준다.
# Summary for index None: #Person2#는 #Person1#에게 캐나다 캘거리행 항공편의 3개 좌석을 예약하라고 요청한다. #Person1#은 #Person2#에게 다른 편을 제안한다. #Person2#는 그것을 수락한다.
# Summary for index None: 윈터스 선생님은 홍 씨에게 영어를 더 재미있게 배우는 방법을 제안한다. 그들은 이번 주에 특별한 프로젝트를 시작할 예정이다.
# Summary for index None: #Person1#은 톰에게 주말 계획을 묻고, 톰은 남부 록키 산맥으로 등산을 가려고 한다고 말한다. 그들은 같이 가기로 결정한다.
# Summary for index None: #Person1#은 게임을 더 재미있게 만들기 위해 스트립 트리비아를 제안하지만, #Person2#는 겁이 나서 거절한다.
# Summary for index None: #Person1#은 #Person2#에게 땅콩을 넣은 매콤한 치킨을 제공하고, 그것이 현지에서 유명한 요리 중 하나라고 말합니다. #Person2#는 맛있다고 생각합니다.
# Summary for index None: #Person2#의 배수구가 막혀서 #Person1#이 살펴보고 머리카락으로 막혀있음을 발견했습니다. #Person2#는 욕조를 사용할 때마다 청소해야 한다는 것을 배웠습니다.
# Summary for index None: #Person1#은 9월 중에 배송을 원하지만 #Person2#는 불가능하다고 하자 #Person1#은 #Person2#에게 협상하라고 요청한다. #Person2#는 9월 20일에 처리할 수 있다고 말한다.
# Summary for index None: 블랙 씨는 브라운 씨에게 아이들이 시끄럽다고 항의합니다. 브라운 씨는 블랙 씨에게 애들을 조용히 시키겠다고 약속합니다.
# Summary for index None: #Person1#과 #Person2#는 일부 부모들이 딸이 따라주지 않는다고 계속 잔소리하고 불평하는 것에 대해 이야기하고 있습니다.
# Summary for index None: #Person1#이 #Person2#에게 저녁 식사를 제공하고, #Person2#는 맛있었다고 말했습니다. #Person2#는 고기파이를 거절하고 아이스크림을 원했습니다.
# Summary for index None: #Person2#는 윈드서핑을 해보고 싶어하고 #Person1#에게 물어봤다. #Person1#는 그것이 어렵고 비싸다고 말했다. #Person2#는 생각해볼 것이다.
# Summary for index None: #Person1#은 벤이 풀장에서 떠다니고 있기 때문에 벤에게 대학원에 대해 생각해보라고 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 계모가 소년의 행복한 미소를 참을 수 없었고, 그녀가 살에 박힌 가시를 뽑기 위해 최선을 다했다고 말했다.
# Summary for index None: #Person1#과 #Person2#는 물 오염에 대해 이야기하고 있습니다. #Person2#는 #Person1#에게 물 오염의 두 가지 원인과 그것을 예방하는 방법에 대해 설명합니다.
# Summary for index None: #Person1#과 #Person2#는 버스에서 너무 일찍 내렸다. 그래서 그들은 걸어가거나 다음 버스를 기다려야 한다.
# Summary for index None: #Person1#은 #Person2#에게 초기 입금에 대해 이야기하고, #Person2#는 #Person1#에게 B형 계좌가 어떻게 다른지 물어봅니다.
# Summary for index None: #Person2#는 #Person1#에게 뉴욕행 101편 환승 항공편을 타기 위해 18번 탑승구로 가야 한다고 말하고, #Person1#이 서둘러야 한다고 경고한다.
# Summary for index None: #Person1#과 #Person2#는 그들의 바지가 널널하다는 것에 대해 이야기하고 있습니다. 그들은 나가기로 결정합니다.
# Summary for index None: #Person1#이 #Person2#에게 자리가 비어 있나 물어보고 같은 테이블에 앉아도 괜찮냐고 물어봅니다.
# Summary for index None: Monica는 다음 주말에 더블룸을 예약하려고 했고, #Person1#은 그녀를 도와주었다.
# Summary for index None: #Person1#은 5%의 할인을 제안하지만 #Person2#는 15%의 할인을 원합니다. #Person1#은 10%를 제안하고, #Person2#는 이에 동의합니다.
# Summary for index None: #Person2#는 아덴이 새로운 제품 시리즈에 대한 상표를 등록하고 싶어하지만 등록 과정에 대해 알지 못합니다. #Person1#는 #Person2#에게 상표의 유효 기간, 사용 우선 원칙, 등록 준비에 대해 알려줍니다.
# Summary for index None: #Person1#은 #Person2#의 MP3 플레이어가 멋지다고 생각하고, #Person2#는 #Person1#에게 온라인 쇼핑의 장점에 대해 이야기한다. #Person1#은 한번 해보고 싶어한다.
# Summary for index None: 왕 씨가 #Person1#을 공항까지 마중 와준다. #Person1#은 왕 씨의 나라와 환대에 감사하고, 왕 씨는 #Person1#이 거래를 성사시키는 데 최선을 다하겠다고 말한다.
# Summary for index None: #Person1#은 저축 계좌를 개설하고 싶어하고, #Person2#는 #Person1#에게 입출금 계좌와 정기 예금 계좌의 차이점을 설명합니다. #Person1#은 입출금 계좌를 개설하기로 결정합니다.
# Summary for index None: #Person1#과 #Person2#는 예상 밖의 서비스 정지를 줄이기 위해 운영 방식을 변경해야 한다고 논의하고 있습니다.
# Summary for index None: #Person1#은 #Person2#에게 잘못된 곳에 주차했다고 말하고, #Person2#는 차를 옮기기로 결정한다.
# Summary for index None: #Person1#과 #Person2#는 차량 사고를 당했습니다. #Person1#은 팔이 아파서 병원에 가야 하지만, #Person2#는 먼저 경찰에게 보고해야 한다고 생각합니다. #Person1#은 #Person2#를 비난하지만, #Person2#는 #Person1#이 경찰이 오면 그게 #Person1#의 잘못이 아니라는 것을 알게 될 것이라고 말합니다.
# Summary for index None: #Person1#은 #Person2#에게 도시에 개 공원을 건설하고 있다고 말한다. #Person2#는 사람들이 개 뒤를 청소할 수 있을지 의심한다.
# Summary for index None: 로라는 케빈에게 새로운 일자리를 찾고 있었지만 회사에서 승진을 제안받아 기뻐한다고 말한다. 케빈은 결혼을 하려고 하고, 로라는 그녀를 만나봐야 한다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 어제 어디에 있었냐고 물었고, #Person2#는 아파서 집에서 잠을 잤다고 대답했다. #Person2#는 약국에 가야 하기 때문에 지금 가려고 한다.
# Summary for index None: #Person1#은 톰에게 이번 주말에 해변에 가자고 제안하지만, 사라는 어머니가 아파서 집에 가야 한다. 그들은 해변에서 피크닉을 하기로 결정하고, 사라에게 전화를 걸어 같이 가자고 할 것이다.
# Summary for index None: #Person1#은 도둑질을 신고하고 #Person2#에게 그 사람의 왼쪽 신발이 훔쳐졌다고 말합니다. #Person2#는 '수염 단 여자'라고 불리는 사람이 그 신발을 훔쳤다고 생각하고, 그는 사실 매우 무해하다고 말합니다.
# Summary for index None: #Person1#은 짐이 #Person2#를 탓하는 것이 불공평하다고 생각한다. #Person2#는 #Person1#에게 보스가 그렇게 하는 이유를 알려준다.
# Summary for index None: #Person1#은 일자리를 찾고 싶어합니다. #Person2#는 #Person1#에게 여러 가지 파트타임 직업을 제안하고, #Person1#은 컴퓨터 센터에서 일하는 것을 신청하고 싶어합니다.
# Summary for index None: #Person1#은 #Person2#가 상사에게 무슨 말을 들었는지 물었다. #Person2#는 그것에 대해 불행해 보인다.
# Summary for index None: #Person1#은 #Person2#에게 대학 시절을 기억하며, 졸업식에 대한 기억을 공유한다. #Person2#는 졸업 후에 무엇을 할지 모르겠다. #Person1#은 #Person2#에게 결정을 내리고 불안감과 두려움에 지배되지 말라고 조언한다.
# Summary for index None: #Person1#은 제이든에게 200달러를 빌려달라고 부탁하지만, 제이든은 돈이 부족하다. 그들은 20달러를 빌리기로 결정하고, #Person1#은 제이든을 저녁 식사에 초대한다.
# Summary for index None: #Person1#은 #Person2#에게 자신의 생일을 알려주고, #Person2#는 #Person1#에게 생일 파티를 할 것인지 묻는다.
# Summary for index None: #Person1#과 #Person2#는 파티의 여자들에 대해 이야기하고 있다. #Person2#는 금발 여자를 좋아하지만 긴장해서 말을 잘못하고, #Person1#는 그에게 가서 얘기하라고 제안한다.
# Summary for index None: #Person1#이 메리에게 경매에서 무엇을 샀는지 물었고, 메리는 #Person1#을 싸움을 걸어서 화나게 했다.
# Summary for index None: 개이브는 어제 밤 잠을 잘 잤지만, 교통 체증에 걸릴 것을 걱정하고 있습니다. #Person2#는 그에게 깊게 숨을 쉬라고 조언하고, 이번 주말에 논문을 작성하는 것이 더 중요하다고 말합니다.
# Summary for index None: #Person1#은 선생님이 전체 반 앞에서 그녀를 비난한 것이 잘못이라고 생각하고, #Person2#는 그것이 맞다고 생각합니다.
# Summary for index None: #Person1#은 카렌에게 시어머니의 병원 방문에 대한 도움을 요청한다. #Person1#은 수지를 데리고 가고 싶지 않지만, 질이나 그녀의 엄마에게 부탁하기에는 좀 더 나이가 많은 사람이 필요하다. 카렌은 17살 소녀 사라를 추천하고, #Person1#은 그녀에게 연락할 것이다.
# Summary for index None: 사브리아는 자신의 여동생으로부터 2주 동안 연락이 없어 걱정하고 있다. 제이슨은 그녀를 위로하고, 만약 문제가 있다면 누군가가 그녀에게 전화를 했을 것이라고 말한다.
# Summary for index None: #Person1#은 감기약을 원하고, #Person2#는 #Person1#이 독감에 걸렸을 수도 있다고 생각한다. #Person1#은 도움을 받는다.
# Summary for index None: #Person1#은 약속이 있어서 친구를 만나야 합니다. #Person2#는 #Person1#을 태워줄 수 있습니다. #Person1#은 감사하게 생각합니다.
# Summary for index None: #Person2#는 #Person1#에게 여름 휴가 동안 인도를 여행했고, 현지 언어를 공부하지 않았기 때문에 한 번은 어색했다고 말했다. #Person2#는 빵집에서 빵을 달라고 하려다가 "돈이 필요해"라고 말해서 놀랐지만, 결국 그들은 친구가 되었다.
# Summary for index None: #Person2#는 매니저와의 인터뷰를 위해 수요일에 #Person1#을 만날 예정입니다.
# Summary for index None: #Person1#은 마라톤을 뛰고 싶어하며, #Person2#에게 달리기를 시작하는 방법을 묻는다. #Person2#는 #Person1#에게 천천히 시작하라고 조언하고, #Person1#은 밖에서 달리는 것을 시도해볼 것이다.
# Summary for index None: #Person1#은 논문을 위해 기독교 교회를 조사하고 있습니다. #Person2#는 #Person1#에게 교회의 목사와 만날 수 있도록 도와줄 것입니다.
# Summary for index None: #Person2#는 #Person1#에게 방의 규칙을 알려줍니다. #Person1#는 동의하고, #Person2#는 두 가지 더 말합니다. #Person1#는 그것들도 받아들입니다.
# Summary for index None: #Person1#은 #Person2#에게 주차를 위반했다고 말하고 티켓을 발급한다. #Person2#는 14일 이내에 법원에 항소할 수 있다.
# Summary for index None: #Person1#은 중국 드레스를 입어보고 싶어합니다. #Person2#는 #Person1#에게 다른 색상의 드레스를 제안합니다.
# Summary for index None: #Person1#은 노트북을 가지고 왔지만 방에서 인터넷을 사용할 수 없다. #Person2#는 #Person1#에게 웹 바를 이용하라고 제안한다.
# Summary for index None: #Person1#은 #Person2#의 도움으로 디지털 카메라를 구입했다.
# Summary for index None: #Person1#은 운이 좋아서 마지막 2인석을 얻었고, #Person2#와 함께 음식을 주문했습니다. #Person2#는 #Person1#이 함께 있어서 기뻐합니다.
# Summary for index None: #Person2#는 데이트 중 린다가 자신을 바람맞혔다. #Person1#은 #Person2#에게 다시 한 번 데이트를 신청하라고 조언한다.
# Summary for index None: #Person1#은 치킨이 이상하다고 느끼고, #Person2#는 그것을 치우고 다른 것을 주문하라고 제안한다. #Person1#은 스테이크를 주문한다.
# Summary for index None: #Person1#은 #Person2#에게 17번가에 새로 생긴 바에 가자고 제안하고, #Person2#는 데이트 상대를 데리고 가고 싶어한다. #Person1#은 9시에 넷이서 가기로 예약을 하고, #Person2#는 입장료와 복장 규정에 대해 묻는다.
# Summary for index None: #Person2#는 차를 렌트하고 싶어하고, #Person1#는 #Person2#에게 폭스바겐, 핀토, 플리머스, 닷선의 요금을 알려줍니다. #Person2#는 핀토를 렌트하고 싶어합니다.
# Summary for index None: #Person1#은 로마에 가면 로마인처럼 행동하라고 말하고, #Person2#는 로마인들이 다른 사람들이 하는 것처럼 행동한다고 생각한다.
# Summary for index None: 칠론은 제니가 힘들어 보여서 그녀에게 도움을 주려고 시도하지만, 제니는 시험에 대해 생각이 나지 않아서 학교를 그만두려고 생각하고 있다.
# Summary for index None: #Person1#은 세상이 나아지지 않았다고 생각하고, #Person2#는 세상이 나아졌다고 생각합니다. #Person1#은 #Person2#의 의견에 동의하지 않습니다.
# Summary for index None: #Person1#은 수강 신청을 잊어버려서 #Person2#에게 도움을 청한다. #Person2#는 #Person1#에게 학과 사무실에 가는 것보다 철학 수업을 위한 교수님에게 가는 것이 더 좋다고 말한다.
# Summary for index None: 메리는 #Person1#에게 어제 밤에 앤과 큰 싸움을 했다고 말하고, 그녀는 화가 나서 그녀의 남자친구와 함께 해변에 갔다. #Person1#은 그녀에게 화해하라고 조언한다.
# Summary for index None: #Person1#은 닐을 만나고 그의 교육과 가족에 대해 묻는다. 닐은 #Person1#에게 논문을 읽으러 가자고 제안하지만 #Person1#은 지도교수님을 만나야 한다.
# Summary for index None: #Person1#은 아내가 병원에 입원했기 때문에 휴가를 신청하려고 합니다. 수잔은 #Person1#에게 매니저가 회의 중이라고 말하고, 고객이 떠난 후에 휴가를 신청하라고 제안합니다.
# Summary for index None: #Person1#은 부엌에서 사용할 큰 팬을 찾고 있습니다. #Person2#는 #Person1#에게 여러 팬을 보여주고, #Person1#은 알루미늄 팬을 선택합니다. #Person1#은 팬에 맞는 뚜껑을 원하며, #Person2#는 그것이 팬에 딸려온다고 말합니다.
# Summary for index None: 모니카가 루시에게 회계사 자리에 대해 전화를 걸었다. 루시는 모니카에게 자리가 아직 남아있고, 영어가 필수적이라고 말했다. 모니카는 자신이 그 자리에 적합하다고 생각하고, 이번 주 안에 이력서를 보낼 것이다.
# Summary for index None: #Person2#는 남편이 심장마비를 앓고 있어서 911에 전화를 걸어 구급차를 요청했다. #Person1#는 구급차를 보내기로 결정했다.
# Summary for index None: #Person2#는 뉴욕행 기차를 예약하고 싶어합니다. #Person1#은 그에게 시간표를 보여주고, #Person2#는 오전 열시 삼십분 뉴욕행 기차를 예약합니다. #Person2#는 딱딱한 좌석을 선택합니다.
# Summary for index None: #Person1#과 #Person2#는 오바마가 새로운 대통령이라는 사실에 대해 행복해하고, 그에 대한 신뢰를 가지고 있습니다.
# Summary for index None: #Person1#은 실업급여 자격을 알고 싶어합니다. #Person2#는 #Person1#에게 자격, 직업, 금액을 결정하는 공식에 대해 설명합니다.
# Summary for index None: #Person1#은 오프라 윈프리에 대한 특집 기사를 #Person2#에게 읽어주고, 그 기사에서 오프라가 자선에 많은 돈을 기부하고 있다는 것을 알 수 있다. #Person2#는 그것이 칭찬할 만한 일이라고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 최종 결정을 전화로 알려줄 것이며, #Person2#는 다음 수요일까지 기다릴 것이다.
# Summary for index None: 데이비드 존슨은 치과에서 예약을 하고 싶어한다. #Person1#은 그를 위해 시간을 잡아준다.
# Summary for index None: #Person2#는 #Person1#에게 새 집에 대해 이야기합니다. 그는 집이 좋고 역사가 있지만 인테리어 비용이 많이 든다고 생각합니다. #Person2#는 집의 위치, 마당, 볕, 그리고 방의 수에 대해 #Person1#에게 설명합니다.
# Summary for index None: #Person1#은 하이난에 보낼 중요한 편지를 등기우편으로 보내고 싶어합니다. #Person2#는 편지가 무게 초과라고 말하고, #Person1#은 추가로 2위안을 내야 합니다.
# Summary for index None: #Person1#은 9월 배송을 요청하지만 #Person2#는 10월 중순이 더 빠르다고 말한다. #Person1#은 10월 이전 배송이 필요하다고 강조하고, #Person2#는 3분기가 꽉 차 있어서 불가능하다고 말한다. #Person1#은 #Person2#에게 생산자들을 설득해 달라고 요청한다.
# Summary for index None: #Person1#과 #Person2#는 집을 보고 있습니다. #Person2#는 #Person1#에게 집의 외관과 내부를 보여줍니다. #Person1#는 집이 아름답다고 생각하고, #Person2#는 #Person1#에게 몇 장의 사진을 찍어보라고 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 가장 좋아하는 음악 장르에 대해 묻습니다. #Person2#는 록과 R & B를 듣는 것을 즐기고, 그 이유는 그들이 사용하는 다양한 종류의 악기 때문입니다.
# Summary for index None: #Person2#의 금목걸이가 도난당했습니다. #Person1#은 #Person2#에게 몇 가지 질문을 하고, 하우스메이드를 보내서 찾아보겠다고 말합니다. #Person2#는 만족하지 않고 총괄 관리자를 만나고 싶어합니다.
# Summary for index None: #Person2#는 치통이 있어서 #Person1#에게 상담을 받았다. #Person1#은 #Person2#의 사랑니를 뽑아야 하며, 먼저 X-레이를 찍어야 한다.
# Summary for index None: #Person1#은 그린피스의 피터 윌슨을 인터뷰하고, 피터는 그린피스와 그곳에서의 그의 업무에 대해 이야기합니다. 피터는 그린피스의 행동 조직자로서 핵 반대 캠페인에 참여하고 있습니다. #Person1#은 피터에게 좋은 일을 계속하라고 격려합니다.
# Summary for index None: #Person1#은 어제 넘어져서 손이 아파서 #Person2#에게 상담을 요청했다. #Person2#는 #Person1#에게 쉬는 것을 제안했다.
# Summary for index None: #Person2#는 차를 빌리고 싶어합니다. #Person1#는 #Person2#에게 보험을 들고 소형 차를 빌리는 데 도움을 줍니다.
# Summary for index None: #Person1#은 마리아에게 영국 사람들에 대한 생각을 물어봤다. 마리아는 스페인 사람들이 함께 있을 때 재미있지만, 영국 사람들이 더 진지하다고 생각한다.
# Summary for index None: #Person2#는 #Person1#에게 전화를 걸어 #Person1#의 가족들이 어떻게 지내고 있는지 물어봅니다. #Person1#는 #Person2#에게 가족들이 모두 잘 지내고 있다고 말합니다.
# Summary for index None: #Person1#과 #Person2#는 번개에 대해 이야기하고 있습니다. #Person1#은 뇌우를 만나면 건물이나 닫힌 차를 찾을 것이고, #Person2#는 집에 있을 때도 뇌우가 칠 때는 목욕이나 샤워를 하지 않을 것입니다.
# Summary for index None: #Person2#는 #Person1#에게 공과대학에 입학하기 위해 지원하고, 추천서를 써달라고 요청한다. #Person1#는 기꺼이 도와줄 것이다.
# Summary for index None: #Person1#과 #Person2#는 비행기에서 서로 인사를 나누고, #Person1#은 LSE에서 국제 관계학 석사 학위를 받으러 가고, #Person2#는 미들섹스 대학교에서 비즈니스 공부를 하러 가고 싶어하지만, 부모님이 원하는 대로 가족 사업을 이어받게 될 것입니다.
# Summary for index None: #Person1#과 #Person2#는 비가 오고 은행이 문을 닫아 있을 것이라는 것에 대해 이야기하고 있습니다. #Person2#는 #Person1#에게 외투가 필요 없다고 말하지만, #Person1#는 영국에서는 그렇지 않을 수 있다고 생각합니다.
# Summary for index None: #Person1#은 #Person2#에게 내일 국립 갤러리에서 열리는 그리스와 로마 조각의 전시회에 가자고 제안한다. #Person2#는 고대 조각을 좋아하므로 동의한다.
# Summary for index None: #Person1#은 일찍 집에 가자고 제안하지만 #Person2#은 교통 체증에 걸리는 것을 싫어한다.
# Summary for index None: #Person1#은 중국 음식을 만들기 위한 재료를 사고 싶어합니다. #Person2#는 켄싱턴 하이 스트리트에 슈퍼마켓이 있으며, #Person1#에게 도움을 줍니다.
# Summary for index None: #Person1#은 11시 30분 기차를 잡을 수 있는지 묻습니다. #Person2#는 교통이 덜 막힌 경로를 선택하라고 제안하고, #Person1#은 받아들입니다.
# Summary for index None: 마이크는 #Person1#에게 중국 여행이 정말 좋았다고 말한다. 그는 베이징, 상하이, 난징, 그리고 구이린을 방문했고, 그들이 아름다웠다.
# Summary for index None: #Person1#은 오늘 밤의 소비자 보고를 마무리하고 제리 라이언에게 스포츠 세계에서 무슨 일이 일어나고 있는지 묻는다. 제리는 축구 경기 결과를 알려준다.
# Summary for index None: #Person1#은 #Person2#에게 휴가에 대해 인터뷰하고 있습니다. #Person2#는 지연된 비행기와 실망스러운 호텔에 대해 이야기합니다. #Person2#는 휴가를 기대하고 있습니다.
# Summary for index None: 빌은 #Person1#에게 눈이 많이 내렸을 때 산에서 길을 잃어 4일 동안 산에서 보냈다고 말한다. 그는 의사들이 그의 다리를 절단했지만, 새로운 다리를 만들어 산을 다시 오를 수 있다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 4인용 창가 테이블을 제공하고, #Person2#는 약간 달달한 맛의 음식을 원한다.
# Summary for index None: 양 씨는 선 씨에게 전출 신청을 하고 싶어한다. 양 씨는 이 사무실을 좋아하지 않기 때문이다. 선 씨는 그녀의 요청을 수락한다.
# Summary for index None: 미셸은 존 샌들스에게 뉴욕의 금연 객실을 예약하는 데 도움을 줍니다. 샌들스는 1박에 $308이라는 가격을 수용하고, 미셸은 그를 위해 객실을 예약합니다.
# Summary for index None: #Person2#는 배당금 입금과 배당금 참여 입금의 차이점에 대해 #Person1#에게 물었다. #Person1#는 그것을 #Person2#에게 설명하고 이미 계좌가 있는 경우 보험료를 납부할 수 있다고 말했다.
# Summary for index None: #Person1#은 아파트를 빌리고 싶어하지만 #Person2#는 임대료가 너무 낮다고 생각합니다.
# Summary for index None: #Person2#는 SARS 유행을 이유로 홍콩 여행이 취소되었지만, #Person1#은 이것이 좋은 일이라고 생각하며, #Person2#는 운동 계획을 세우기로 결정했습니다.
# Summary for index None: #Person1#은 버스에 빨리 타고 싶어하지만 버스가 오지 않습니다. 그들은 차를 사야 한다고 결정합니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#가 광저우에 4개월 동안 있었는데, 그곳에서 중국어를 더 잘 알게 되었다고 말한다. #Person2#는 #Person1#에게 중국인들이 흥정을 좋아하고, 그들이 대화할 때 격렬한 말다툼을 벌이는 것을 보았다고 말한다.
# Summary for index None: #Person1#은 오늘 무엇을 입을지 고민하고, #Person2#는 #Person1#이 쇼핑 중독이라고 생각한다. #Person1#은 또 쇼핑에 가려고 한다.
# Summary for index None: 앨런 파커는 지난 주 필리스 시모어에게 도움을 준 것에 대해 감사의 말을 전하고, 필리스의 상사에게 필리스를 잘 붙잡아 두라고 말하고 싶어한다.
# Summary for index None: 마이크는 #Person1#에게 나노미터가 길이 척도라고 말하고, 이를 이해하기 쉽게 비교하라고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 벤이 자신의 밴드를 만들고 있으며, #Person2#를 초대할 수도 있다고 말한다. #Person2#는 드럼을 칠 수 있지만, DJ가 되는 것을 고려하고 있다. #Person1#은 컴퓨터 프로그램을 사용하는 것을 제안한다.
# Summary for index None: #Person1#은 교재를 사고 싶어합니다. #Person2#은 #Person1#에게 교재를 사는 방법을 알려주고, #Person1#에게 도와줄 수 있습니다.
# Summary for index None: #Person1#은 이번 주말에 스카이다이빙을 하고 싶어하지만, #Person2#는 그것이 위험하다고 생각합니다. #Person1#은 다음 주 월요일에 모든 것을 말할 것입니다.
# Summary for index None: 에밀리는 #Person1#에게 그녀의 매니저가 그녀를 끔찍하게 대하는 방법에 대해 불평한다. #Person1#은 그것이 공정하지 않다고 생각하고, 에밀리는 그것을 참아내기로 결정한다.
# Summary for index None: #Person1#은 혈액 검사를 위해 연구실에 왔습니다. #Person2#는 #Person1#에게 백혈구 수치를 측정하고, 그 수치가 정상이 아니면 감염을 의심한다고 말합니다.
# Summary for index None: #Person1#은 #Person2#에게 가슴 주머니가 하나만 달린 디자인을 찾아달라고 요청하지만, #Person2#는 색상이 다른 것을 발견한다.
# Summary for index None: #Person2#는 #Person1#에게 풀오버 스웨터를 보여달라고 요청하고, #Person1#는 다양한 스타일을 보여줍니다.
# Summary for index None: #Person1#은 #Person2#에게 월 5,000 위안을 제안하고, 3개월 수습 기간 후 성과에 따라 인상해 줄 것이라고 말한다. #Person2#는 만족한다. #Person1#은 #Person2#에게 직속상사, 수당, 해외 출장에 대해 알려준다.
# Summary for index None: #Person1#과 #Person2#는 올해 크리스마스에 가족을 위한 의미 있는 선물을 줄 것이다.
# Summary for index None: #Person1#은 버스를 타고 있고, #Person2#는 #Person1#에게 #Person1#의 차가 있음에도 불구하고 왜 직접 운전하지 않는지 묻는다.
# Summary for index None: #Person1#은 목요일 아침 발표를 위해 리즈에게 도움을 청하고, 리즈는 화이트보드를 설치하는 데 도움을 줄 것입니다.
# Summary for index None: #Person2#는 #Person1#에게 소액 소비자 금융 대출을 신청하고 20,000 RMB를 받았습니다. #Person1#는 #Person2#의 신용 정보를 이미 가지고 있었습니다.
# Summary for index None: #Person2#는 #Person1#에게 승무원이 되기 위해 이 직업을 선택한 이유, 영어로 소통하는 데 어려움이 없는 이유, 승무원의 책임, 건강 상태, 강점과 약점, 그리고 승객이 #Person2#의 말을 알아듣지 못할 때의 대처 방법에 대해 이야기합니다.
# Summary for index None: #Person1#은 비키에게 비키의 경력과 강점에 대해 묻는다.
# Summary for index None: #Person2#는 #Person1#에게 자신의 성격, 성격이 내향적인지 외향적인지, 그리고 행복해지기 위해 필요한 것에 대해 이야기합니다. #Person2#는 진정으로 친하다고 생각되는 동창 세 명과 일하고 싶어합니다.
# Summary for index None: #Person1#은 #Person2#에게 직원의 업무가 불만족스러울 때 관리자가 어떻게 대응해야 하는지 물었다. #Person2#는 #Person1#에게 방해받지 않는 상황에서 일대일 대화를 진행하는 것이 매우 중요하다고 말했다. #Person1#은 #Person2#에게 오늘 아침에 엘리베이터에서 직원을 꾸짖는 것을 들었다고 말
# Summary for index None: #Person1#은 방을 빌리는 방법에 대해 #Person2#에게 묻습니다. #Person2#는 #Person1#에게 신문을 읽는 것을 추천합니다.
# Summary for index None: #Person1#은 #Person2#에게 다크 앤 스토미 나잇을 보기 위해 금요일 영화 입장권을 요청하지만 매진되었습니다. #Person1#은 토요일 앞쪽에 함께 앉을 수 있는 영화 입장권을 구매합니다.
# Summary for index None: #Person2#는 키가 작아서 사촌이 준 로드 자전거를 탈 수 없다. #Person1#는 그에게 새로운 자전거를 사는 것을 제안하고, #Person2#는 #Person1#의 도움으로 자전거를 팔기로 결정한다.
# Summary for index None: #Person1#은 #Person2#에게 호텔 방을 예약하는 데 도움을 청하고, #Person2#는 1층에 있는 방만 아니면 무엇이든 좋다고 말한다. #Person1#은 상층 방을 요청한다.
# Summary for index None: #Person2#는 베를린행 비행기를 예약하고 싶어합니다. #Person1#는 하루 일찍 출발하면 훨씬 저렴하다고 말하고, #Person2#는 그 비행기를 타기로 결정합니다.
# Summary for index None: #Person1#은 #Person2#에게 뉴욕 현대미술관에서 구입한 조지아 오'키프의 '레이크 조지 윈도우' 복제화를 소개하고, #Person1#이 다음 투어에서 더 많은 복제화를 구입할지도 모른다고 말했다.
# Summary for index None: #Person2#는 #Person1#에게 부모님이 자유를 많이 허락하지만, 남자친구와 휴가를 가는 것은 17살이 되어야 한다고 말했습니다.
# Summary for index None: #Person1#은 #Person2#가 자정에도 불구하고 컴퓨터 키보드를 두드리는 것에 화가 났다. #Person2#는 #Person1#에게 자정이 거의 다 되었다고 말하고, #Person1#은 #Person2#에게 #Person2#가 쓰고 있는 기사에 대해 물었다.
# Summary for index None: #Person1#이 #Person2#에게 릭이 브라질에 가서 한 달 동안 일할 것이라고 말한다. 릭은 미국 밖에 처음 나가는 것이기 때문에 기대하고 있다.
# Summary for index None: #Person2#는 아버지의 날 선물을 사려고 하지만 지갑은 비싸고 #Person2#는 돈이 없습니다. #Person1#는 세일 중인 넥타이를 추천하고 #Person2#는 그것을 사기로 결정합니다.
# Summary for index None: #Person1#은 #Person2#에게 택시를 같이 타자고 제안하고, #Person2#는 기꺼이 동의합니다.
# Summary for index None: #Person1#은 식기를 찾고 있습니다. #Person2#는 #Person1#에게 손으로 먹는 방법을 알려줍니다. #Person3#은 #Person1#에게 요리를 소개하고, #Person1#은 #Person3#에게 꿀 와인을 요청합니다. #Person2#는 #Person3#에게 자신의 국제법과 비즈니스 공부에 대해 이야기합니다.
# Summary for index None: #Person1#은 주문 제작 치마를 맞추고 싶어합니다. #Person2#는 사이즈를 재고, #Person1#은 재단 비용을 물어봅니다.
# Summary for index None: #Person1#은 이자벨에게 재즈 학생들을 찾고 있으며, 그들이 어딘가에 있다고 말한다. 이자벨은 #Person1#이 몽상가라고 생각한다.
# Summary for index None: #Person1#이 #Person2#에게 전공, 학과, 그리고 문학 수업에 대해 물었고, #Person2#는 모두에 대해 대답했다.
# Summary for index None: #Person1#은 채혈을 위해 왔고, #Person2#는 #Person1#에게 백혈구 수치를 알아보기 위해 피를 채취한다.
# Summary for index None: #Person1#은 켄터키의 가장 특별한 행사가 모자 퍼레이드라고 #Person2#에게 말한다. #Person2#는 행사에 대해 더 알고 싶어한다.
# Summary for index None: 존은 에임스에게 문에 기름칠을 해달라고 요청합니다. 에임스는 늦은 시간에 문을 열고 닫는 것에 대해 사과하고, 이번 주말에 문을 어떻게 해볼 것이라고 말합니다.
# Summary for index None: #Person1#은 마크에게 그의 어린 시절과 첫 해외 여행에 대해 물어봅니다.
# Summary for index None: 데이비드는 #Person1#에게 오늘 하루가 정말 끔찍했다고 말하고, 스케이트보드를 타다가 떨어져 더러워졌다고 말한다.
# Summary for index None: 토미는 엄마에게 휴대폰이 훔쳐졌다고 말한다. 엄마는 토미에게 지금 바로 경찰에 신고하라고 말하고, 보험사에 알아볼 것이라고 한다.
# Summary for index None: #Person1#은 테이블을 사려고 합니다. #Person2#는 튼튼하고 밝은 테이블이 좋다고 생각하지만, #Person2#는 약한 테이블을 원합니다.
# Summary for index None: 조지 데이먼이 메이블 호텔에 전화하여 1월에 200명을 수용할 수 있는 공간을 예약하려고 한다. #Person1#은 13호실을 추천하지만 조지는 끝자리가 9인 19호실이나 26로실을 원한다.
# Summary for index None: #Person1#은 #Person2#에게 자전거의 장점에 대해 이야기합니다. #Person2#는 동의합니다.
# Summary for index None: 마리아는 비전통적인 애완동물을 키우고 싶어하고, 샘은 그것이 위험하다고 생각한다. 샘은 그녀에게 강아지를 키우는 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 중국과의 사업에 대해 인터뷰하고, #Person2#는 중국 파트너들과의 문제는 없다고 생각하며, 중국 정부가 노력하고 있다고 말합니다.
# Summary for index None: #Person1#은 케이트에게 채널을 바꾸라고 요청하고, 케이트는 토크쇼를 보는 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 계산서를 받고 싶어합니다. #Person2#는 #Person1#의 계산서를 확인합니다.
# Summary for index None: #Person1#은 크리스토퍼에게 일요일에 해변에 가자고 제안한다. 크리스토퍼는 기대하고 있지만, 서핑을 해본 적이 없기 때문에 걱정하고 있다.
# Summary for index None: #Person1#은 도리스에게 헬렌 몰에서의 세일에 같이 가자고 제안하지만, 도리스는 돈이 없어서 거절한다.
# Summary for index None: #Person1#은 사무실 파티를 준비하는 데 도움이 필요하다. #Person2#는 #Person1#에게 엔터테인먼트를 맡고 미국 음식을 준비하라고 제안한다.
# Summary for index None: #Person1#은 처방전을 받으러 왔고, #Person2#는 #Person1#에게 처방전을 20분 후에 준비할 것이라고 말했다. #Person2#는 #Person1#에게 약을 복용하는 방법을 알려주었다.
# Summary for index None: #Person1#은 TV를 볼 수 없어서 엄마에게 물었고, 엄마는 #Person1#에게 독서를 하라고 하고 리모컨을 나중에 찾겠다고 말했다.
# Summary for index None: #Person2#는 #Person1#이 빨간 불을 무시하고 운전했기 때문에 벌금 티켓을 발행했습니다.
# Summary for index None: #Person1#은 앨런이 무슨 일이 생겼는지 물어본다. #Person2#는 앨런의 여동생이 차 사고를 당해서 병원에 입원했다고 말한다.
# Summary for index None: #Person1#은 존을 만나고 그의 학교 시험에 대해 이야기한다. 존은 쇼핑하러 가려고 하지만 #Person1#은 누군가를 만나야 한다.
# Summary for index None: #Person1#은 빈스에게 프로그래머 중 한 명이 웹트레커를 위해 그들을 감시하고 있다고 말합니다. 빈스는 #Person1#에게 데이브가 웹트레커의 스파이라고 의심합니다.
# Summary for index None: #Person1#과 #Person2#는 서로 다른 영화를 좋아합니다. #Person2#는 #Person1#에게 두 번째 데이트에서 공포 영화를 보러 가자고 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 급여 인상을 요청하고, 그에 대한 대가로 스케줄을 담당하고 초과근무 수당을 받는다.
# Summary for index None: 케롤은 사이먼이 영화에 가지 않고, 그의 변명이 거짓말이라고 생각한다. 레베카는 그녀를 위로한다.
# Summary for index None: #Person1#은 #Person2#에게 흡연을 금지시키고, #Person2#는 안내문을 읽을 수 없다.
# Summary for index None: 에이미는 만두를 먹고 싶어하고 릭은 새로운 것을 시도하자고 제안한다. 그들은 연양 팟을 시도하기로 결정하고, 릭은 스웨터를 입고 올 것이다.
# Summary for index None: #Person1#은 설거지를 도와야 하지만 #Person2#는 #Person1#에게 먼저 양파를 까고 씻은 다음에 썰라고 말한다. #Person1#은 그것을 끝내고 아빠와 형을 불러줄 것이다.
# Summary for index None: #Person1#은 우주 여행의 위험성에 대해 걱정하고 있지만, 랄프는 #Person1#에게 상황이 좋아졌다고 말하고, 우주에서 인간이 직면하는 실제 위험은 방사선이라고 설명한다.
# Summary for index None: #Person1#과 #Person2#는 커피 테이블을 고르고 있습니다. #Person2#는 청소하기 쉽고 가격이 저렴한 것을 선호합니다.
# Summary for index None: #Person2#는 밝은 색상의 아이섀도우를 구입하려고 합니다. #Person1#는 몇 가지 제품을 추천하고, #Person2#는 마침내 원하는 것을 찾습니다.
# Summary for index None: #Person1#은 #Person2#의 상 수상을 축하하고, #Person2#는 놀라워하고 #Person1#에게 감사의 말을 전한다.
# Summary for index None: #Person1#은 마스터 카드 청구서를 받지 못했고, #Person2#는 우체국에 연락하라고 제안한다. #Person1#은 감사의 말을 한다.
# Summary for index None: #Person1#은 #Person2#에게 직접 지불하고 개인 의료 보험을 가지고 있다고 말합니다. #Person2#는 #Person1#에게 보험금 청구를 위한 증명서를 줍니다.
# Summary for index None: #Person1#은 신문 광고를 통해 저렴한 아파트를 찾았다. #Person2#는 #Person1#을 축하한다.
# Summary for index None: #Person2#는 #Person1#의 도움으로 몇 개의 꽃병을 창춘으로 보내기 위해 항공우편을 이용하고 있습니다.
# Summary for index None: #Person2#는 #Person1#에게 근무 시간이 유연하다고 말하고, #Person1#는 이를 선호한다.
# Summary for index None: #Person1#은 #Person2#에게 피카소의 그림 전시회에 함께 가자고 제안하지만, #Person2#는 차가 없어서 거절한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#이 서른이 된 날 컴퓨터를 켰을 때, 장난삼아 서른 넘은 사람들의 방에 들어가서 그가 거기에 있었고, 그들은 채팅을 시작했다고 말했다. #Person1#은 #Person2#에게 그들이 개인적인 것에 대해 이야기하지 않기로 결정했다고 말했다.
# Summary for index None: #Person1#은 #Person2#에게 예약 전화를 받은 사람이 기록을 잊어버려 자리가 없다고 말합니다. #Person2#는 중요한 사람들을 초대했기 때문에 #Person1#에게 한 테이블 더 놓을 수 있도록 요청합니다.
# Summary for index None: 바비는 밤중에 발에 심한 통증이 있었고, 카르다노 박사는 그녀를 3층의 실험실로 보내서 혈액 검사를 받게 했다.
# Summary for index None: 톰은 샐리에게 자신이 사람들을 위해 마당 일을 한다고 말한다. 샐리는 일에서 물건을 들고 다니는 것이 지치는 것을 인정하고, 그들 모두가 학비를 벌어야 한다는 것에 동의한다.
# Summary for index None: #Person1#은 수잔에게 중국의 못생긴 여성 넷을 소개하고, 그들이 내면의 아름다움을 가지고 있었기 때문에 존경받았다고 말했다.
# Summary for index None: #Person1#은 재채기를 하고 눈물이 나는데, #Person2#는 #Person1#이 알레르기가 있다고 생각한다. #Person1#은 땅콩 알레르기가 있는지 확인하려고 #Person2#에게 던지지만, #Person2#는 알레르기가 없다. #Person1#은 먼지 알레르기가 있는지 확인하려고 하지만, #Person2#는 먼지가 가득한 사
# Summary for index None: #Person1#은 #Person2#를 재촉하고 있지만, #Person2#는 #Person1#이 결혼 후로 더 성급해지고, 일 때문에 바쁘다는 이유로 화를 냅니다. #Person1#은 #Person2#에게 자신이 여전히 #Person2#를 사랑한다고 말하고, #Person2#는 감동합니다.
# Summary for index None: #Person1#은 팬이 필요하다. #Person2#는 #Person1#에게 팬을 추천하고, #Person1#은 그것을 구매한다. #Person1#은 현금으로 결제하고, #Person2#는 #Person1#에게 뚜껑도 포함되어 있다고 말한다.
# Summary for index None: #Person1#은 릴리에게 리지의 가족을 알고 있는지 묻는다. 릴리는 그들을 알고 있지만, #Person1#은 그들을 방문하고 싶어한다.
# Summary for index None: #Person1#은 존슨 가족이 돌아오는 길이라고 말하고, #Person2#는 그들을 기억하지 못한다. #Person1#은 #Person2#를 도와 기억시키려고 노력하지만 실패한다.
# Summary for index None: 링컨이 캐피탈 호텔에 전화를 걸어 예약을 유지해달라고 요청한다.
# Summary for index None: #Person2#는 #Person1#에게 셰프의 샐러드와 미디엄 레어의 스테이크를 주문하고, 그것과 함께 완두콩과 당근을 원한다.
# Summary for index None: #Person1#은 #Person2#에게 비행기가 2시간 후에 출발한다고 말하고, #Person2#는 서둘러야 한다. #Person2#는 지갑을 찾지 못하고, #Person1#은 #Person2#를 비난한다. #Person2#는 지갑을 찾지만 열쇠를 잃어버린다.
# Summary for index None: #Person1#은 축구 토너먼트를 보았고, #Person2#는 축구에 대해 더 많이 알고 싶어한다. #Person2#는 축구에 대해 더 많이 알고 싶어한다. #Person1#은 #Person2#에게 축구에는 골 이외에도 많은 것들이 있다고 말한다.
# Summary for index None: 토니 찬은 파크 호텔에 전화하여 싱글룸을 예약하고 있습니다. #Person2#는 그의 예약을 도와주고 있습니다.
# Summary for index None: 선 신문의 기자가 필 테일러에게 화재가 어떻게 일어났는지 묻는다. 필은 감자튀김 때문에 화재가 발생했다고 말하고, 그가 불을 끄는 데 어떻게 했는지 설명한다.
# Summary for index None: #Person2#는 1월 29일부터 2월 1일까지의 예약을 취소하고, #Person1#는 280달러를 돌려줍니다.
# Summary for index None: #Person1#은 #Person2#에게 전화 받기, 이메일 보내기, 일찍 일어나기 등의 업무에 대해 묻는다. #Person2#는 이에 대해 대답하고 참조인을 제공한다. #Person1#은 결정을 내린 후 #Person2#에게 연락할 것이다.
# Summary for index None: #Person1#은 고양이를 칭찬하지만, #Person2#는 개를 키우는 것이 더 좋다고 생각합니다. 그러나 둘 다 애완동물을 키울 준비가 되어 있지 않다고 느낍니다.
# Summary for index None: #Person1#은 TV 수리가 아직 끝나지 않았다고 #Person2#에게 말한다. 그들은 오늘 밤에 볼 영화를 선택하고 결정한다. #Person2#는 '아빠 셋 엄마 하나'를 보기로 결정한다.
# Summary for index None: #Person2#는 #Person1#에게 카메라맨이 되기로 결정한 계기를 말합니다. #Person2#는 텔레비전을 많이 보지 않았고, 삼촌이 영화 배우였지만 거의 만나지 못했습니다. #Person2#는 카메라맨의 전기를 읽고 그것이 재미있었기 때문에 카메라맨이 되기로 결정했습니다. #Person2#는 또한 미래의 계획과
# Summary for index None: 왕 여사는 가격이 너무 높아 입찰하기 어렵다고 브라운 씨에게 말합니다. 브라운 씨는 5%의 할인을 제안하지만, 왕 여사는 더 많은 할인을 요청합니다. 브라운 씨는 본사로부터 답변을 받을 때까지 기다리기로 합니다.
# Summary for index None: #Person1#은 #Person2#에게 전통 예술품을 추천하고, #Person2#는 외국 친구들에게 줄 선물을 고르기 위해 종이접기를 선택한다. #Person2#는 #Person1#이 진짜 전문가라고 생각한다.
# Summary for index None: 제인은 #Person2#에게 장부를 검토하기 위해 시간을 내달라고 요청한다. #Person2#는 1시 30분에 30분 동안 제인과 함께 할 수 있다.
# Summary for index None: #Person2#는 새 냉장고를 사고 싶어합니다. #Person1#는 켄모어 냉장고를 추천하고, #Person2#는 그것을 좋아합니다.
# Summary for index None: #Person1#은 컴퓨터가 아이들에게 논리적인 생각을 요구하기 때문에 생각하는 법을 가르친다고 생각하지만, #Person2#는 그것에 동의하지 않습니다.
# Summary for index None: #Person1#과 #Person2#는 만리장성을 보고 있습니다. 그들은 어떻게 올라갈지에 대해 이야기하고, 결국 올라가기로 결정합니다.
# Summary for index None: #Person1#은 샌드위치와 음료수를 주문하려고 하고, #Person2#은 주문 금액이 15달러 이상이면 배달이 가능하다고 말한다.
# Summary for index None: #Person1#은 런던행 기차 시간표를 #Person2#에게 물어봅니다. #Person2#는 도착 시간과 티켓 가격에 대해 설명하고, #Person1#은 일반 왕복 티켓을 구입합니다.
# Summary for index None: #Person2#는 #Person1#에게 이력서에 적힌 전화번호로 전화를 걸어서 #Person2#의 월급과 결과를 알려줄 것이라고 말했습니다.
# Summary for index None: #Person2#는 데이브에게 그가 웹트래커에서 일하고 있다는 것을 알게 된 경험을 공유한다. 데이브는 놀란다.
# Summary for index None: #Person1#은 비디오 게임을 하고 싶지 않아서 집에 혼자 있었고, #Person2#는 이를 이해한다. #Person1#은 비디오 게임에 빠져 있고, #Person2#는 #Person1#이 집에서 편안하게 무언가를 하는 것이 좋다고 생각한다.
# Summary for index None: #Person1#과 #Person2#는 여름 휴가를 즐기고 있습니다. #Person2#는 #Person1#에게 함부르크에 머물 생각이었지만 서두르지 않으면 불가능하다고 말합니다. #Person1#은 먼저 호수를 즐기고 싶어합니다.
# Summary for index None: #Person1#은 베이징으로 출장을 가고, #Person2#는 친구를 만나러 휴가를 갑니다. #Person1#은 #Person2#에게 베이징의 지하철이 너무 붐비기 때문에 버스를 타거나 차를 빌리라고 제안합니다.
# Summary for index None: #Person2#는 #Person1#에게 야근으로 피곤하다고 말하고, 이는 큰 프로젝트를 끝내야 했기 때문이라고 말한다. #Person2#는 #Person1#에게 승진을 희망한다.
# Summary for index None: #Person2#는 여가 시간에 춤, 체스, 우표 수집, 여행, 사진 찍기를 좋아합니다. #Person1#는 중국 체스에는 관심이 없지만, 중국 장기나 군사 체스를 배울 것입니다. #Person1#는 원예를 좋아합니다.
# Summary for index None: #Person1#과 #Person2#는 서로 좋은 주말을 보내기를 바랍니다. #Person2#는 #Person1#에게 가족들이 멀리 있고 비용이 많이 들어서 계획이 없다고 말합니다.
# Summary for index None: #Person1#은 부엌에서만 사용할 수 있는 제품을 원합니다. #Person2#는 두 제품을 비교하고, #Person1#은 저렴한 제품을 결제합니다.
# Summary for index None: #Person1#과 #Person2#는 도시에서 가장 멋진 식물원을 방문했다. #Person2#는 더 많은 사진을 찍고 싶어했고, #Person1#은 도와주기로 결정했다.
# Summary for index None: #Person1#은 #Person2#에게 면접이 끝났음을 알리고, 최종 결정을 전화로 알려줄 것이라고 말한다. #Person2#는 2차 면접에 대해 묻는다.
# Summary for index None: #Person1#은 존에게 다음 주 회의에 고객들을 초대하라고 지시하고, 존은 회의 일정을 준비하고 연락처를 #Person1#에게 가져다줄 것입니다.
# Summary for index None: #Person1#은 #Person2#에게 운전 시험에 합격했다는 것을 물었고, #Person2#는 #Person1#이 한 가지를 제외하고는 훌륭히 했다고 말했다.
# Summary for index None: #Person1#은 학생 입장료에 대해 묻고, #Person2#는 50% 할인을 해준다. #Person1#은 박물관 안내서를 무료로 받는다.
# Summary for index None: #Person1#은 기차역으로 가려고 하지만 16번 버스를 기다리는 것을 기다릴 수 없습니다. #Person2#는 2번 버스를 타는 것을 제안하고, #Person1#은 감사합니다.
# Summary for index None: #Person2#는 버스를 너무 일찍 내려서 #Person1#을 불편하게 했다. #Person1#은 걷고 싶지 않다.
# Summary for index None: #Person1#은 #Person2#에게 전화를 걸어 아파트를 빌리고 싶다고 말했다. #Person2#는 #Person1#에게 아파트에 대한 정보를 제공했다.
# Summary for index None: #Person1#은 #Person2#에게 비행기 탑승 절차에 대해 묻습니다. #Person2#는 #Person1#에게 티켓을 보여주고 저 키오스크에서 탑승권을 받는 방법을 알려줍니다.
# Summary for index None: #Person1#은 리 양에게 그녀의 경력 목표에 대해 묻는다. 그 후, #Person1#은 리 양에게 그녀가 잘 맞을 수도 있는 회사의 비서 직무에 대해 이야기한다.
# Summary for index None: #Person1#은 #Person2#에게 집에 초고속 인터넷을 설치하고 싶다고 말한다. #Person2#는 토요일 11시에 올 수 있다.
# Summary for index None: #Person1#은 #Person2#가 늦게 들어오고 전화하지 않아서 화가 났다. #Person1#은 #Person2#가 다시 늦게 들어오면 물건들을 밖에 놓을 것이라고 말했다.
# Summary for index None: #Person1#은 수프를 마시는 것이 끔찍하다고 생각하고, #Person2#는 #Person1#에게 수프를 먹도록 요청한다.
# Summary for index None: #Person1#은 체스가 더 합리적이라고 생각하고, #Person2#는 중국장기를 더 좋아한다. 그들은 두 게임의 차이점을 논의한다. #Person1#은 체스가 더 강력하다고 생각하고, #Person2#는 중국장기가 더 큰 공간에서 움직일 수 있다고 생각한다.
# Summary for index None: #Person1#과 #Person2#는 놀라움을 느끼고, 토요일 아침 9시에 식료품 쇼핑을 피하기 위해 이곳에 왔다.
# Summary for index None: 제인은 멀버리 핸드백을 사기로 결정했지만, 존은 그녀에게 핸드백 대여를 제안한다. 제인은 그것이 좋은 생각이라고 생각하고, 존은 그녀에게 어떻게 빌릴 수 있는지 알려준다. 그 후 제인은 온라인으로 주문한다.
# Summary for index None: 엘사 토빈이 자리를 바꾸고 마이크 제라드 호건을 만나서 인사를 나눕니다.
# Summary for index None: #Person1#은 이혼과 그것이 아이들에게 미치는 영향에 대해 제니퍼 벤제스에게 인터뷰합니다. 제니퍼는 이혼이 그녀의 아이들에게 미치는 영향에 대해 이야기하고, 이혼이 그들을 위로하려고 노력한다고 말합니다.
# Summary for index None: #Person1#은 티나에게 이번 주에 밴드 연습에 올 것을 요청한다. 티나는 기타가 고장나서 못 갔다. #Person1#은 티나에게 기타를 빌려주려고 하지만, 티나는 왼손잡이 기타를 가지고 있기 때문에 거절한다.
# Summary for index None: #Person1#은 #Person2#의 유전학 박사학위를 축하하고, #Person2#는 #Person1#에게 자신의 진로에 대해 이야기한다. #Person2#는 #Person1#에게 유전학에 대한 논의가 많이 있고, 가능성이 많다고 말한다.
# Summary for index None: #Person2#는 와인 리스트를 요청하지만 #Person1#은 칵테일을 추천합니다. #Person2#는 쿠에르보 골드 마가리타를 주문합니다.
# Summary for index None: #Person1#은 #Person2#에게 78세의 새로운 이민자 친구에게 읽는 법을 가르쳐 주는 것을 도와달라고 요청한다. #Person2#는 동의하고 #Person1#에게 저녁을 만들어 달라고 요청한다.
# Summary for index None: 스티븐이 베로니카에게 사과하고 그녀와 결혼하자고 제안하지만, 베로니카는 거짓말에 관계를 맺을 수 없다고 말한다. 스티븐은 비행기를 타야 하지만 베로니카가 오지 않는다.
# Summary for index None: #Person1#은 흉부 엑스레이 촬영을 하기 위해 #Person2#에게 오라고 했습니다. #Person2#는 #Person1#에게 어떻게 서야 하는지 알려주고, #Person1#은 #Person2#가 사진을 찍을 때까지 기다립니다.
# Summary for index None: 마크와 #Person2#는 폭염에 대해 이야기하고 있다. #Person2#는 마크에게 술을 많이 마시도록 권한다.
# Summary for index None: #Person1#은 셔츠가 끔찍하다고 생각하고, #Person2#는 80년대 스타일을 좋아한다고 생각했지만, #Person1#은 그렇지 않다. #Person1#은 모던한 가게에서 더 나은 것을 찾기로 결정했다.
# Summary for index None: #Person2#는 #Person1#에게 아들이 물 속에 빠져 끔찍한 상황에 처했다고 말합니다. 헨리 씨가 아들을 구해줘서 다행히 아무런 문제가 없었습니다.
# Summary for index None: #Person2#는 #Person1#에게 어머니가 훨씬 나아졌다고 말하고, 어머니를 돌보는 일을 직접 하겠다고 말한다. #Person1#는 #Person2#를 칭찬한다.
# Summary for index None: #Person1#은 차가 항상 아침에 시동이 걸리지 않아서 새 차를 사려고 합니다. #Person2#는 지미의 정비소를 추천하고 #Person1#에게 예약을 하라고 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 케임브리지를 돌아보라고 제안하지만, #Person2#는 친구와 함께 이미 갔기 때문에 오늘은 테이트 모던에 가기로 결정했다.
# Summary for index None: #Person1#은 일자리를 잃었고, #Person2#는 학생들이 기말고사 때문에 긴장하고 있다. #Person1#은 #Person2#가 영어를 잘 가르쳐줘서 감사하다.
# Summary for index None: #Person1#은 #Person2#가 게임에 미쳐서 피곤해 보인다고 생각하고, 게임을 줄이는 대신 다른 일에 바쁘다면 게임할 시간이 없을 것이라고 제안한다.
# Summary for index None: 빌은 슈에게 케이크를 먹도록 권하지만, 슈는 다이어트 중이기 때문에 거절한다. 슈는 의사가 특정 음식을 먹지 말라고 했기 때문에 다이어트를 하고 있으며, 빌은 그에게 수프를 가져다 줄 것이다.
# Summary for index None: #Person1#과 #Person2#는 밴쿠버에서 퀘벡으로 가는 횡단 여행 계획을 다시 한번 살펴보고 있다.
# Summary for index None: #Person1#은 #Person2#에게 자신을 솔직하고, 근면하며, 끈기있고, 창의적이라고 말합니다. #Person2#는 #Person1#이 마음이 착한 여성이라고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 여행에 대해 논의하고 있습니다. #Person2#는 비용이 더 들더라도 기차를 선호하고, #Person1#는 그에 동의합니다. 그들은 왕복 표를 사기로 결정했습니다.
# Summary for index None: 에취는 #Person2#에게 알레르기에 걸려서 재채기하고, 코가 많이 흐르고, 가끔 목이 가려워진다고 말한다. #Person2#는 술에 대한 심각한 알레르기 반응이 있다.
# Summary for index None: #Person1#과 #Person2#는 기차를 타기 위해 표를 사고 있습니다. #Person2#는 기차에 타기 좋은 위치에 서라고 제안합니다.
# Summary for index None: #Person2#는 #Person1#에게 약물 문제로 인해 선수가 실격되었다고 말한다. #Person1#은 이에 대해 실망하고, #Person2#는 새로운 규정이 이를 막을 것이라고 생각한다.
# Summary for index None: #Person1#은 서부극을 보고 싶어하고 #Person2#는 축구 경기를 보고 싶어했지만, 결국 #Person1#과 #Person2#는 퀴즈쇼를 같이 보기로 결정했다.
# Summary for index None: #Person2#는 뉴욕에 3일 동안 머무르고 싶어합니다. #Person1#는 #Person2#에게 짐을 보관하라고 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 오늘 밤에 축구 경기가 있으므로 술과 디저트를 사러 가자고 제안합니다.
# Summary for index None: #Person1#은 아파트를 빌리고 싶어하지만 #Person2#는 월 $ 1050 이하로는 내려가지 않을 것입니다.
# Summary for index None: #Person1#과 #Person2#는 음악에 대해 이야기하고 있습니다. #Person1#은 팝 음악을 좋아하고, #Person2#는 클래식 음악을 좋아합니다. #Person2#는 어릴 때 피아노를 배웠고, 아직도 취미로 피아노를 치고 있습니다.
# Summary for index None: #Person2#는 #Person1#의 도움으로 아내와 함께 놀라운 시골 여행을 계획하게 되었습니다. #Person1#은 #Person2#에게 패키지에 대해 설명하고, #Person2#는 비용에 대해 걱정하지 않습니다.
# Summary for index None: 왕 메이야는 #Person1#의 새 드레스를 칭찬하고, 그 드레스를 구매하고 싶어한다. #Person1#은 그녀와 함께 가자고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 머리를 자르고 싶어합니다. #Person1#은 #Person2#의 일에 만족하고, #Person2#는 $55를 받습니다.
# Summary for index None: #Person1#과 #Person2#는 공원에서 산책하고 있습니다. #Person2#는 공원이 조용하다고 생각하지만, #Person1#은 많은 사람들이 있다고 생각합니다.
# Summary for index None: #Person1#은 #Person2#에게 일본어 전공으로 동아시아 언어학과에서 공부하고 있다고 말한다. #Person2#는 문학 과정이 매우 도움이 된다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 플로리다에 있는 #Person1#의 콘도에 가자고 제안한다. #Person2#는 기쁘다.
# Summary for index None: #Person1#은 #Person2#를 환영하고, #Person2#는 와인 한 병을 가져왔다. #Person1#은 #Person2#에게 음료를 제공하고, #Person2#는 레드 와인을 선택했다. #Person1#은 #Person2#에게 저녁 식사에 누가 오지 않을지 말했다.
# Summary for index None: #Person1#은 배가 고프다. #Person1#과 #Person2#는 핫팟을 먹기로 결정한다. #Person2#는 식당 이름을 잊어버리지만, #Person1#은 그것을 기억한다.
# Summary for index None: #Person1#은 #Person2#의 교육 배경, 대학원 과정, 그리고 Oracle에서의 업무 경험에 대해 묻습니다. #Person2#는 그에 대해 자세히 설명합니다.
# Summary for index None: #Person1#은 룸 서비스를 요청했지만 #Person2#는 15분이 더 걸릴 것이라고 말했습니다. #Person1#은 실망했습니다.
# Summary for index None: #Person1#은 #Person2#에게 빨간 불에 우회전 금지라고 경고하고 벌금 티켓을 발행했습니다.
# Summary for index None: #Person1#은 #Person2#에게 버스를 타라고 말하지만, #Person2#는 짐을 들고 가는 것을 싫어합니다.
# Summary for index None: #Person1#은 신규 이사자인 잭에게 식료품점, 세탁소, 그리고 이발소를 소개합니다.
# Summary for index None: #Person1#은 #Person2#가 항상 행복해 보이는 이유를 묻습니다. #Person2#는 운동을 하기 때문이라고 말하고, #Person1#은 운동이 새로운 것을 배우는 데 도움이 된다는 것을 배웁니다.
# Summary for index None: #Person2#는 #Person1#에게 여행이 3시간 동안 이어지고 15개의 관광지를 방문하게 될 것이라고 약속했지만 2시간 동안만 여행했다고 말한다. #Person1#는 조사를 약속한다.
# Summary for index None: #Person2#는 #Person1#에게 스테레오의 보증에 대해 묻습니다. #Person1#는 #Person2#에게 매장 정책과 제조사의 보증에 대해 설명합니다.
# Summary for index None: #Person1#은 침실 세트를 사고 싶어합니다. #Person2#는 이케아에서 자신의 것을 샀으며, #Person1#에게 그것이 좋다고 말합니다.
# Summary for index None: #Person1#은 피로와 높은 혈압 때문에 의사에게 찾아갑니다. 의사는 #Person1#에게 과로가 원인이라고 말하고, #Person1#이 체중을 줄이고 운동을 더 해야 한다고 제안합니다.
# Summary for index None: #Person2#는 #Person1#에게 시범 주문을 제안하지만, #Person1#는 그것에 동의할 수 없습니다. 그들은 결국 반복 주문에 동의하지만, #Person1#는 반복 주문이 시범 주문과 같은 조건을 가질 수 없다고 말합니다.
# Summary for index None: #Person1#은 마틴에게 물리학 책을 빌리고 예전 시험지를 볼 수 있도록 요청한다. 마틴은 동의하고, 점심시간에 만나기로 한다.
# Summary for index None: 데이비드 파커는 신문에 광고된 아파트에 대해 전화를 걸어서 #Person2#에게 물어봤다. #Person2#는 그에게 아파트에 대한 정보를 알려주었다.
# Summary for index None: 로드는 바바라를 환영하고 그녀의 여행에 대해 묻습니다. 바바라는 로드에게 밀라노는 흥미롭지만 피곤했다고 말하고, 짐이 무거워서 피렌체에 가지 않았다고 말합니다.
# Summary for index None: #Person1#은 가죽 자켓을 원했지만, #Person1#의 부모님은 비옷을 샀다. #Person1#은 비옷을 반품하고 가죽 자켓을 사고 싶어했지만, #Person2#는 #Person1#에게 50달러를 빌려주고 돈을 갚아달라고 했다.
# Summary for index None: #Person1#은 쇼핑을 하고 있고, #Person2#는 영수증을 보고 #Person1#이 필요하지 않은 물건을 샀다고 생각한다. #Person1#은 #Person2#에게 허버트를 위한 것이라고 설명하지만, #Person2#는 스테이크를 밖에 던진다.
# Summary for index None: #Person2#는 #Person1#에게 내일은 푹 쉴 수 있지만 모레는 바쁜 날이 될 것이라고 말했다.
# Summary for index None: #Person1#은 #Person2#에게 약속 시간이 11시라고 말하지만, 그는 실제로는 10시 30분에 약속이 있다.
# Summary for index None: #Person1#은 정장을 만들고 싶어합니다. #Person2#는 체형 측정을 하고, #Person1#은 싱글 브레스트를 원합니다. #Person2#는 2주 후에 완성될 것입니다.
# Summary for index None: #Person1#은 #Person2#에게 고등학교를 졸업했고, 네 개의 대학에 합격했지만, 런던에서 생활하는 데 돈이 많이 들기 때문에 어느 학교에 갈지 결정하지 못했다고 말합니다. #Person2#는 #Person1#에게 장학금을 신청하라고 제안합니다.
# Summary for index None: #Person1#과 #Person2#는 새로운 휴대폰 사용 규칙에 대해 이야기하고 있습니다. #Person2#는 그것이 동료들에 대한 존중을 보여준다고 생각하지만, #Person1#는 그것이 합리적이지 않다고 생각합니다.
# Summary for index None: #Person1#은 #Person2#의 새 노트북을 칭찬한다. #Person2#는 #Person1#에게 무선 인터넷 연결을 제공하는 카페에서 무료로 인터넷에 접속할 수 있다고 말하고, #Person2#의 노트북에 어떤 프로그램들이 있는지 설명한다.
# Summary for index None: #Person2#는 #Person1#에게 호주의 거대한 산불과 아프리카의 가뭄에 대해 이야기하고, 국제 사회가 어떻게 도움을 주고 있는지 설명한다. #Person2#는 또한 이란에서의 지진에 대해 이야기하고, #Person1#에게 사상자 수를 알려준다.
# Summary for index None: #Person2#와 아내가 #Person1#에게 주문을 합니다. #Person2#는 콜슬로와 송어가 없어서 작은 혼합 샐러드를 주문합니다.
# Summary for index None: 해리엇은 존에게 논문 작업을 시작한 이후로 컴퓨터 화면에 나타나는 광고를 막아주는 앱을 사라고 제안한다. 해리엇은 존에게 그것이 가치가 있다고 생각하게 한다.
# Summary for index None: #Person1#은 차 향기가 좋다고 생각하고, #Person2#는 그것이 '철관음'이라고 말한다. #Person1#은 차 분류를 이해하는 것이 어렵다고 생각하고, #Person2#는 그것을 설명한다. #Person1#은 차 문화에 대해 더 말해 달라고 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 7시 30분까지 식당에 가야 한다고 말하지만, #Person2#는 퇴근 시간이 거의 끝나가고 있으므로 #Person1#에게 길 안내를 요청한다.
# Summary for index None: #Person1#은 물고기를 사려고 하지만 #Person2#는 물고기를 키우려면 어항이 필요하다고 생각합니다. #Person2#는 #Person1#에게 어항의 구조와 물속 식물을 사는 것이 중요하다고 말합니다.
# Summary for index None: 피터 파커는 메리에게 수학 문제를 도와달라고 요청하지만, 메리는 바쁘다. 그들은 내일 점심 후에 만나기로 결정한다.
# Summary for index None: #Person1#은 추수감사절을 맞아 토론토로 여행을 떠날 예정이다. #Person2#는 집에 머무를 예정이다.
# Summary for index None: 넷은 리사에게 그녀가 왜 날씨가 안 좋을 때 차를 타지 않는지 물어봅니다. 리사는 그녀의 근무 시간이 이미 충분히 길기 때문에 기차에서 할 수 있는 일들을 하지 않습니다.
# Summary for index None: #Person2#는 #Person1#의 도움으로 꽤 큰 금액을 인출했다. #Person1#은 #Person2#에게 돈을 세어보라고 요청했다.
# Summary for index None: #Person1#은 글씨가 너무 연해 토너 카트리지를 교체했지만, #Person2#는 누군가가 최근에 대량의 팩스를 받았을 수도 있다고 생각한다. #Person1#은 IT 부서에 누군가에게 확인하라고 제안한다.
# Summary for index None: #Person1#은 스미스 씨에게 실크 스커트와 코트에 관심이 있다고 말하고, 그들은 납품 계약을 체결하기로 합니다. 스미스 씨는 #Person1#에게 고객들을 참여시키는 것에 동의합니다.
# Summary for index None: 하오 보는 스턴 씨에게 7월 10일 오전 10시 30분에 광저우로 가는 3장의 일등석 티켓을 예약했습니다. 그는 스턴 씨의 아이들의 이름을 물었습니다.
# Summary for index None: 헨리는 #Person1#에게 담배를 달라고 요청하고, #Person1#은 헨리에게 함께 있을 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 스쿠터의 '오감기관'이 섬세하고 민첩하다고 말하고, #Person2#는 그것이 매력적이라고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 날씨에 대해 이야기하고 있습니다. #Person2#는 #Person1#에게 겨울이 지루하다고 말합니다.
# Summary for index None: 엘리스는 아담에게 늦은 이유를 설명하고 사과한다. 아담은 그녀가 늦었지만 이제 왔으니까 괜찮다고 생각한다.
# Summary for index None: #Person1#과 #Person2#는 매트릭스를 보고 싶어하지만 표를 구하기 어려워한다. 그들은 다음 영화를 확인하고 줄을 서서 표를 구하려고 노력한다.
# Summary for index None: #Person2#는 잡지를 대출하려고 하지만 #Person1#은 잡지 대출을 허용하지 않습니다. #Person2#는 이를 이해하지 못합니다.
# Summary for index None: #Person2#는 미국으로 돌아가기 전에 #Person1#에게 작별 인사를 하러 왔다.
# Summary for index None: 제러드는 트리나에게 청혼하고, 트리나는 이미 결혼식을 계획해뒀다. 트리나는 제러드에게 결혼식에 대한 모든 것을 말하고, 제러드는 놀라워한다.
# Summary for index None: 에이바는 이단에게 그녀가 두 시간 늦게 출근했고, 상사가 그녀를 해고할 것이라고 말했다고 말한다. 그녀는 다른 일자리를 찾아야 한다고 생각하고, 에이바는 그녀를 도와줄 것이다.
# Summary for index None: #Person1#은 모래 폭풍 때문에 완벽한 계획이 망가졌다. #Person2#는 모래 폭풍이 끝나기를 기다리고 아파트를 청소하기로 결정했다.
# Summary for index None: #Person1#은 #Person2#에게 일레인이 너에게 부족하다고 생각하고, #Person2#에게 그녀를 데이트에 초대하지 않는다면 로빈슨 가족을 저녁 식사에 초대하겠다고 말한다.
# Summary for index None: #Person1#은 헬렌이 미국으로 유학을 가게 되어서 신이 나는 것을 축하한다. 헬렌은 #Person1#에게 그녀의 계획을 말한다.
# Summary for index None: #Person1#은 찰스를 파티에 초대한다. 찰스는 의자를 가져갈 것이다. #Person1#은 그를 6시 반에 데리러 갈 것이다.
# Summary for index None: #Person2#는 뉴델리로 송금을 하고 싶어합니다. #Person1#은 #Person2#에게 은행어음을 추천합니다.
# Summary for index None: #Person2#가 #Person1#에게 가루, 안약, 연고의 사용법을 알려줍니다.
# Summary for index None: #Person1#은 #Person2#에게 새 차를 사고, 여자들을 만나러 다닐 것이라고 말한다. #Person2#는 그것이 멋지다고 생각한다.
# Summary for index None: #Person1#은 메뉴판을 요청하고 #Person2#에게 현지 특산물을 시도하고 싶다고 말합니다. #Person2#는 필레 스테이크를 추천하고 #Person1#은 그것을 두 개 주문합니다.
# Summary for index None: 왕 선생님은 에어컨이 작동하지 않는 방에서 다른 방으로 이동하고 싶어합니다. #Person1#은 그에게 다른 방을 제공합니다.
# Summary for index None: #Person2#는 #Person1#에게 영어 실력에 대해 이야기합니다. #Person2#는 CET-6을 통과했고, 영어 번역사로 일했던 경험이 있으며, TOEFL에서 600점, GRE에서 2,300점을 받았습니다.
# Summary for index None: #Person1#은 주문에 대한 견적을 원하지만 #Person2#은 주문량을 알아야 한다. #Person1#은 100개 주문에 대한 예상 금액을 알고 싶어하지만, #Person2#은 500개 이상 주문한다면 더 나은 가격을 제공할 수 있다.
# Summary for index None: 테리 첸이 하우스키퍼에게 방 청소를 요청한다.
# Summary for index None: #Person1#은 저렴한 비행기 표를 찾을 수 없어서 #Person2#에게 도움을 청하고, #Person2#는 #Person1#에게 인터넷을 시도하라고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 미국에서 구입한 신발과 같은 신발을 구매하고 싶어합니다. #Person2#는 그 신발이 유행이 아니라고 말합니다. #Person1#은 그 신발이 매우 불편해 보인다고 생각합니다.
# Summary for index None: #Person1#은 선물로 넥타이를 추천하지만 #Person2#는 그것이 지루하다고 생각한다. #Person2#는 딜버트 넥타이를 추천하고, #Person1#은 그것이 재미있다고 생각한다.
# Summary for index None: #Person1#은 #Person2#의 여권을 체크하고, #Person2#는 후지산 성 출신의 중국인입니다. #Person2#는 호주에 반 달 동안 머무를 계획입니다.
# Summary for index None: #Person1#은 #Person2#가 티셔츠를 선택하는 데 도움을 줍니다. #Person2#는 녹색이 좋지만 크기가 작아서, 핑크색을 선택합니다.
# Summary for index None: #Person2#는 신고 있는 신발을 대체할 신발을 사고 싶어합니다. #Person1#은 #Person2#에게 두 쌍을 추천하고, #Person2#는 두 쌍을 사기로 결정합니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#의 아들이 수업에 늦게 도착한다고 말합니다. #Person2#는 놀라워하고 그에게 벌을 줄 것입니다.
# Summary for index None: 브라운 부인이 #Person2#의 건강 상태를 확인하고, #Person2#가 감기에 걸렸다고 판단합니다. 그녀는 #Person2#에게 에어컨이 있는 사무실에서 일하는 것이 건강에 좋지 않다고 말하고, 산책을 하고 운동을 더 많이 하는 것을 제안합니다.
# Summary for index None: 데이비드는 수잔에게 그 자리를 떠났다고 말하고, 수잔은 댄서로서 매우 성공적이었다고 말한다. 데이비드는 댄스 학교를 열기로 결정한다.
# Summary for index None: #Person1#과 #Person2#는 서로의 교육 상황에 대해 이야기하고 있습니다. #Person2#는 PCC에 다니고 있습니다.
# Summary for index None: #Person1#은 어떤 차가 가장 적합한지 물어봅니다. #Person2#는 #Person1#에게 이 차를 추천하고, 그 이유는 이 차가 안전하고 경제적이기 때문입니다. #Person1#은 이 모델이 제가 찾고 있던 차일지도 모른다고 생각합니다.
# Summary for index None: #Person2#는 #Person1#에게 감사 업무에 참여한 경험에 대해 이야기하고, 감사관이 되기까지의 경험을 공유합니다.
# Summary for index None: #Person1#은 #Person2#에게 드레스를 보여주고, #Person2#는 그것이 너무 차려입은 것 같다고 생각한다. #Person3#는 편안하게 입을 수 있는 스타일을 선택하라고 조언한다.
# Summary for index None: #Person1#은 #Person2#의 서예를 칭찬하고, #Person2#는 #Person1#에게 나눠줍니다. #Person1#는 기쁩니다. #Person2#는 #Person1#에게 진정한 행운은 스스로 만들어야 한다고 말합니다.
# Summary for index None: #Person1#은 #Person2#에게 그들이 이혼했다고 말하고, 그들의 결혼이 불가피했다고 생각한다.
# Summary for index None: #Person1#은 엘리자베스에게 외국어 능력을 묻고, 엘리자베스는 프랑스어와 스페인어를 할 수 있다고 말합니다. #Person1#은 스페인어를 쓸 일이 없기 때문에 엘리자베스가 적합하다고 생각합니다.
# Summary for index None: #Person1#은 길을 잃어버렸고, 티켓 기계를 사용하는 법을 모르기 때문에 #Person2#에게 도움을 청합니다. #Person2#은 #Person1#에게 기차를 타고 과학박물관에 가는 방법을 알려줍니다.
# Summary for index None: #Person2#는 파티에 오는 사람들 명단을 가지고 있고, 그들에게 날짜를 비밀로 유지하라고 말했습니다. #Person1#은 #Person2#를 사무실에서 데리고 같이 갈 것입니다.
# Summary for index None: #Person1#은 우체국에 가고 싶어합니다. #Person2#는 #Person1#에게 가는 길을 알려주고, #Person1#은 택시를 탈 것입니다.
# Summary for index None: #Person1#은 #Person2#에게 캐나다 여행 계획을 말한다. #Person2#는 그것이 흥미롭다고 생각하고 #Person1#에게 즐거운 시간을 보내라고 말한다.
# Summary for index None: #Person1#은 #Person2#가 행복하지 않다고 생각하고, #Person2#는 그 이유가 부모님 때문이라고 말한다. #Person1#은 그들 사이에는 세대 차이가 있다고 생각한다.
# Summary for index None: 조는 #Person1#에게 그의 여행이 좋았다고 말하고, #Person1#에게 그의 아빠가 그를 데려가서 긴 차 여행을 했으며, 그들이 사용할 수 있는 편안한 침실이 충분했다고 말한다.
# Summary for index None: #Person2#는 스탠다드룸을 예약하고 싶어합니다. #Person1#은 #Person2#에게 요금과 예약 확인 번호를 알려줍니다.
# Summary for index None: #Person1#은 선물로 받은 너무 작은 장갑을 반품하려고 합니다. #Person2#은 교환을 제안하고, #Person1#은 더 비싼 장갑을 선택합니다.
# Summary for index None: #Person1#은 #Person2#에게 자동차 수리 과정에 대해 이야기합니다. #Person2#는 수업을 좋아하며, 오늘 이 과정에 등록하고 싶어합니다.
# Summary for index None: #Person1#은 #Person2#에게 업그레이드를 위해 회계 시스템을 오프라인으로 전환할 것이라고 말했고, #Person2#는 48시간 동안 여유롭게 잡아두었다.
# Summary for index None: #Person1#은 피부 상태를 위한 약이 필요하지만, 처방전이 만료되었습니다. #Person2#는 #Person1#이 처방전 없이 약을 구매하는 것이 불법이라고 말하고, #Person1#은 다른 의사를 찾아야 합니다.
# Summary for index None: #Person1#은 #Person2#에게 엄마와 직장인이라는 두 가지 역할을 어떻게 잘 수행하는지 물었습니다. #Person2#는 #Person1#에게 자신에게 친절해야 한다고 말했습니다. #Person2#의 남편은 #Person2#의 생각을 지지합니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#의 기술적 직위, 이에 대한 자격증, 그리고 #Person2#의 설계 중 하나에 대해 설명하도록 요청합니다.
# Summary for index None: #Person1#은 기차역으로 가고 싶어합니다. #Person2#는 #Person1#을 태우고 20분이 걸릴 것이라고 말합니다. #Person1#은 천천히 운전하라고 요청합니다.
# Summary for index None: #Person1#은 빨간 블라우스를 사고 싶어하지만 존은 파란색을 추천한다. #Person1#은 무지개 색깔을 원한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#의 취미에 대해 물어봅니다. #Person2#는 책 읽는 것을 좋아하고, #Person1#은 자는 것을 좋아합니다.
# Summary for index None: #Person1#은 베이징 출장을 가고 있고, #Person2#는 친구를 만나러 휴가를 가고 있습니다. #Person1#은 #Person2#에게 지하철이 너무 붐볐다고 말하고, #Person2#는 버스를 타거나 차를 빌릴 수도 있다고 제안합니다.
# Summary for index None: #Person1#은 아이린에게 어제 밤에 데이트한 남자에 대해 물어봅니다. 아이린은 그가 잘생겼고, 주니어 투자 은행원이라고 말합니다. #Person1#은 그가 #Person1#의 형이라는 것을 알게 됩니다.
# Summary for index None: #Person1#은 쇼 비즈니스 스타들이 쉬운 삶을 살고 있다고 생각하지만, #Person2#은 그들이 끔찍한 삶을 살고 있다고 생각한다. #Person1#은 그들이 그것을 좋아할 것이라고 생각하지만, #Person2#는 그들이 비용이 많이 든다고 생각한다.
# Summary for index None: #Person1#은 금요일 밤에 파티를 하자고 제안하지만, #Person2#는 집에 있기를 선호한다. 그들은 라틴 클럽과 New Bar 중 어디로 갈지에 대해 논쟁한다. #Person2#는 라틴 클럽에 가는 것에 동의한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#의 엄마와 아빠에 대해 이야기하고, #Person1#은 두 주 전에 그들과 이야기했다고 말한다. #Person1#은 크리스마스에 집에 가려고 계획하고, #Person1#은 엄마를 더 닮았다.
# Summary for index None: #Person1#은 샨이 파울을 저지르지 않았다고 생각하지만, #Person2#는 그것이 괜찮다고 생각한다. #Person1#은 심판이 샨의 워킹을 놓친 것에 화가 나지만, #Person2#는 그것이 멋진 슛이라고 생각한다.
# Summary for index None: 빌리는 #Person1#에게 ATM 카드를 사용하는 방법을 가르치고, #Person1#은 기계가 은행 직원보다 더 빠르다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 대통령이 직무에서 물러날 때까지 기다리고 있기 때문에 자신의 차를 가지고 있지만, 기름값이 내려갈 때까지 기다리고 있다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 특별한 메뉴를 추천하고, #Person2#는 그것을 주문한다.
# Summary for index None: #Person2#는 Sharp DVD 플레이어를 찾고 있지만, #Person1#는 그 모델이 모두 팔렸다고 말한다. #Person1#는 약 2주 후에 다시 입고할 것이라고 말한다.
# Summary for index None: #Person1#은 #Person2#의 VISA 카드가 거절되어 물건을 가져갈 수 없다. #Person2#는 내일 다시 올 것이다.
# Summary for index None: 마이크는 #Person2#에게 정기구독을 추천하지만 #Person2#는 관심이 없다. 마이크는 #Person2#가 요리 잡지를 좋아할 것이라고 생각하고, #Person2#는 두 가지 출판물을 구독한다.
# Summary for index None: #Person1#은 미국의 쇼핑몰이 크다는 것을 발견했고, #Person2#는 #Person1#에게 미국인들이 주말에 벼룩시장을 열어서 물건을 판다고 말했습니다.
# Summary for index None: #Person2#는 잠을 잘 못 자는 이유가 룸메이트들이 한국 드라마를 자정까지 보기 때문이라고 #Person1#에게 말한다. #Person1#는 #Person2#에게 방이 조용해져야 한다고 말하고, #Person2#는 동의한다. 둘 다 자신만의 공간이 필요하다고 생각한다.
# Summary for index None: #Person2#는 #Person1#에게 이번 화요일에 투표하러 갈 것이며, 후보를 선택했다고 말합니다. #Person1#는 #Person2#의 선택을 칭찬합니다.
# Summary for index None: #Person1#은 #Person2#에게 노트북을 구매하는 데 도움을 청하고, #Person2#는 #Person1#에게 맥을 추천하고, #Person1#은 그것을 구매하고 결제합니다.
# Summary for index None: #Person1#은 #Person2#에게 저녁 식사 때 냅킨을 어떻게 다루는지 묻는다. #Person2#는 #Person1#에게 알려준다.
# Summary for index None: #Person1#은 #Person2#에게 스키와 부츠를 빌리고 스키 강사를 찾는 데 도움을 청합니다.
# Summary for index None: #Person1#은 쇼핑 지구에 대해 묻고, #Person2#는 그곳에 있는 상점들과 극장들에 대해 설명합니다. #Person1#은 옷을 사고 싶어합니다.
# Summary for index None: #Person1#과 #Person2#는 서비스가 느리다고 불평하고, 그들은 2시에 있는 수업에 늦을 것 같다. 그들은 여름학교에 대해 이야기하고, 그들 모두 3주 더 머무르다가 다른 학교로 이동할 예정이다.
# Summary for index None: #Person2#는 #Person1#에게 새로운 직장에서 가장 좋아하는 것은 급여, 집과 회사 사이의 거리, 그리고 교육 프로그램이라고 말한다. #Person1#는 그것이 좋아 보인다고 생각한다.
# Summary for index None: 쟈니는 웬디에게 시내 광장이 놀이공원으로 바뀌는 소식을 전한다. 웬디는 이것이 좋다고 생각하지만, 쟈니는 광장이 더 좋다고 생각한다. 웬디는 놀이공원이 고용을 의미한다고 생각한다.
# Summary for index None: 미키는 아빠에게 맛있는 간식을 먹고 싶어한다. 아빠는 미키가 기다리는 것을 제안하고, 미키는 사탕을 원한다. 아빠는 미키가 시금치 샌드위치를 좋아한다는 것을 알게 되고, 준비하러 간다.
# Summary for index None: #Person1#은 #Person2#에게 비행기가 6시간 지연될 예정이라고 말하고, #Person2#는 터미널의 조용한 부분에서 낮잠을 자는 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#가 초록색 드레스를 찾는 데 도움을 준다. #Person2#는 드레스를 입어보고 사기로 결정한다.
# Summary for index None: #Person2#는 '바람과 함께 사라지다'를 찾고 있었고, #Person1#이 도와주었습니다. #Person2#는 하드커버를 사기로 결정했습니다.
# Summary for index None: #Person1#은 우산을 잊고 왔다. #Person2#는 #Person1#에게 우산을 빌려주고 같이 가자고 제안했다.
# Summary for index None: #Person2#는 #Person1#에게 문과 창문의 잠금을 확인하고 불을 껐다고 말합니다. #Person2#는 이웃에게 우리 집을 잘 살펴보라고 요청했습니다.
# Summary for index None: 메리는 #Person1#에게 앤과 큰 싸움을 했다고 말한다. 메리는 앤이 남자친구와의 약속 때문에 해변 여행을 취소했다고 생각하고, 그녀의 이기심을 비난했다. #Person1#은 그녀에게 더 이해해주는 것이 좋다고 말한다.
# Summary for index None: #Person2#는 #Person1#이 존과 함께 있었다는 사실을 알게 되어 울고 있다. #Person1#는 그것이 사실이 아니라고 말한다.
# Summary for index None: #Person1#은 리브에게 자신이 새로 입양한 고양이의 사진을 보여주고, 리브는 그 고양이가 정말 귀엽다고 생각한다.
# Summary for index None: #Person1#은 시계가 왼손잡이 사람들에게 불편하다고 생각하지만, #Person2#는 그것이 왼손잡이인 #Person2#에게 불편하다고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 로즈가 임신했다는 소식에 대해 이야기하고 있다. #Person1#은 로즈가 남자 아이를 원하는 이유를 설명하고, #Person2#는 여자 아이도 좋다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#의 친구가 남자친구를 차버렸다고 말하고, #Person2#를 저녁 식사에 초대한다. #Person2#는 도움을 주지 않았지만, #Person1#의 친구는 #Person2#가 #Person1#을 돕기 위해 #Person1#에게 자유를 준 것에 감사하다고 생각한다.
# Summary for index None: #Person1#은 수잔이 위암에 걸렸다고 #Person2#에게 말한다. #Person2#는 놀라고, #Person3#는 무슨 일이 있었나요? 라고 묻는다.
# Summary for index None: 베스는 #Person2#에게 엄마에게 전화하라고 제안하고, #Person2#는 그렇게 한다. 베스는 #Person2#에게 자신의 생일이 언제인지 묻고, #Person2#는 4월 2일이라고 대답한다. 베스는 #Person2#를 깨워서 동기를 부여하고, 그들은 10시쯤 수영하러 갈 예정이다.
# Summary for index None: #Person1#이 계산서에 대해 #Person2#에게 물어보고, #Person2#는 18달러로 수정했다.
# Summary for index None: #Person1#은 메리가 감기에 걸렸다는 것을 알고, 약을 먹고 충분히 쉬는 것을 권장한다.
# Summary for index None: #Person1#은 #Person2#에게 재미있는 농담을 하나 들려준다. #Person2#는 농담을 듣고 웃는다.
# Summary for index None: #Person1#은 #Person2#에게 도착한 데일 씨를 만나러 공항에 왔다고 말하고, #Person2#에게 #Person1#의 계획을 알립니다.
# Summary for index None: 앨리스는 버스를 놓쳐서 늦었고, 퇴근이 늦었기 때문에 미안해했다. 아담은 약간 화가 났지만, 결국 그녀가 여기에 있어서 기뻤다.
# Summary for index None: #Person2#는 손이 다쳐서 필기 속도가 느려졌다. #Person1#는 #Person2#에게 녹음기를 가져가서 강의를 녹음하라고 제안했다.
# Summary for index None: #Person1#은 학교 소풍 날인데, #Person1#의 알람이 울리지 않아서 늦을 것 같다. #Person1#의 엄마는 아직 샤워도 하지 않았고 옷도 입지 않았기 때문에 #Person1#을 데려다 줄 수 없다. 하지만 #Person1#의 엄마는 #Person1#을 #Person1#의 친구 빌리와 함께 데리고 가는 것을 제안한다.
# Summary for index None: #Person1#은 호텔 내에서 즐길 수 있는 장소를 물어봅니다. #Person2#는 산책, 레크리에이션 센터, 그리고 음악 다방을 추천합니다.
# Summary for index None: #Person1#은 #Person2#에게 3년 동안의 좋은 협력에 대해 감사하다. #Person1#은 #Person2#의 제품의 단독 대리점이 되고 싶어하고, #Person2#는 #Person1#에게 몇 가지 조건을 묻는다.
# Summary for index None: #Person1#은 #Person2#에게 가장 가까운 영화관에 대한 길을 물어봅니다. #Person2#는 친절하게 가는 방법을 알려줍니다.
# Summary for index None: 지나는 빌에게 헤이븐의 이메일을 보내줄 것이다. 빌은 그녀를 다시 찾고 싶어한다.
# Summary for index None: #Person1#과 #Person2#는 영화 등급에 대해 이야기하고 있습니다. #Person2#는 #Person1#에게 등급의 의미를 설명하고, #Person1#은 X 등급 영화를 본 적이 없다는 것을 기억합니다.
# Summary for index None: #Person1#은 4일 동안 욕조가 있는 조용한 방을 예약하고, #Person2#은 #Person1#에게 방을 보증하는 데 필요한 요금을 지불하라고 요청한다.
# Summary for index None: #Person2#는 배가 너무 아파서 #Person1#에게 도움을 청하고, #Person1#는 #Person2#를 즉시 응급실로 보낼 것이라고 결정했다.
# Summary for index None: #Person1#은 남부 캘리포니아 출신이기 때문에 대만의 추운 날씨에 익숙하지 않다. #Person2#는 #Person1#에게 따뜻한 옷을 좀 더 준비하라고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 해산물과 야채를 추천하고, #Person2#는 그것을 주문한다.
# Summary for index None: #Person1#은 크레이그에게 영어를 얼마나 오래 공부했는지 물어본다. 크레이그는 #Person1#에게 영어를 잘하지 못한다고 말하고, #Person1#은 그를 파티에 초대한다.
# Summary for index None: B씨는 프레드씨에게 일요일 신문을 읽는 이유를 말하고, 프레드씨는 B씨에게 와인을 마시는 것을 좋아한다고 말한다.
# Summary for index None: #Person1#과 #Person2#는 #Person1#의 친구에 대해 이야기하고, 그들은 그가 친절하지 않다고 느낀다.
# Summary for index None: #Person1#은 묵주를 받아들이지 않지만, #Person2#는 그녀가 받아야 한다고 주장합니다. #Person2#는 #Person1#에게 그의 할머니가 돼지를 키우는 것에 대해 불평하는 것을 좋아하지만, 그녀가 그들을 사랑한다고 말합니다.
# Summary for index None: #Person1#은 데드맨에게 엔진을 가동시키는 방법을 알려준다. 데드맨은 #Person1#에게 에스프레소의 이름이 어떻게 생겼는지 알려준다.
# Summary for index None: #Person1#과 #Person2#는 바빠서 야근을 해야하며, 그들의 급여는 그들에게 여행을 갈 수 있는 기회를 준다.
# Summary for index None: #Person1#은 캠퍼스 내에서 주택을 찾고 있습니다. #Person2#는 #Person1#을 위해 대기 목록에 올려주고, #Person1#은 몇몇 아파트를 보고 싶어합니다.
# Summary for index None: #Person1#과 #Person2#는 어제 밤에 케이트가 #Person1#에게 전화를 걸어서 새로운 남자친구에 대해 흥분했다는 것을 논의하고 있습니다.
# Summary for index None: #Person1#은 우주의 은하들이 우주를 이동하고 있는지 묻습니다. #Person2#는 은하들이 주변 공간에서 대체로 수동적으로 자리잡고 있다고 말합니다. #Person2#는 #Person1#에게 충돌이 어떻게 발생하는지에 대해 설명합니다.
# Summary for index None: #Person2#는 #Person1#에게 #Person2#의 외국인 남편과의 결혼 생활에 대해 이야기하고, 그들의 아들에 대해 이야기합니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#의 생일과 영화 시간을 묻습니다. #Person1#은 시간에 맞춰 갈 수 없다고 생각하고 내일 보기로 합니다.
# Summary for index None: #Person1#은 해리에게 오페라를 좋아하냐고 물었지만, 해리는 그것이 비싸고 다른 언어로 노래를 부르기 때문에 싫어한다.
# Summary for index None: #Person1#은 #Person2#에게 골프를 가르치고 있습니다. #Person2#는 #Person1#의 지시에 따라 공을 쳐서 목표를 달성합니다.
# Summary for index None: #Person1#은 메리가 처음 만난 날을 기억하고, 메리는 그것을 잊지 못한다. 그들은 그것에 대해 이야기하고 있다.
# Summary for index None: #Person2#는 #Person1#에게 하이랜드 호텔에서의 주말을 즐겼다고 말합니다. #Person2#는 방, 레스토랑, 서비스에 대해 이야기하고, 불만사항은 인터넷 접속에 문제가 있었을 뿐이라고 말합니다. #Person2#는 호텔의 팁 정책을 소개합니다.
# Summary for index None: #Person1#은 최첨단 노트북을 보고 싶어하고 #Person2#은 그것의 특징을 설명합니다. #Person1#은 그것이 대단하다고 생각하지만, 가격이 비싸다고 생각합니다.
# Summary for index None: #Person1#은 #Person2#에게 타임시트를 도와달라고 요청하고, #Person2#는 #Person1#에게 어떻게 채워야 하는지 알려준다.
# Summary for index None: #Person1#은 #Person2#에게 피프스 애비뉴에서 내렸어야 했다고 말한다. #Person2#는 걱정하지 않아도 된다.
# Summary for index None: #Person2#는 건강에 신경을 쓰고 있으며, #Person1#에게 당근 주스를 제공합니다. #Person1#는 수업에 늦을 것 같아서 달려가야 합니다.
# Summary for index None: #Person1#은 #Person2#에게 디저트를 추천하고, #Person2#는 친구들과 나눠 먹기 위해 사과 크리스프와 초콜릿 무스 케이크를 주문한다. #Person2#는 뜨거운 차를 선호한다.
# Summary for index None: #Person2#는 체력이 떨어져서 운동을 해야 한다고 생각합니다. #Person1#는 #Person2#에게 체력 상태에 따라 맞춤형 운동 계획을 제공하고, 이를 위해 1개월 멤버십을 구입하도록 권장합니다.
# Summary for index None: 파슨스 씨는 레베카에게 내일 최종 후보 인터뷰를 마무리하고 다음 주 초에 결정을 내리겠다고 말합니다. 레베카는 이에 동의하고 파슨스 씨에게 감사의 인사를 합니다.
# Summary for index None: #Person2#는 브루스 리처럼 되고 싶어합니다. #Person1#는 그것이 긴 여정이 될 것이라고 말하고, #Person2#에게 런닝머신이나 줄넘기를 시도하라고 제안합니다. #Person2#는 청바지를 입을 수 없어서 실망합니다.
# Summary for index None: 수잔이 브라운 씨에게 전화를 걸어 그의 아들이 수학여행을 놓쳤다고 말한다. 브라운 씨는 수잔에게 그 이유를 설명하고, 수잔은 그의 수면 습관을 바꾸라고 제안한다.
# Summary for index None: #Person1#은 존에게 졸업 후에 무엇을 할 것인지 묻는다. 존은 아빠처럼 정보 기술 분야에서 일하고 싶어한다. 존은 의학에 관심이 있고, #Person1#에게 그가 잘하는 과목에 대해 이야기한다.
# Summary for index None: #Person1#은 브래들리 씨가 예약한 싱글룸을 위해 키 카드를 발급해주고, 브래들리 씨는 출발 날짜를 제외한 모든 서류를 작성합니다.
# Summary for index None: #Person1#은 우편을 보내려고 하지만 길을 잃었습니다. #Person2#는 #Person1#에게 우편함이 있는 길을 알려주고, #Person1#은 #Person2#에게 감사합니다.
# Summary for index None: #Person1#은 리사 린치에게 일자리 창출이 증가하고 있다고 생각하는지 물어봅니다. 리사 린치는 긍정적인 보고서라고 생각하며, 모든 부문에서 고용이 이루어지고 있음을 볼 수 있다고 생각합니다.
# Summary for index None: #Person1#은 새 집의 인테리어에 중국 전통 요소를 추가하고 싶어합니다. #Person2#는 빨간색, 격자무늬, 그리고 중국 풍경화를 추천합니다. #Person1#은 벽을 다시 칠하고 새 소파를 사고 싶어합니다.
# Summary for index None: #Person2#는 #Person1#에게 찰리가 끝없이 음악을 듣고 #Person2#가 짜증났다고 말한다. #Person1#는 #Person2#에게 찰리와 이야기해 보라고 제안한다.
# Summary for index None: #Person1#은 톰에게 #Person1#이 줄리아와 결혼했다고 말한다. 톰은 축하한다. #Person1#은 톰에게 #Person1#이 줄리아와 함께 행복하다고 말한다.
# Summary for index None: #Person1#은 빌 게이츠의 집을 보았지만 그곳에서 살고 싶지 않다. #Person1#은 영국의 조용한 마을에 있는 작은 오두막집에서 살고 싶어한다. #Person1#은 오래된 집을 원래 상태로 복원하려고 한다.
# Summary for index None: #Person1#은 #Person2#에게 아침 식사를 도와주고, 토마토 주스, 크림 오브 위트, 베이컨, 계란, 버터 토스트를 주문하도록 도와줍니다.
# Summary for index None: #Person1#은 8인용 테이블을 원했지만, 모두 예약되어 있었습니다. #Person2#는 #Person1#에게 작은 테이블을 붙이는 데 도움을 주었습니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#의 상사가 성차별적이라고 말하고, 그가 #Person1#을 깔보는 태도로 대하기 때문에 #Person1#이 그를 신고할 것이라고 말한다. #Person2#는 #Person1#이 과장하고 있다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 새해에 금연을 하고 커밍아웃을 하기로 결정했다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 조랑 결혼했는지 물었지만, #Person2#는 #Person1#이 무슨 말을 하는지 모른다.
# Summary for index None: #Person2#는 차에서 이상한 소리가 나서 #Person1#에게 도움을 청합니다. #Person1#는 #Person2#에게 내일 아침에 차를 가져가라고 제안합니다.
# Summary for index None: #Person2#가 라 살바토레의 책에서 한 페이지가 빠져있는 것을 발견했습니다. #Person1#은 #Person2#에게 빠진 부분을 사진으로 찍어 업로드하라고 요청하고, 2일 내로 새 책을 보내줄 것입니다.
# Summary for index None: #Person1#과 #Person2#는 이번 해가 빨리 지나가고 있다는 것에 놀라고 있다. #Person2#는 #Person1#에게 자신이 생일 파티를 도울 것이라고 말하고, #Person1#는 그것이 꽤 멋진 직업이라고 생각한다.
# ROUGE Scores: {'rouge-1': 0.2832595624025616, 'rouge-2': 0.10517484977795644, 'rouge-l': 0.2745897879581135}

# %%
# dev_df에서 'summary'와 'predicted_summary' 열만 추출하여 CSV 파일로 저장
output_path = '/data/ephemeral/home/data/dev_predicted_summary.csv'

# 'summary'와 'predicted_summary' 열만 포함된 데이터프레임 생성
dev_predicted_df = dev_df[['summary','predicted_summary']]

# 데이터프레임을 CSV 파일로 저장
dev_predicted_df.to_csv(output_path, index=True)

# 저장 경로 출력
output_path
# Out:
# '/data/ephemeral/home/data/dev_predicted_summary.csv'

# %%
# 요약 생성
submission_df = submission_df.merge(test_df[['fname', 'dialogue']], on='fname', how='left')
submission_df['summary'] = submission_df['dialogue'].apply(summarize_with_gpt)

# 결과 저장
submission_df = submission_df[['fname', 'summary']]  # 필요한 열만 남김
submission_df.to_csv('/data/ephemeral/home/GPT_finetuned_1128_3.csv', index=True)
print("Submission file created: GPT_finetuned_1128_3.csv")
# Out:
# Summary for index None: #Person1#은 더슨 씨에게 즉시 효력을 발휘하여 모든 직원에게 내부 메모를 배포하도록 요청합니다. 이 메모는 근무 시간 동안 즉시 메시지 사용을 금지합니다.
# Summary for index None: #Person2#가 교통 체증 때문에 늦었다. #Person1#은 #Person2#에게 대중교통을 이용하고, 날씨가 좋을 때는 자전거를 타는 것을 제안한다.
# Summary for index None: #Person1#은 케이트에게 마샤와 히어로가 이혼하려고 한다고 말한다. 케이트는 놀라워하고 그들이 잘 어울린다고 생각했다.
# Summary for index None: #Person1#은 브라이언의 생일을 축하하고, 브라이언은 #Person1#이 기쁨을 느끼는 것을 바란다. 그들은 서로 칭찬한다.
# Summary for index None: #Person1#과 #Person2#는 올림픽 공원을 방문하고 있습니다. #Person2#는 #Person1#에게 올림픽 공원의 정보를 알려줍니다.
# Summary for index None: #Person1#은 회사에서의 일에 짜증이 나서 사업 계획서를 작성하고 투자자를 모집하려고 결정한다. #Person2#는 #Person1#에게 사업 계획서 작성에 대해 조언한다.
# Summary for index None: #Person1#은 #Person2#가 수두에 걸렸다고 생각한다. #Person2#는 의사를 만나기 전에는 확신하지 못한다.
# Summary for index None: #Person1#는 #Person2#에게 청구서를 주지만, #Person2#는 11월 20일에 이용한 세탁 서비스 비용이 다른 사람의 것이라고 말합니다. #Person1#는 죄송하게 생각하고 수정합니다.
# Summary for index None: #Person1#은 스티븐에게 #Person1#의 아내가 #Person1#의 불륜을 발견했고 이혼하려고 한다고 말합니다.
# Summary for index None: #Person2#는 #Person1#에게 에이브러햄 링컨이 건전한 성격을 지닌 남자라고 말합니다.
# Summary for index None: #Person1#은 #Person1#의 친구에게 허베이가 모래폭풍으로 인해 위험하다고 말합니다. 이에 #Person1#의 친구는 동의합니다.
# Summary for index None: #Person2#는 #Person1#의 생일 파티에 와서 리모컨 자동차 모델을 선물합니다. #Person1#은 그것을 좋아합니다.
# Summary for index None: 토니는 스티븐에게 부정행위를 하다 걸려 실패했다고 말한다. 스티븐은 토니에게 열심히 공부하라고 조언한다.
# Summary for index None: #Person1#은 아홉시 반 기차를 타야 하기 때문에 서둘러야 하지만, #Person2#은 기차역이 가까워서 걱정하지 않는다.
# Summary for index None: #Person1#은 #Person2#에게 삶을 어떻게 조정해야 할지 물어봅니다. #Person2#는 충분한 수면을 취하고, 와인을 적게 마시고, 매일 아침 운동하는 것을 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 루오지아의 결혼 파티에 초대받았다고 말하고, #Person2#는 차 세트를 사야 한다고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 적들을 쏘고 그것이 재미있다고 생각하지만, #Person2#는 그것이 잔인하다고 생각한다.
# Summary for index None: #Person1#은 마이크에게 누나에 대해 묻는다. 마이크는 누나와 자신을 비교한다.
# Summary for index None: #Person1#이 머리가 아플 때 #Person2#가 #Person1#의 체온을 잰다.
# Summary for index None: #Person2#는 카메라와 MP3 플레이어가 있는 휴대폰을 사고 싶어합니다.
# Summary for index None: 프랭크는 주디에게 그가 우체국에서 일하게 되었고, 정부는 그에게 훌륭한 건강보험 혜택을 제공한다고 말한다.
# Summary for index None: #Person2#는 #Person1#에게 #Person2#의 기술, 자격증, 교육, 그리고 경험에 대해 설명합니다.
# Summary for index None: #Person1#은 요청한 미디엄 레어 스테이크가 너무 익혀져 있어서 #Person2#에게 바꿔달라고 요청합니다.
# Summary for index None: #Person1#은 톰에게 그의 소설이 노벨상을 받았다고 말하고, 톰은 그것에 대해 놀라워하고 기뻐한다.
# Summary for index None: #Person2#는 #Person1#에게 이 일을 잘 할 수 있을 것이라고 말한다. #Person2#는 자동차 디자인을 전공하고, 과학 석사 학위를 받았다.
# Summary for index None: #Person2#는 술을 많이 마시고 시간이 지나면 내성이 생긴다고 #Person1#에게 말한다. #Person1#는 연습 중이다. #Person2#는 내일 밤에 같이 나가자고 제안한다.
# Summary for index None: 엄마는 메이에게 피크닉 준비를 도와달라고 요청하고, 메이는 모든 것을 거실로 가져갈 것이다.
# Summary for index None: 제임스와 뮤리엘은 새로운 계정에 대해 이야기하려고 만납니다. 그들은 휴가에 대해 이야기하고, 제임스는 수잔을 소개하러 갑니다.
# Summary for index None: #Person1#은 ATM에서 10000 달러를 인출하려고 시도하지만, 기계는 그 돈을 세계 야생동물 기금에 이체한다. #Person1#은 화가 나서 #Person2#를 비난한다.
# Summary for index None: #Person1#은 #Person2#에게 동료들과 소통하는 전략을 묻는다. #Person2#는 소통에서 가장 중요한 것은 진심이라고 답한다.
# Summary for index None: #Person1#은 폴리 씨에게 탄산 음료 한 병을 사는 데 도움을 주지만, #Person2#는 지갑에 달러가 네 개밖에 없어서 한 병만 살 수 있습니다.
# Summary for index None: 모니카가 프란시스에게 전화를 걸어 재무 보고서를 작업하는 시간을 물어본다. 그들은 금요일 오후에 만날 예정이다.
# Summary for index None: #Person1#은 #Person2#의 면접 수업에 참석하고 있습니다. #Person2#는 면접에서 도움이 될 것들을 배우고 있습니다.
# Summary for index None: #Person1#은 마이크에게 그가 더 많은 분노를 느끼고 싶어한다고 말하고, 그가 그의 진짜 감정을 보여줄 것이라고 말한다.
# Summary for index None: #Person1#은 토드 부인에게 인사를 나누고 싶다는 제인의 요청을 전달하러 왔다.
# Summary for index None: 빌은 피곤하다. 그는 일에 바빠서 집에 가서 쉬어야 한다. 그의 동생은 미국에 있고, 빌은 5시에 친구를 만날 예정이다.
# Summary for index None: 사이먼은 핵무기 확산을 막기 위한 시위에 가자고 클레오에게 제안하지만, 클레오는 시위를 싫어하고 물리학 시험을 공부할 계획이다.
# Summary for index None: #Person1#은 #Person2#에게 일부는 자신의 잘못이라고 말하며, #Person2#는 예상하지 못한 사람을 절대로 들여보내면 안 된다고 말합니다.
# Summary for index None: 마크는 매기에게 역사 과목 노트를 빌리고자 한다. 그는 매기에게 자신이 매일 저녁에 일하기 때문에 노트가 필요하다고 말한다. 그들은 공부 파트너가 된다.
# Summary for index None: #Person2#는 터너 교수님에게 고급 지질학 과목을 다시 듣고 싶어하고, 그 이유를 설명합니다. 터너 교수님은 #Person2#에게 등록을 허락합니다.
# Summary for index None: #Person1#은 방금 전에 펜던트를 구입했지만, 펜던트가 부러졌습니다. #Person2#는 교체해줄 것입니다.
# Summary for index None: #Person1#와 #Person2#는 선물을 중심으로 옷에 대해 이야기하고 있다. #Person2#는 경기를 보고 싶어하며 #Person1#는 #Person2#의 팀이 항상 진다는 것을 비웃는다.
# Summary for index None: #Person2#는 미디어 쪽에서 일하고 싶어하며, #Person1#은 TV 뉴스 디렉터나 잡지를 위해 글을 쓰는 것을 제안하지만 #Person2#는 인터랙티브 미디어를 선호한다.
# Summary for index None: #Person1#은 #Person2#에게 지루함을 참아야 하고 #Person2#는 십자말풀이를 하면서 #Person1#은 집중해야 한다.
# Summary for index None: #Person1#은 사라에게 남편과 함께 더 저렴한 집을 찾기 위해 도심에서 멀리 떨어진 곳에 집을 사는 것을 제안한다.
# Summary for index None: #Person1#은 런던의 정보 담당관 마크 리치를 인터뷰하고, 그는 브리튼 비즈니스 센터의 정보 담당관입니다.
# Summary for index None: 루시와 린팡은 영어가 그들의 가장 좋아하는 과목이라는 점에서 공감하지만, 그들은 두 번째로 좋아하는 과목에 대해 다른 의견을 가지고 있다.
# Summary for index None: 제임스가 토마스 부인에게 토마스 부인의 개 오스카를 산책시키고, 집안일을 돌보는 것을 도와줍니다. 토마스 부인은 제임스에게 주말에도 일해줘서 감사합니다.
# Summary for index None: #Person1#은 봄이 왔지만 밤에는 여전히 춥다. #Person1#은 고양이처럼 햇살을 쬐며 앉아 있어야 한다.
# Summary for index None: #Person1#은 마이크에게 그녀가 마이크를 더 이상 보고 싶지 않다고 말하고 있지만, 마이크는 이것이 그의 캐릭터와 일치하지 않는다고 생각한다.
# Summary for index None: #Person1#은 중요한 일이 있어서 택시를 타고 프렌드십 호텔로 가야 합니다. #Person2#는 빠르게 #Person1#을 목적지로 데려갑니다.
# Summary for index None: #Person1#은 #Person2#에게 돈이 없어서 다른 버스를 타야 한다고 말한다. #Person2#는 #Person1#에게 버스 기사에게 환승을 요청하라고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 시내까지의 거리, 동네의 회사, 그리고 직원 식당에 대해 묻습니다.
# Summary for index None: #Person1#은 #Person2#에게 루루와 빅이 헤어졌다고 말한다.
# Summary for index None: 데이브는 짐과 통화하려고 전화를 걸었지만, 샐리는 짐이 아직 돌아오지 않았다고 말했다.
# Summary for index None: #Person2#는 #Person1#에게 시청으로 가는 방법을 알려줍니다. #Person1#은 처음에 이해하지 못했지만, 두 번째로는 이해합니다.
# Summary for index None: #Person1#은 여행 중에 여권을 분실한 것 같다. #Person2#은 분실물 신고서를 작성하는 데 도움을 주고, #Person1#은 대사관에 연락해야 한다.
# Summary for index None: 레아는 나다니엘에게 콜린스 선생님이 전화를 받지 못할 것이라고 말하고, 다른 사람과의 약속을 잡기 위해 전화를 걸라고 요청합니다.
# Summary for index None: #Person1#은 #Person2#에게 그녀가 딕 이외의 남자와 결혼하지 않겠다고 말했을 때, #Person1#의 마음은 거의 입으로 나올 뻔했다고 말한다.
# Summary for index None: #Person1#은 금발의 여자를 추천하지만, #Person2#는 긴장하고 말을 잘못해서 #Person1#은 #Person2#에게 조금 서둘러야 한다고 말한다.
# Summary for index None: 잭은 #Person1#에게 정치학 수업이 좋았지만, 작년에 들었던 비즈니스 커뮤니케이션 수업이 더 좋았다고 말한다.
# Summary for index None: #Person1#과 #Person2#는 날씨에 대해 이야기합니다. 베이징의 가을은 아름답지만, 여름은 너무 덥습니다.
# Summary for index None: #Person1#과 #Person2#는 오늘 밤에 영화를 보러 가려고합니다. #Person2#는 전쟁 영화를 보고 싶어합니다. #Person1#은 놀랍습니다.
# Summary for index None: #Person1#이 학교를 아담에게 소개하고, #Person1#은 언젠가 학교에 입학하고 싶어한다. 아담은 #Person1#의 꿈을 응원한다.
# Summary for index None: #Person1#은 #Person2#에게 임신하고 있으며 아빠가 될 것이라고 말한다. #Person2#는 그것이 정말 기쁘다.
# Summary for index None: 존이 일주일에 그녀와 일곱 번이나 만나고 그들은 서로 잘 어울린다고 생각합니다.
# Summary for index None: #Person2#는 시스템 업그레이드에 대해 생각하고 있습니다. #Person1#은 #Person2#에게 무엇을 고려해야 하는지 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#가 어디로 가는지, 어디서 왔는지, 그리고 몇 살인지 묻습니다. #Person2#와 #Person1#은 서로에게 관심을 가지고 있습니다.
# Summary for index None: #Person1#은 체중 증가를 우려하며, #Person2#는 #Person1#에게 식단 조절을 하고 운동을 해보라고 제안한다.
# Summary for index None: 제임스는 8명을 위한 룸을 예약했지만, #Person1#은 그들에게 창가 테이블을 제안합니다. 제임스는 그것을 거절합니다.
# Summary for index None: #Person1#은 #Person2#에게 공장이 얼마나 크고, 언제 설립되었으며, 그 안에 몇 명의 직원이 있는지 물어봅니다.
# Summary for index None: 레베카는 #Person1#에게 대학 졸업 후 첫 직장은 지역 신문사였고, 그 후에는 런던에서 일했다고 말한다.
# Summary for index None: #Person1#과 #Person2#는 내일의 그룹 발표를 위해 문구점에 가서 포스터를 만들기 위한 물건을 사야 합니다.
# Summary for index None: #Person1#은 메리에게 인터넷에서 일자리를 찾는 것이 편리하다고 말하고, 메리는 시도해 볼 것이다.
# Summary for index None: #Person2#는 쇼핑 예산을 만들고 있고, #Person1#은 #Person2#의 예산 계획이 좋다고 생각합니다.
# Summary for index None: 헨리는 제인에게 13번 버스가 병원에 갈 수 있지만, 시내 중심에서 출발하기 때문에 걸어가야 한다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 내년 판매 예측에 대해 이야기하고 싶어 한다. #Person2#는 다음 주 화요일 오후 2시 30분에 만나기로 합의했다.
# Summary for index None: #Person2#는 #Person1#에게 '뉴욕의 친구'라는 개인 투어 가이드 서비스를 추천합니다.
# Summary for index None: #Person1#은 #Person2#에게 회사에 대해 묻고, #Person2#는 영업 부서에서 일하고 싶어하며, 월 2,000 위안을 벌고 있습니다. #Person1#은 #Person2#에게 회사에서의 급여와 복리후생 혜택을 알려줍니다.
# Summary for index None: #Person1#은 계약서를 서명하러 왔지만, 계약서가 완전히 준비되지 않았다. #Person2#는 수정이 필요한 부분을 확인하고 계약서를 만들 예정이다.
# Summary for index None: #Person1#은 ABC 렌트카 회사에 전화를 걸어 차량 사고가 났다고 말한다. #Person1#은 #Person2#에게 구급차와 경찰을 불러달라고 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 학교 클리닉으로 가는 길을 물었다. #Person2#는 #Person1#에게 알려준다.
# Summary for index None: #Person2#는 방의 소음 때문에 더 이상 참을 수 없어서 #Person1#에게 방을 바꾸어 달라고 요청합니다. #Person1#은 내일 여분의 방이 생길 것이라고 말합니다.
# Summary for index None: #Person1#는 #Person2#를 베이징 호텔로 데려가고, #Person2#의 호텔 체험과 저녁 식사에 대해 이야기합니다.
# Summary for index None: #Person1#은 길을 잃었고, #Person2#는 #Person1#에게 지도를 보여줍니다. #Person1#은 리우 이창으로 가야 하고, #Person2#는 버스 713번을 타라고 제안합니다.
# Summary for index None: #Person1#과 #Person2#는 컴퓨터가 작동하지 않아서, #Person1#은 컴퓨터 수리공에게 전화할 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#가 어머니에게 선물로 줄 수 있는 시계를 추천합니다. #Person2#는 그 시계가 좋다고 생각하며, #Person1#은 어머니께서 그것을 좋아하실 것이라고 확신합니다.
# Summary for index None: 피셔 씨와 로스 씨가 10월 24일 토요일에 열리는 발표 준비를 위해 만나서, 시간, 날짜, 비용, 장비, 그리고 초대장을 토대로 방의 수용 인원을 결정합니다.
# Summary for index None: #Person1#과 #Person2#는 러시아와 캐나다의 주요 차이점에 대해 이야기합니다. #Person2#는 캐나다에서 모든 것이 더 빠르게 진행된다고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 카리브해로의 여행을 계획하고 있지만, #Person1#은 그곳의 날씨가 가끔 안 좋을 수 있다고 말한다.
# Summary for index None: #Person1#은 엄마에게 소풍에 가져갈 과일을 요청하고, 엄마는 #Person1#에게 바나나와 포도를 가져가라고 말합니다.
# Summary for index None: #Person1#은 소형차를 빌리고 싶어하고, #Person2#은 #Person1#에게 양식을 작성하라고 요청합니다.
# Summary for index None: #Person1#은 엘리베이터에서 미소를 짓는 사람들을 질렸습니다. #Person2#는 #Person1#이 그들을 좋아하지 않기 때문이라고 생각합니다.
# Summary for index None: #Person1#과 #Person2#는 지난해 판매 정보에 대해 이야기하고 있습니다. 그들은 회사의 성과가 향상되었다는 것에 동의합니다.
# Summary for index None: #Person2#는 가방을 잃어버렸고, #Person1#에게 돈을 빌리기 위해 50달러를 빌렸다. #Person1#은 #Person2#를 집에 데려다줄 것이다.
# Summary for index None: 린이 해외에서 먹은 가장 화려한 식사를 스티븐에게 대접하고, 스티븐은 중국의 팁 시스템을 묻는다.
# Summary for index None: 빌은 #Person1#에게 오늘 그의 룸메이트가 브레인 로커를 알고 있었고, 그가 오늘 이사했다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 지불하고 싶어서 청구서를 내놓습니다. #Person2#는 #Person1#이 660달러를 지불하도록 도와줍니다.
# Summary for index None: 캐롤이 수잔에게 전화를 걸었지만 #Person1#이 전화를 받았다. #Person1#은 캐롤이 파티에 초대하고 싶어한다.
# Summary for index None: #Person1#은 #Person2#를 만나서 이전에 어디에서 일하던 사람인지 물어봅니다. #Person2#는 #Person1#이 다른 사람과 혼동하고 있다고 생각합니다.
# Summary for index None: #Person1#은 트럼프가 올바른 사람이 아니라고 생각하며, 바이든에게 투표할 것이다. #Person2#는 트럼프를 믿고 그에게 투표했다.
# Summary for index None: #Person1#은 ATM을 사용하는 방법을 모릅니다. #Person2#가 알려줍니다.
# Summary for index None: 수잔은 존에게 사무 절차에 대한 메모에 대해 묻는다. 존은 그것을 기억하지 못한다.
# Summary for index None: #Person1#은 릴리에게 이번 주말에 함께 소풍을 가자고 제안하고, 무엇을 가져가야 하는지 묻는다.
# Summary for index None: #Person2#은 베이징 사람들의 따뜻함과 환대로 인해 중국의 연회에 초대받은 적이 있습니다. #Person2#은 #Person1#에게 중국 식사 도구에 익숙해지는 것이 어렵지 않지만, 중국 식사 자리에서 어떻게 적절하게 행동해야 하는지에 대해선 아직도 애매모호하다고 말합니다.
# Summary for index None: 프랭크는 메리에게 영화를 보는 것을 좋아한다고 말한다. 메리는 예술 영화를 좋아하고, 그들은 둘 다 무비 살롱을 좋아한다.
# Summary for index None: #Person2#는 녹색당에 가입하는 것을 생각하고 있지만, #Person1#는 녹색당이 선거에서 이길 가능성이 없다고 생각합니다.
# Summary for index None: #Person1#은 윌슨 씨에게 상품에서의 실수에 대해 사과하고, 오늘과 같은 일이 다시는 일어나지 않을 것이라고 약속합니다.
# Summary for index None: #Person1#은 #Person2#에게 강도에 대해 추가 질문을 하고 경찰서로 오라고 요청합니다.
# Summary for index None: #Person1#은 #Person2#에게 데이트를 위해 나가는 아빠와 엄마를 놀라워하며, 피자를 주문하자고 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 다이어트를 시작한다고 말한다. #Person2#는 #Person1#이 이전에도 그랬다고 생각하지만, #Person1#은 이번에는 다르다고 믿는다.
# Summary for index None: #Person2#는 비교문학 287 수업에 등록하려고 시도했지만 컴퓨터에서 안 돼서 학과 사무실에 왔습니다. #Person1#은 비교문학 학생들을 위해 추가 자리를 남겨두었다는 것을 알려줍니다.
# Summary for index None: #Person2#는 #Person1#에게 지금 시간을 알려줍니다. #Person1#는 우산을 깜빡하고 왔고, #Person2#는 함께 걸어가는 것을 제안합니다.
# Summary for index None: 잭이 데이지에게 자신의 새 차를 보여주고 그것이 얼마나 좋은지 데이지에게 보여줍니다.
# Summary for index None: #Person1#은 #Person2#에게 정확한 시간을 묻습니다. #Person2#는 10시쯤이라고 대답합니다.
# Summary for index None: #Person1#은 #Person2#가 905위안을 지불하려 했지만 900위안으로는 충분하지 않았다. 그래서 #Person1#의 남편이 신용카드로 결제했다.
# Summary for index None: #Person1#은 #Person2#에게 차량의 외부와 내부를 모두 세차하는 일반 세차 패키지를 추천하고 #Person2#는 동의한다.
# Summary for index None: 해리는 #Person1#에게 그와 그의 아내가 해외로 여행을 가고 싶어한다고 말합니다. 하지만 그의 아내는 항상 걱정을 합니다.
# Summary for index None: #Person1#은 신규 회원이다. 존슨은 #Person1#에게 기계를 사용하는 방법을 알려주고, #Person1#은 몇 개의 기계를 힘들어하며 그만두는 것을 결정한다.
# Summary for index None: #Person1#과 #Person2#는 일자리를 잃었고 #Person2#가 #Person1#에게 전기기사 프로그램을 추천했다.
# Summary for index None: #Person1#은 #Person2#에게 강아지에게 밥을 주고 목욕을 시키고 동물병원에 예약하라고 요청합니다.
# Summary for index None: #Person1#이 에이든에게 200달러를 빌리고 싶지만, 에이든은 20달러밖에 주지 못한다. #Person1#은 월요일에 갚을 것이다.
# Summary for index None: #Person2#는 #Person1#에게 자선 단체에서 일하며 사랑, 동정, 평등 등을 배웠다고 말합니다.
# Summary for index None: #Person1#은 한 주 안에 결정을 내릴 것이고, #Person2#는 그녀에게 전화나 이메일로 연락하라고 요청한다.
# Summary for index None: #Person2#는 무탄과 베이징 오리구이를 주문하도록 #Person1#에게 추천합니다.
# Summary for index None: 안젤라는 댄에게 전화를 걸었지만, 댄은 샤워 중이었기 때문에 전화를 받지 못했다. 댄은 결혼식에 가기 위해 초대되었고, 메건도 초대되었다.
# Summary for index None: #Person1#과 #Person2#는 디저트를 먹고 있습니다. #Person2#는 그리스 요구르트를 추천하고 #Person1#는 티라미수를 추천합니다. #Person2#는 티라미수를 좋아하고 바나나 튀김을 시키기로 결정합니다.
# Summary for index None: #Person1#은 스미스 씨에게 스미스 씨의 대학, 학문, 나이, 그리고 지난 은행에서의 연봉에 대해 묻는다.
# Summary for index None: #Person1#은 #Person2#의 도움으로 조카를 위해 디지털 바비를 $32.42에 구매했다.
# Summary for index None: #Person2#는 조던 스포츠 신발을 사고 싶어합니다. #Person1#은 제품을 보여주고 가격을 말합니다.
# Summary for index None: #Person1#은 티켓 기계를 사용하여 과학 박물관에 가는 기차표를 샀다. #Person2#는 #Person1#에게 기차를 어떻게 타고 내려야 하는지 알려주었다.
# Summary for index None: 사이먼은 #Person1#에게 단계적 은퇴 프로그램에 참여하고 있으며, 회사는 임시 직원 대신 은퇴한 직원들이 접근할 수 있는 웹사이트에 채용 공고를 올린다고 말합니다.
# Summary for index None: #Person1#은 로키에게 춤추러 나가는 여자를 찾아보라고 권장하지만, 로키는 집에서 요리하고 청소하며 아이들을 돌보는 여자를 선호한다.
# Summary for index None: #Person1#은 #Person2#에게 어제 밤의 폭풍이 얼마나 심했는지 묻고, 봄 날씨에 대해 불평합니다.
# Summary for index None: #Person1#은 #Person2#가 TV를 보는 것을 즐기지 않기 때문에 불만스럽다. #Person2#는 음악을 함께 나눌 수 있다고 제안한다.
# Summary for index None: 벤은 학교 생활에 대해 걱정하고 있지만, #Person1#은 그에게 편안하게 생각하라고 조언한다.
# Summary for index None: 애덤의 무릎이 나아졌다. #Person1#은 그에게 무릎을 쉬게 하라고 제안하고, 미시간의 경기 영상을 보라고 하며, 미시간은 강한 팀이라고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 프린터가 고장났기 때문에 복사본을 출력해달라고 요청한다.
# Summary for index None: #Person1#은 커튼을 걸고 싶어하고 #Person2#에게 도움을 청합니다.
# Summary for index None: #Person1#은 잭에게 주말 캠핑 여행을 위해 일정을 확인해달라고 요청한다.
# Summary for index None: #Person1#은 #Person2#를 용서하고, #Person2#는 북쪽에서의 산불로 인해 #Person1#에게 전화를 걸지 못했다고 말한다. #Person1#은 임신하였고, #Person2#는 아빠가 되고 싶어한다. 그런 다음, 그들은 병원에 가서 검사를 받는다.
# Summary for index None: #Person2#는 #Person1#에게 #Person2#의 딸이 대학을 결정하지 못해 걱정스러워하고 있다고 말한다.
# Summary for index None: #Person1#은 직장을 잃으면 어떻게 살아갈지 모릅니다. #Person2#는 #Person1#에게 돈을 절약하면서 살고, 직장을 잃으면 #Person2#와 함께 살 수 있다고 제안합니다.
# Summary for index None: #Person2#는 #Person1#에게 에든버러 대학교의 박사과정 학생이며 멀티모달 텍스트 생성에 대한 강연을 할 것이라고 말한다.
# Summary for index None: #Person2#는 존의 집에 가지 않고 집에서 쉬는 것을 선호하지만, #Person1#은 #Person2#가 따뜻하게 지내도록 도와줄 것입니다.
# Summary for index None: 파버 씨는 요크 호텔에 전화하여 3박 동안 더블 룸을 예약합니다.
# Summary for index None: #Person2#는 #Person1#에게 웨스트 더비를 추천하지만, 여기에는 대부분 큰 집들이 있습니다. #Person1#은 연립 주택에만 관심이 있습니다. #Person2#는 #Person1#에게 존 고드프리에게 전화하라고 제안합니다.
# Summary for index None: #Person1#은 모든 것이 #Person2#의 잘못이라고 생각하고, #Person2#는 #Person1#이 계속해서 모든 잘못을 #Person2#에게 돌리고 있다고 생각한다.
# Summary for index None: 달린이 댄에게 전화하여 100대의 컴퓨터가 2일이나 지연되었으며, 스티브에게 이 사실을 알리고 싶어한다.
# Summary for index None: #Person1#과 #Person2#는 워싱턴 포스트, 뉴욕 타임즈, 로스앤젤레스 타임즈의 창립일을 비교하고 있다.
# Summary for index None: #Person2#는 이메일을 보낼 수 없다. #Person1#이 컴퓨터를 확인하자, 첨부파일이 너무 크다는 것을 발견한다.
# Summary for index None: #Person2#는 #Person1#에게 주말에 #Person1#를 초대해줘서 감사하다고 말합니다.
# Summary for index None: #Person1#은 뭘 먹을지 결정하지 못했다. #Person2#는 중국 음식을 추천하고 판다 익스프레스에서 음식을 사오라고 제안했다.
# Summary for index None: 메리는 톰에게 판매 직원 자리를 다른 사람에게 제공하기로 결정했다는 것을 알려줍니다.
# Summary for index None: #Person1#이 #Person2#에게 전화하지만 #Person2#는 전화를 받지 않는다. #Person1#은 #Person2#에게 경찰에 신고할 것이라고 경고한다.
# Summary for index None: #Person2#는 #Person1#에게 음악 선생님이 되고 싶은 이유와 음악에 대한 #Person2#의 선호도에 대해 이야기합니다. #Person2#는 클래식 음악을 듣는 것이 스트레스를 줄이는 데 도움이 된다고 생각합니다.
# Summary for index None: #Person2#는 #Person1#에게 #Person2#의 아래층에 사는 싱글인 미국 여성을 만났다고 말한다. #Person2#는 그녀를 저녁 식사에 초대할 계획이다.
# Summary for index None: #Person1#은 #Person2#에게 미렐라가 회사에 청바지와 추리닝 상의를 입고 출근했고, 이것이 캘리포니아의 일하는 방식에 영향을 받았다고 말했다.
# Summary for index None: #Person2#는 자신만의 법률 사무소를 세우려 하고 있다. #Person1#은 #Person2#에게 새로운 도전에서 모든 성공을 기원한다.
# Summary for index None: 피터는 케이트에게 어젯밤에 밤새도록 온라인에 있었고, 지금 휴식이 필요하다고 말했다.
# Summary for index None: #Person1#과 #Person2#는 배와 보트가 교통수단으로 중요하지 않다는 것에 동의하며, 이에 대한 이유를 설명합니다.
# Summary for index None: 패니는 앤디에게 어젯밤에 무서운 악몽을 꿨다고 말하고, 앤디는 그녀가 좋은 어머니를 가졌다고 생각한다.
# Summary for index None: #Person1#은 어니에게 함께 밴드를 시작하자고 제안하고, 그들이 어떤 종류의 음악을 연주할지에 대해 이야기한다.
# Summary for index None: #Person1#은 뉴올리언스에서 무엇을 할지 모르고 #Person2#에게 여러 옵션을 제안합니다. #Person2#는 극장을 가는 것에 동의합니다.
# Summary for index None: #Person1#은 #Person2#의 도움으로 쇼핑을 하고 #Person2#는 #Person1#에게 안녕히 가세요라고 인사합니다.
# Summary for index None: #Person1#은 블레이크에게 포스터가 훈련 매뉴얼을 원한다고 전화했다고 말하고, 블레이크는 내일 오후에 두기로 약속했다.
# Summary for index None: #Person2#는 휴가 동안 롱아일랜드로 가서 형의 40번째 생일을 축하하고, 관광을 즐길 예정이다. #Person1#은 그 휴가가 즐거울 것이라고 느낀다.
# Summary for index None: #Person2#는 #Person1#의 비행기가 떠나야 한다고 주장하지만, #Person1#은 파멜라를 돌봐달라고 #Person2#에게 부탁합니다. #Person1#은 #Person2#에게 감사하며 #Person2#를 진정한 친구로 생각합니다.
# Summary for index None: #Person1#은 #Person2#에게 이 도시의 가장 붐비는 거리를 묻습니다. #Person2#는 77번 거리를 추천하고 12번 버스를 타라고 제안합니다.
# Summary for index None: #Person1#은 이슬람에 대한 프로그램을 보고 있습니다. #Person2#는 #Person1#에게 무슬림들이 메카로 순례를 하러 가는 이유에 대해 이야기합니다.
# Summary for index None: #Person1#은 길을 잃었고, #Person2#는 그에게 센트럴 백화점과 국립은행으로 가는 방향을 알려준다.
# Summary for index None: #Person1#은 #Person2#에게 며칠 런던에 가자고 제안하며, #Person2#는 차를 선호한다.
# Summary for index None: 톰과 캐서린은 패스트푸드에 대해 이야기하고 있다. 톰은 패스트푸드가 미국 라이프 스타일이라고 생각하지만, 캐서린은 그것을 싫어하고 건강에 좋지 않다고 생각한다.
# Summary for index None: #Person1#은 #Person2#의 주문을 받아 레모네이드 한 잔, 바비큐 윙, 그리고 베이비 백 립을 준비합니다.
# Summary for index None: #Person1#은 #Person2#의 더블 치즈버거, 용수철감자 라지, 그리고 펩시콜라 중 사이즈를 주문받습니다.
# Summary for index None: #Person2#는 머핀 만들기로 일찍 일어났다. #Person1#은 커피와 계란을 요청하지만 계란이 딱딱해서 불평한다.
# Summary for index None: #Person1#은 #Person2#가 그랜드 호텔로 가는 방법을 물어봅니다.
# Summary for index None: #Person1#은 #Person2#의 사진을 찍어 아이들에게 미국 경찰이 어떻게 생겼는지 보여줍니다.
# Summary for index None: #Person1#은 #Person2#에게 내일 빈 방이 없으므로 다른 호텔에 전화해보라고 제안한다.
# Summary for index None: #Person2#는 #Person1#에게 미국에서 공부하기 위해 비자를 신청하고 다음 주에 인터뷰를 보러 갈 것이라고 말했습니다.
# Summary for index None: 앤은 삼-오와의 만남이 재미없었고 삼-오의 농담이 그녀를 깔깔거리게 만들었기 때문에 삼-오와 다시 만나고 싶지 않다.
# Summary for index None: 메리는 #Person1#에게 온라인 쇼핑의 장점을 소개합니다. 메리는 #Person1#에게 온라인으로 물건을 확인하라고 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 미국식 회계에 대해 묻습니다. #Person2#는 회계 과정의 기본 개념을 설명합니다.
# Summary for index None: 제인은 피터에게 여름에 시안에 가는 것에 관심이 있느냐고 물어보고, 피터는 관심이 있다. 그들은 각자의 휴가에 대해 이야기한다.
# Summary for index None: #Person2#는 딸을 위해 영화를 대여하려고 합니다. #Person1#은 #Person2#에게 멤버십 카드를 발급하고 무료로 대여할 수 있습니다. #Person2#는 7달러 50센트를 지불하고 목요일 오후 열 시까지 반납해야 합니다.
# Summary for index None: #Person1#은 미스터 리를 찾아 그의 소포를 #Person2#에게 전달합니다.
# Summary for index None: #Person1#은 #Person2#에게 뜨는 비행기에 대해 묻지만, #Person2#는 공항이 폐쇄되었다고 말한다. #Person1#은 불을 켜놓지 않으면 잠을 자지 못한다.
# Summary for index None: #Person1#은 컴퓨터를 도와준 보답으로 #Person2#에게 식사를 대접하려고 하지만, #Person2#는 그것을 거절하고 식당을 찾는 것에 동의합니다.
# Summary for index None: #Person2#는 성적 때문에 걱정이 많아서 잠이 잘 안 와. #Person1#은 #Person2#에게 음악을 듣고 휴식을 취하라고 권장한다.
# Summary for index None: #Person1#은 주방을 새롭게 만들고 싶어하고, #Person2#는 그 이유를 이해하지 못한다.
# Summary for index None: 스털링과 월터는 우드 교수님에 대해 이야기하고 있다.
# Summary for index None: #Person2#는 #Person1#에게 검사 결과가 명확하지 않아서 추가 검사를 하기 위해 상담 약속을 잡았다고 말한다.
# Summary for index None: 엘리자는 마틴에게 다가오는 시험에 대비하고 있으며, 램 선생님의 도움으로 돈을 벌고 있으며, 학생 복지 클럽에 만족하고 있다고 말한다.
# Summary for index None: #Person1#은 한국으로 소포를 보내고 싶어합니다. #Person2#은 패키지 우편이 더 저렴하다고 제안합니다.
# Summary for index None: #Person1#은 결혼식에 가기 전에 휴대폰을 두고 온 것을 알아냅니다. 린다는 #Person1#의 휴대폰으로 여동생에게 전화할 수 있습니다.
# Summary for index None: #Person1#은 미국인이며, 미국에서 여행 중인 #Person2#에게 도시의 아름다움을 칭찬합니다.
# Summary for index None: #Person1#은 여름방학에 쉬고 싶어한다. #Person2#는 삼촌 회사에서 일하고 경영학 수업을 듣는다.
# Summary for index None: #Person2#는 우유 배달을 하다가 거대한 개에게 쫓겨나 다른 곳으로 피해 도착했다.
# Summary for index None: #Person2#는 #Person1#에게 6년 전과 지금의 느낌이 다르다고 말하고, #Person2#는 일을 더 오래 하고 더 많이 번다. #Person2#는 승진을 기대하고 있고, 어머니를 돌보기 위해 여행을 자주 가지 않는다.
# Summary for index None: #Person1#은 당좌예금 계좌를 개설하고 싶어하고, #Person2#는 #Person1#에게 그것이 이자를 주지 않는다고 말하고, #Person1#은 돈을 인출하는 방법을 물어봅니다.
# Summary for index None: #Person1#은 죽을 만큼 배가 고프고, #Person2#는 중국 요리를 추천합니다. 그들은 적절한 식당을 찾기 위해 노력합니다.
# Summary for index None: #Person1#이 #Person2#에게 양모의 배송이 느려서 걱정이라고 말한다. #Person1#은 오클랜드에 전화해서 다음 달 출발의 첫 배에 주문 물량을 싣는 데 동의했다.
# Summary for index None: #Person1#이 #Person2#에게 503호의 독서등을 깨뜨렸다고 말하고 새 것을 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 2006 회계 연도 마케팅 계획의 소개 부분을 소개합니다.
# Summary for index None: #Person2#는 #Person1#에게 휴가 동안 유럽으로 여행할 계획이며, #Person1#은 #Person2#에게 기념품을 사다 달라고 요청합니다.
# Summary for index None: #Person1#은 중형 차량을 예약했지만 차량이 없다고 하여 컴팩트 차량을 대신 렌트합니다. #Person2#는 보험료와 대여료에 대해 할인을 적용합니다.
# Summary for index None: #Person1#은 카드 게임을 하고 싶어하지만, #Person2#는 아빠가 공부하고 있기 때문에 소리를 내지 않도록 경고한다.
# Summary for index None: 앤이 존스 씨에게 이번 주의 회의 일정을 알려줍니다.
# Summary for index None: #Person2#는 지도를 보고 지리 수업을 준비하고 있다. #Person1#은 그것이 흥미롭다고 생각하고 더 많은 정보를 찾아보고 싶어한다.
# Summary for index None: #Person2#는 담배 냄새가 나는 방을 바꾸고 싶어합니다. #Person1#은 금연 방을 준비해 줄 것입니다.
# Summary for index None: 빌은 젖은 페인트에 손대지 말라는 경고를 들었다. #Person1#은 작업자들이 공지 없이 그것을 두고 가면 안 된다고 말했다.
# Summary for index None: #Person1#이 가야 하지만 #Person2#는 #Person1#에게 하나 더 하라고 요청합니다. #Person1#은 감사하며, #Person2#는 #Person1#에게 #Person2#의 번호를 줍니다.
# Summary for index None: 빌은 짐에게 멋진 딕이 아픈 상태라고 말한다.
# Summary for index None: #Person1#은 #Person2#가 최저임금으로 일하면서도 야근에 대한 추가 급여를 받지 못한다고 불평한다.
# Summary for index None: 리사는 마크가 다른 여자와 만나고 있다는 것을 알게 되었고, 마크는 처음에는 변명을 했지만 나중에는 실수를 인정했다.
# Summary for index None: #Person2#는 #Person1#에게 의사 선생님의 다이어트 조언을 알려준다.
# Summary for index None: #Person2#는 #Person1#에게 함께 인생을 같이 하자고 말하지만, #Person1#은 #Person2#에게 이제 돌아섰다고 말한다.
# Summary for index None: #Person2#는 #Person1#에게 도서관 이용 방법을 알려주고, #Person1#은 #Person2#의 도움으로 영어 회화에 관한 책을 대출한다.
# Summary for index None: #Person1#과 #Person2#는 날씨가 좋아서 밖에서 점심을 먹고 봄날씨를 즐기려고 합니다.
# Summary for index None: #Person1#은 #Person2#가 박물관에서 사진을 찍지 못하도록 막았습니다. #Person2#는 그림 엽서를 구매할 수 있습니다.
# Summary for index None: #Person2#는 대출 신청에 대한 정보를 원합니다. #Person1#은 #Person2#에게 대출 정책의 일반적인 조건을 소개하지만, #Person2#의 신용 점수가 매우 낮습니다.
# Summary for index None: #Person1#이 모니카의 발표에 감동하고 그녀의 노력에 대해 칭찬합니다. 모니카는 그것을 다했을 뿐이라고 말합니다.
# Summary for index None: #Person1#은 톰에게 러닝에 초대하지만 톰은 아침에 달리는 것을 선호한다. 톰은 내일 아침에 #Person1#을 찾아갈 것이다.
# Summary for index None: #Person1#은 #Person2#에게 일본 레스토랑의 음식 종류와 영업 시간에 대해 묻는다.
# Summary for index None: #Person1#은 심슨 씨에게 목요일 점심에 같이 먹자고 제안한다.
# Summary for index None: #Person1#은 데이트를 위한 레스토랑을 찾고 있습니다. #Person2#는 그에게 그래마시 타번을 추천하고 예약을 도와줍니다.
# Summary for index None: #Person1#은 #Person2#에게 50달러를 지불하고 팁을 거절한다.
# Summary for index None: #Person2#는 #Person1#에게 그들의 나라에서 축구, 농구, 테니스, 수영, 골프, 럭비를 좋아하지만 익스트림 스포츠는 시도해보는 것이 두렵다고 말합니다.
# Summary for index None: #Person2#는 프리덤 여행사에 전화하여 헬싱키로 가는 비행기를 예약한다. #Person1#은 #Person2#에게 저렴한 비행기를 추천하고 채식주의자 식사를 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 내일 플로리다로 날아가서 할머니를 방문할 예정이라고 말합니다.
# Summary for index None: #Person1#은 #Person2#에게 호주에 가본 적이 없다고 묻고, #Person2#는 가고 싶어한다.
# Summary for index None: 로라는 헬스장에 가는 길에 #Person1#을 만난다. 그들은 운동과 스포츠에 대해 이야기한다. 로라는 #Person1#에게 헬스장에 같이 가자고 제안하지만, #Person1#은 게으른 편이라고 말한다.
# Summary for index None: #Person2#는 사실은 윌메트에서 자랐고, 14살 때 이곳으로 왔다. 그리고 #Person2#는 뮌헨에서 11년 동안 살았다.
# Summary for index None: #Person1#은 새로운 정장에 대해 #Person2#에게 묻고, #Person2#는 그것이 좋은 거래라고 생각하지 않는다.
# Summary for index None: 앤은 로빈에게 산호수 자전거 투어에 대해 인터뷰한다. 로빈은 투어가 무엇인지, 한 방향으로 타는 데 얼마나 걸리는지, 올해 몇 명이 참가할지에 대해 앤에게 설명한다.
# Summary for index None: #Person1#은 #Person2#에게 무알콜 칵테일을 추천합니다. #Person2#는 그것을 시도하고 맛있다고 생각합니다.
# Summary for index None: 에릭은 그레고리에게 점심을 사주겠다고 제안하지만, 그레고리는 현금이 부족하다. 에릭은 그레고리에게 번지 점프를 가르쳐 주고 싶지만, 그레고리는 거절한다.
# Summary for index None: #Person1#은 노르망디 상륙작전에 대한 정보를 찾고 싶어합니다. #Person2#는 #Person1#에게 구체적인 정보를 얻기 위해 도서관에 가는 것을 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 훈련에 대해 조언하고, #Person2#는 근육질이 아닌 체형을 원한다. #Person1#은 #Person2#에게 무게를 줄이고 스트레칭을 하는 것을 제안합니다.
# Summary for index None: #Person2#는 #Person1#에게 캠퍼스 서쪽에 주차 구조물이 있다고 말하지만, #Person1#은 그곳이 가득 찼을지도 모른다고 생각합니다.
# Summary for index None: 에밀리는 수잔에게 미국에서 받는 첫 번째 급여에 대한 몇 가지 질문을 합니다. 수잔은 그녀에게 세금과 공제에 대해 설명합니다.
# Summary for index None: #Person1#은 기계로 물건을 어떻게 사는지 알고 싶어합니다. #Person2#는 #Person1#에게 도와줍니다.
# Summary for index None: #Person2#는 겨울 휴가에 태국에 여자친구를 만나러 갈 예정이며, 그들은 인터넷을 통해 서로를 알게 되었다.
# Summary for index None: 케이트는 새 가구, 커튼, 카펫을 사고 장식을 다시 했다. 제임스는 새로운 가구들을 칭찬한다.
# Summary for index None: 빌은 운동 스케줄에 대해 불평합니다. #Person2#는 빌에게 댄스 수업을 시작하라고 말합니다.
# Summary for index None: #Person1#은 마르켓에게 과학 과목에 대한 조언을 구합니다. 마르켓은 #Person1#에게 지도학이 필요하다고 말하지만, #Person1#은 지도학이 약합니다.
# Summary for index None: 팀은 #Person1#에게 그의 프로젝트가 친환경적인 삶과 그가 어떻게 친환경적으로 행동하는지에 대해 이야기한다.
# Summary for index None: #Person1#은 크리스마스가 다가오고 있고, #Person1#이 일하는 장난감 부서가 너무 바빠서 피곤하다.
# Summary for index None: 빌은 수에게 생일 파티에서 케이크를 먹는 것을 제안하지만, 수는 알레르기 반응을 피하기 위해 다이어트 중이므로 거절한다.
# Summary for index None: #Person1#은 #Person2#가 센스가 좋다고 말하며, 올해 스타일에 딱 맞는 티셔츠와 치마를 구입하는 데 도움을 준다.
# Summary for index None: #Person1#은 예약 확인서를 가지고 왔지만, #Person2#는 #Person1#이 72시간 이내에 재확인하지 않아 취소되었다고 말합니다.
# Summary for index None: #Person2#는 #Person1#에게 부활절에 대한 가족 모임에 대해 이야기하고, 아이들이 숨어있다고 말합니다.
# Summary for index None: #Person1#은 토니가 나쁜 습관을 가지고 있어 걱정하고 있다. #Person2#는 #Person1#에게 토니에게 인내심, 애정, 존중을 가지고 대해 달라고 요청한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person1#의 친구인 줄리와 알렉스가 결혼할 예정이라고 말한다. #Person1#은 알렉스의 베스트맨과 대화했고, #Person1#은 남자들만의 파티를 준비하고 있다고 말한다.
# Summary for index None: #Person1#은 #Person2#가 투표용지를 받는 데 도움을 줍니다.
# Summary for index None: #Person1#은 회사가 인력을 줄일 것이라고 #Person2#에게 말한다. 그들은 누가 해고될지에 대해 이야기한다.
# Summary for index None: #Person1#과 #Person2#는 중국 스타일 이혼이라는 중국 TV 시리즈에 대해 논의하고 있다. 이것은 끊임없이 변화하는 세상에서 겪는 어려움을 반영하고 있다.
# Summary for index None: #Person1#과 주디는 여행 예산에 대해 이야기하고 있습니다. 주디는 유스호스텔을 선택하는 것을 제안합니다.
# Summary for index None: #Person1#은 #Person2#에게 메리가 제로드와 결혼하고 파리에서 살 것이라고 말한다.
# Summary for index None: #Person2#는 지갑을 잃어버렸다. #Person1#는 #Person2#에게 50달러를 빌려주고 함께 책을 사러 갈 것이다.
# Summary for index None: #Person1#은 #Person2#에게 머피 뮤직과 U-튠즈가 합병한다고 말합니다. #Person2#는 그것이 소문일 뿐이라고 생각하지만, #Person1#은 금융 페이지에서 직접 읽었다고 말합니다.
# Summary for index None: 톰은 조에게 그의 새 비서가 도움이 된다고 말하지만, 조는 비서가 그에게 인사조차 하지 않았다고 생각한다.
# Summary for index None: 사라는 회의에서 아무도 그녀의 제안을 듣지 않았다. #Person1#은 그녀에게 짧고 간결하게 말하라고 제안하고, 회의 후에 직접 관련된 사람들과 이야기하라고 제안한다.
# Summary for index None: #Person2#는 무슬림들이 메카로 순례를 가는 것에 대한 프로그램을 보고 있고, #Person1#은 기독교 순례자들과 치유를 받는 사람들에 대해 이야기한다.
# Summary for index None: 테드는 제니를 좋아하지만 그녀에게 고백할 용기가 없다. 마이크는 테드에게 제니에게 어떻게 느끼는지 말하라고 조언한다.
# Summary for index None: #Person2#는 #Person1#에게 화를 풀기 위해 음악을 듣는 것이 효과적이라고 말하고, #Person1#는 이것이 효과가 있을 것 같다고 생각한다.
# Summary for index None: #Person1#은 아빠에게 뉴질랜드에 있는 가족에 대해 묻는다. 아빠는 가족 구성원들의 관계를 설명한다.
# Summary for index None: #Person1#이 스튜어트를 도시 마라톤에서의 우승을 축하하고, #Person2#는 아이들과 함께 경기를 봤습니다.
# Summary for index None: #Person2#는 #Person1#의 도움으로 자신의 아이들을 위한 5켤레의 운동화와 아내를 위한 향수를 구매하였다.
# Summary for index None: #Person1#은 영국에 전화를 걸어야 하지만 로밍 요금을 감당할 수 없습니다. 홍이 현지 SIM 카드를 사용하도록 제안합니다.
# Summary for index None: 브라운 씨는 #Person2#에게 월급을 더 많이 주고 유익한 복지 혜택을 제공할 것이라고 말합니다.
# Summary for index None: #Person1#과 #Person2#는 배리가 너무 야망적이고 부정적이라고 생각하며, #Person2#는 #Person1#이 낯을 가리지 않는다고 생각한다.
# Summary for index None: #Person1#은 집을 사는 데 관심이 있습니다. #Person2#는 #Person1#의 선호도에 따라 #Person1#에게 딱 맞는 집을 찾아볼 것입니다.
# Summary for index None: 그랜트 씨는 샘플을 볼 기회가 있어서 기쁘지만, 지금 결정을 내리기에 적절한 상황은 아닙니다.
# Summary for index None: #Person2#는 #Person1#에게 Fair Oaks와 Orange Grove에 있는 Sons까지 가는 방법을 알려준다.
# Summary for index None: 이 씨가 워드 여사님을 태우고, 워드 여사님이 그에게 우산을 들어달라고 요청합니다.
# Summary for index None: #Person2#는 #Person1#의 진료를 받은 후, #Person1#은 #Person2#에게 어깨를 엑스레이로 찍어보고 병원에 하룻밤 머무는 것이 좋을 것이라고 말한다.
# Summary for index None: 셸리는 #Person2#에게 카드를 잃어버렸다고 전화한다. #Person2#는 그녀의 FRCM 일부 세부 사항을 받아서 도와줄 것이다.
# Summary for index None: #Person1#은 잠을 자려고 하고, #Person2#는 #Person1#에게 전화기를 뽑아 놓는 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 중국 음식을 먹고 싶냐고 묻습니다. #Person2#는 #Person1#의 도움으로 2인분 식사를 주문합니다.
# Summary for index None: #Person1#과 #Person2#는 식사를 하러 왔습니다. #Person1#은 크림 케이크를 많이 먹을 것이고 #Person2#는 그것을 좋아하지 않습니다.
# Summary for index None: #Person1#은 루시에게 노래를 부르라고 하지만 루시는 듣는 것을 선호한다. 그래서 #Person1#은 스탠리에게 노래를 부르라고 요청한다.
# Summary for index None: #Person1#은 홈 비디오 플레이어가 영화관을 대체하여 엔터테인먼트 사업에서 퇴출시킬 것이라고 생각한다. #Person2#는 영화관이 사람들을 만나는 곳이어야 한다고 생각한다.
# Summary for index None: #Person2#는 갈색 드레스가 무거워서 흰색 면 드레스를 원한다. #Person1#은 노란색이나 초록색을 제안하지만 #Person2#는 흰색을 원한다.
# Summary for index None: 조슈아는 아빠에게 13달러를 받는데, 아빠는 돈이 없다고 생각한다. 조슈아는 아빠에게 돈을 가지고 있다고 말한다.
# Summary for index None: #Person1#와 #Person2#는 내일 마이크의 생일 파티에 갈 예정이다.
# Summary for index None: #Person1#은 #Person2#의 도움을 받아 소포를 우등 우편으로 보내고, 50달러의 보험과 우표를 구매합니다.
# Summary for index None: #Person1#과 #Person2#는 지진이 얼마나 심각한 재해인지 이야기하고 있습니다. #Person2#는 지진을 겪은 사람들이 '구조'와 '지원'이라는 두 단어만 알고 있었을 것이라고 말합니다.
# Summary for index None: #Person1#와 #Person2#는 날씨에 대해 이야기하고 있습니다. #Person1#는 따뜻한 날씨를 좋아하고 #Person2#는 습한 날씨에 익숙합니다.
# Summary for index None: #Person1#과 #Person2#는 배구 경기 후에 올림픽 기념품 가게에 가서 가족들에게 선물을 사기로 결정했다.
# Summary for index None: #Person1#은 양이 많은 음식을 요리하기 위해 팬을 사고 싶어합니다. #Person2#는 #Person1#에게 알루미늄 팬을 추천하고 #Person1#은 그것을 구매합니다.
# Summary for index None: #Person1#은 #Person2#에게 퇴근 후에 만나자고 제안하고, #Person2#는 동의한다.
# Summary for index None: #Person1#은 베이커 씨에게 워싱턴의 공무원들이 자신들의 일을 즐기는 이유를 이해할 수 있다고 말합니다. 베이커 씨는 #Person1#에게 그 이유를 설명합니다.
# Summary for index None: #Person1#은 피트에게 헨리 존슨을 소개하고, 피트의 뉴욕 출신을 알아본다. 그들은 오늘 저녁 계획을 정하고, 중국에서의 생활에 대해 이야기한다.
# Summary for index None: 줄리는 존스 선생님에게 점심 후에 프라이드 치킨을 먹은 후 식중독에 걸려 아팠다고 말한다. 존스 선생님은 그녀가 수업을 다시 따라갈 수 있기를 바란다.
# Summary for index None: 엄마는 친구들을 초대하고 준비를 돕기 위해 마이크에게 도움을 청한다. 마이크는 커피를 내릴 수 있고, 과일 주스와 콜라를 사러 갈 것이다.
# Summary for index None: #Person1#은 베를린에 도착한 #Person2#를 환영한다. #Person2#는 비행기보다 친환경적이라는 이유로 버스를 탔지만, 다음에는 비행기를 탈 것이다.
# Summary for index None: #Person1#은 #Person2#에게 일에 대한 질문을 합니다. #Person2#는 이 일을 잘할 수 있고, 여행을 좋아하며 사람들을 만나는 것을 좋아합니다.
# Summary for index None: 에이미는 어제 지미에게 전화를 했지만 지미는 집에 늦게 돌아왔기 때문에 전화를 받지 못했다. 지미는 에이미에게 어제 소풍에 대해 이야기하고, 에이미는 지미에게 그의 책을 돌려주기 위해 만나자고 제안한다.
# Summary for index None: #Person1#은 피터에게 차를 제안하지만, 피터는 정원에 물을 줘야 한다. 그러나 비가 내려서 피터는 차를 마실 수 있다.
# Summary for index None: #Person1#은 켄이 돌아오지 않을 수도 있기 때문에 #Person2#에게 비상 회의를 소집하라고 요청한다.
# Summary for index None: #Person2#는 편지에 붙일 우표가 필요합니다. #Person1#은 #Person2#에게 7달러의 우표를 판매합니다.
# Summary for index None: #Person1#은 스미스 씨에게 감염에 대한 처방전을 쓰고 약국에 가서 약을 사라고 말한다.
# Summary for index None: #Person2#는 중국의 예술과 공예품이 훌륭한 솜씨로 유명하다는 것을 알고, #Person1#의 도움으로 집으로 가져갈 수 있는 것을 찾는다.
# Summary for index None: #Person1#은 #Person2#에게 에펠탑이 1889년에 지어졌으며, 그 설계자의 이름을 따서 지어졌다고 말했다.
# Summary for index None: #Person1#이 브라이언에게 영어에 대해 여쭤봅니다. 브라이언은 대학에서 배웠으며, 미국에 있었던 경험을 공유합니다.
# Summary for index None: #Person2#는 누군가를 걱정하고 있지만, #Person1#는 그가 스스로를 잘 챙길 수 있다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 우리가 하는 일에는 항상 문제가 있다며 경고한다.
# Summary for index None: #Person1#과 #Person2#는 존이 그녀와 데이트를 자주 한다. 그들은 서로 잘 어울리기 때문에 존이 그녀에게 반했을 수도 있다.
# Summary for index None: #Person1#은 런던의 역사적인 장소들을 소개하고, #Person2#는 #Person1#에게 웨스트민스터 대성당을 보는 것을 기대하고 있다고 말한다. 그들은 런던의 역사적 인물들을 보는 것을 즐긴다.
# Summary for index None: 다니엘은 과학을 좋아하지만, #Person2#는 그가 체육을 좋아할 줄 알았습니다.
# Summary for index None: #Person1#은 베이비 샤워에 참석했지만 처음으로 자신을 위한 것을 받습니다. #Person1#은 양수가 터졌고, #Person2#에게 병원에 데려가 달라고 요청합니다.
# Summary for index None: #Person1#은 중국에 가고 싶지만, 엄마는 바쁘기 때문에 같이 갈 수 없다.
# Summary for index None: 팀이 늦었다고 생각하여 카렌에게 인사를 하고 간다.
# Summary for index None: #Person2#는 어제 밤에 새로운 오토바이를 타게 해준 마이클을 만났다. #Person2#는 그것이 무서웠지만 좋아했다.
# Summary for index None: #Person2#는 중국어, 영어, 프랑스어를 할 수 있습니다. #Person1#은 #Person2#에게 영어 실력이 충분하다고 생각합니다.
# Summary for index None: 낸시는 타일러에게 전화를 걸어서 나오미에게 앤디가 전화했다고 말하라고 요청했다.
# Summary for index None: #Person2#는 #Person1#에게 #Person1#의 비행기가 취소되었으며, #Person1#은 내일 비행기를 예약하고 50% 할인을 받을 것입니다.
# Summary for index None: #Person1#과 #Person2#는 점심에 버거퀸에 가기로 결정했다. #Person1#은 그들의 치즈버거를 추천하고, #Person2#는 그들의 밀크쉐이크를 좋아한다.
# Summary for index None: #Person1#은 #Person2#에게 짐이 8킬로그램을 초과하고 있으므로 초과 수하물 요금을 내야 한다고 말합니다.
# Summary for index None: #Person1#이 목이 말라서 무엇을 마실지 고민하고 있습니다. #Person2#는 물을 마시라고 제안합니다.
# Summary for index None: 왕 묘은 매니저 량에게 CEO가 긴급한 일정 변경으로 인해 량과의 약속을 취소한다고 말한다.
# Summary for index None: #Person1#은 30사이즈의 유광 가죽 신발을 원하고, #Person2#는 굽이 늘어날 것이라고 말합니다.
# Summary for index None: 벤자민은 프로젝트 보고서를 아직 쓰지 못했고, #Person1#은 그에게 언제까지 써야 하는지 알려줍니다. 벤자민은 보고서의 형식에 대해 몰라서 #Person1#에게 도움을 청합니다.
# Summary for index None: #Person2#는 피자 하우스에서 중간 사이즈 피자와 해산물 피자를 주문합니다. #Person1#은 #Person2#에게 배달 시간을 알려달라고 요청합니다.
# Summary for index None: #Person1#은 새우 칵테일, 계란 수프, 양파 스테이크, 미네랄 워터를 주문한다.
# Summary for index None: #Person1#은 #Person2#에게 집에 대해 소개합니다. 집은 멋진 거실, 꽤 현대적인 부엌, 그리고 편리한 화장실을 갖추고 있습니다.
# Summary for index None: #Person2#는 개인용 스테레오를 샀지만 만족하지 않습니다. 그 스테레오는 큰 긁힘과 소음이 있습니다. #Person1#은 #Person2#의 스테레오를 다른 모델로 교환해 줄 것입니다.
# Summary for index None: #Person1#은 #Person2#에게 기숙사 보증금을 내는 데 서둘러야 한다고 말하지만, #Person2#는 캠퍼스 밖에서 살 생각을 하고 있다.
# Summary for index None: #Person1#과 #Person2#는 중고 서점에서 책을 사고 있다. #Person1#은 책을 사서 도서관에서 유명한 사람과 비슷한 이름을 찾아볼 것이다.
# Summary for index None: #Person1#은 #Person2#의 주문을 받고 베이징 오리를 시도하도록 권하고, #Person2#는 20분 후에 음식을 요청한다.
# Summary for index None: #Person1#은 중요한 증명서를 아들에게 전달하고 싶어합니다. #Person2#는 공인 우편이나 등기 우편으로 보내는 것을 제안합니다.
# Summary for index None: #Person1#이 샐리에게 톰이 보낸 편지를 읽어주고, 톰은 샐리와 존에게 1월에 방문할 예정이라고 말한다.
# Summary for index None: #Person1#은 컴퓨터 접근에 어려움을 겪고 있고, #Person2#는 스스로 컴퓨터를 구입할 수 있는 날을 기대하고 있다.
# Summary for index None: #Person1#과 #Person2#는 아름다운 날씨에 대해 이야기하고 있습니다. 그리고 #Person2#는 일주일 동안 비가 오지 않았기 때문에 소풍에 가자고 제안합니다.
# Summary for index None: #Person1#은 컴퓨터에 대한 일반적인 정보를 찾고 있습니다. #Person2#은 #Person1#을 도와줄 것입니다.
# Summary for index None: #Person2#는 프렌치 가든 레스토랑에 와서 물 한 병, 참치 샌드위치, 야채 수프 한 그릇을 주문한다.
# Summary for index None: #Person1#은 #Person2#의 주문을 받아 레모네이드, 바비큐 윙, 베이비 백 립을 준비합니다.
# Summary for index None: #Person1#은 #Person2#의 저녁식사 및 디저트 주문을 도와줍니다.
# Summary for index None: #Person1#과 #Person2#는 서로에게 질문을 하고 있다. #Person1#은 에릭이 #Person2#를 데이트에 초대하면 어떻게 할지 물어본다.
# Summary for index None: #Person1#은 잭에게 #Person1#의 새로운 아기 사진을 보여준다.
# Summary for index None: #Person1#은 엄마에게 제인 이모가 톰에게 새 자전거를 사줬다고 말하고, #Person1#은 언젠가 큰 차와 비행기를 사줄 것이라고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 400달러짜리 치마를 추천하지만, #Person2#는 너무 비싸다고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 #Person2#의 도시가 어떻게 성장했는지, 그리고 200년 이상 된 건물들이 여전히 남아있는지 물어봅니다.
# Summary for index None: #Person1#과 #Person2#는 세계의 다양한 환경 문제에 대해 이야기하고 있으며, #Person1#은 #Person2#에게 환경 보호에 헌신하는 조직에 가입하라고 제안합니다.
# Summary for index None: 데니스는 채팅방에서 여자로 가장하여 사람들과 이야기를 나눕니다. 데니스는 새로운 온라인 친구를 사귀고 있지만, #Person2#는 그것을 좋아하지 않습니다.
# Summary for index None: 엄마는 네이선이 시카고로 연습하러 갈 것에 대해 걱정하고, 네이선은 그녀에게 그것이 너무 큰 고도라고 생각하며, 그들은 그것에 대해 더 이상 논의하지 않습니다.
# Summary for index None: #Person1#은 #Person2#가 토요타 캐롤라를 3일 동안 빌리는 것을 도와줍니다.
# Summary for index None: #Person2#는 #Person1#에게 뉴욕에서 무엇을 볼지 추천하고, 뉴욕의 대학교를 소개합니다.
# Summary for index None: #Person1#은 #Person2#에게 필름 현상을 부탁하고, #Person2#는 내일까지 완료할 것이라고 약속한다.
# Summary for index None: #Person1#은 폭우로 인해 지연된 비행기에 대한 정보를 #Person2#에게 문의하고, #Person2#은 #Person1#에게 최근의 일기예보를 확인하라고 권장한다.
# Summary for index None: #Person1#은 #Person2#에게 지도에서 베이징 대학교의 위치와 가는 방법을 물어봅니다.
# Summary for index None: #Person1#과 #Person2#가 신문에 무슨 기사가 있는지, 일기 예보는 어떤지, 그리고 은행 강도가 잡혔는지에 대해 이야기합니다.
# Summary for index None: #Person1#은 컴퓨터 게임이 폭력적이라고 생각하지만, #Person2#는 소년들이 게임을 통해 컴퓨터를 사용하는 법을 배울 수 있다고 생각한다.
# Summary for index None: #Person1#은 맥주를 제안하지만, 짐은 건강에 좋지 않다고 생각한다. 그들은 운동장에 가서 노래를 부르고 친구들을 만나기로 결정한다.
# Summary for index None: #Person1#과 #Person2#는 닭발과 와인을 주문한다.
# Summary for index None: #Person2#는 #Person1#에게 몇몇 외국인 관광객 그룹을 안내했으며, 그들에게 몇몇 관광지를 소개했다고 말한다.
# Summary for index None: 잭은 더블룸 예약을 위해 #Person1#에게 도움을 청한다.
# Summary for index None: 질은 마크에게 전화를 걸어 마크에게 데이비드가 숙취로 인해 출근하지 않았다고 말하고, 빌의 아내가 어제 밤에 딸을 낳았다는 것을 알려준다.
# Summary for index None: #Person1#은 #Person2#를 초대하지만 #Person2#는 남편이 좋아하지 않을 것 같아서 거절한다.
# Summary for index None: #Person1#은 #Person2#에게 야구 경기를 볼 수 있는 좋은 장소라고 말합니다. #Person2#는 그것에 동의하고 #Person1#에게 야구가 미국인의 가장 좋아하는 여가활동 중 하나라고 말합니다.
# Summary for index None: #Person2#가 #Person1#을 감사하고 #Person1#은 도움을 준 것에 만족하고 있다.
# Summary for index None: #Person2#는 #Person1#에게 그들의 나라에서 석탄과 구리를 수출하고 있으며, 이웃 국가로부터 철과 알루미늄을 수입하고 있다고 말합니다.
# Summary for index None: #Person1#은 예술 갤러리를 방문하는 것을 좋아합니다. #Person2#는 #Person1#과 함께 국립 갤러리의 그리스와 로마 조각의 전시회를 방문할 예정입니다.
# Summary for index None: #Person2#는 책을 반납하고 비디오를 대출하려고 합니다. #Person1#는 #Person2#에게 비디오를 손상시키지 않도록 요청합니다.
# Summary for index None: #Person1#은 #Person2#에게 볼링을 소개하고, #Person2#는 더 알고 싶어합니다. #Person1#은 #Person2#에게 게임하면서 더 알려줄 것이라고 말합니다.
# Summary for index None: #Person1#은 #Person2#에게 은행의 새로운 서비스에 대해 설명하고, #Person2#가 전화로 상담 서비스를 이용할 수 있다고 말합니다.
# Summary for index None: #Person2#는 #Person1#에게 체크아웃 시간이 30분 남았으며, 짐을 둘 곳이 필요하다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 파티에 몇 명이 오는지 묻는다. #Person2#는 세 명이 오고 뷔페를 원한다.
# Summary for index None: #Person2#는 해외에서 공부할 예정이지만 대출을 받을 수 있는지 확실하지 않습니다. #Person1#은 해외유학 대출에 대해 #Person2#에게 정보를 제공합니다.
# Summary for index None: #Person1#은 영어 노래를 찾고 싶어합니다. #Person2#은 영어 가수들이 많지 않기 때문에 찾는 데 시간이 걸릴 수 있다고 말합니다.
# Summary for index None: #Person1#은 #Person2#의 글쓰기 경험에 감탄하고 #Person2#에게 이 직무에 관심을 가진 이유를 묻습니다.
# Summary for index None: 잭과 #Person1#은 면접 결과를 물어보는 것에 대해 논의하고, 문의서를 작성하는 방법에 대해 이야기한다.
# Summary for index None: #Person1#은 #Person2#의 집을 둘러보면서, #Person2#는 #Person1#에게 마당의 옥수수 이삭이 수확 후에 깎는 시간을 줄이기 위해 나무에 매달아 놓았다고 말합니다.
# Summary for index None: #Person2#는 #Person1#이 뉴욕에서의 하루를 즐기는 동안 보증금을 내고 수하물을 보관함에 맡길 수 있다고 말합니다.
# Summary for index None: #Person2#는 #Person1#에게 새로운 웹사이트가 무료로 글쓰기 기술을 향상시켜 준다고 말한다. 하지만 #Person1#는 그것이 신뢰할 수 없다고 생각한다.
# Summary for index None: #Person1#과 #Person2#는 교장이 새 실험실 건물을 지을 수 있도록 지방 정부에 도움을 청할 것이라고 믿습니다.
# Summary for index None: 케이트는 현금이 없어서 집에 가는 길에 신용카드로 소고기를 샀습니다. 헨리는 그녀에게 카드의 위험성을 경고했습니다.
# Summary for index None: #Person1#은 스미스씨에게 내일의 마을 방문에 대해 이야기하고, 스미스씨는 산악 지역의 마을을 방문하기로 결정한다.
# Summary for index None: 벳은 #Person1#에게 오이를 먹고 잠을 자는 것이 그녀가 스트레스와 우울증을 다루는 방법이라고 말하며, 그녀는 또한 그녀의 아기에 대한 책임을 느낍니다.
# Summary for index None: #Person2#는 #Person1#에게 우표 수집에 대한 열정을 이야기하며, #Person1#은 그것이 부자들만 즐길 수 있는 큰 즐거움이라고 생각합니다.
# Summary for index None: #Person1#은 톰이 친환경 제품을 판매하는 회사의 관리자로서 성공한 사업가가 되었다는 사실에 대해 인터뷰한다.
# Summary for index None: #Person2#는 #Person1#에게 니스든의 보행자 지하도에서 발견된 40대로 추정되는 한 남자의 죽음을 살인으로 다루고 있으며, 사건을 수사하고 있다고 말한다.
# Summary for index None: 셰리는 밥에게 내년 여름에 퀘벡을 방문할 예정이라고 말하고, 그곳에서 관광도 하려고 한다. 그들은 퀘벡 시, 몬트리올, 그리고 퀘벡 시에 대해 이야기한다.
# Summary for index None: 톰은 제인을 운동하러 학생 센터에 가자고 초대하지만 제인은 논문을 쓰기 위해 바쁘다. 톰은 그릴에서 저녁 식사를 하는 것을 제안한다.
# Summary for index None: #Person1#은 #Person2#에게 약을 복용하고도 아직 등 통증이 있는 것을 믿지 못한다. #Person2#는 #Person1#에게 약을 더 자주 복용해야 한다고 말한다.
# Summary for index None: #Person1#은 #Person2#에게 휴대폰이 고장나서 200 위안을 빌리고, #Person2#는 #Person1#에게 돈을 빌려준다.
# Summary for index None: #Person1#은 글씨를 개선하고 싶어하지만, 몇 주 동안의 노력에도 불구하고 아무런 변화가 없습니다. #Person2#는 #Person1#에게 인내심을 가져야 한다고 말합니다.
# Summary for index None: #Person2#은 #Person1#이 자신의 속눈썹을 집는 것을 보고 겁이 나서, #Person2#은 #Person1#을 겁쟁이라고 비난한다.
# Summary for index None: #Person2#는 주말에 운전 수업을 듣고 싶어합니다. #Person1#은 그녀에게 수업 시간, 코치, 그리고 차량 공유에 대해 알려줍니다.
# Summary for index None: 티나는 8년 동안 피아노를 배웠으며, #Person1#은 그녀의 선생님에게 배우고 싶어합니다. 티나는 #Person1#을 소개해줄 것입니다.
# Summary for index None: #Person2#는 #Person1#에게 자신이 개인적으로도 단체에서도 잘 일하며, 처음에는 조금 긴장할 수 있지만 학습하고자 하는 의지를 가지고 있다고 말합니다.
# Summary for index None: 스테파니는 #Person1#에게 피곤하고 머리가 아파서 의사에게 가야 한다고 말한다. #Person1#은 그녀에게 보고서를 늦게 제출할 수 있도록 부탁하라고 제안한다.
# Summary for index None: #Person1#은 데이비드에게 크리스마스를 시골 호텔에서 보내야 한다고 말한다. 데이비드는 지루하다고 생각한다.
# Summary for index None: #Person1#과 밥은 지난 주말의 활동을 공유한다. 밥은 #Person1#을 이번 주말에 게임을 하자고 초대한다.
# Summary for index None: #Person1#은 일자리를 찾고 있지만 돈이 부족하기 때문에 #Person2#에게 50달러를 빌린다.
# Summary for index None: #Person1#은 #Person2#에게 모든 손님들이 재킷과 넥타이를 착용해야 하지만 #Person2#는 가지고 있지 않습니다. #Person2#는 회의 시간을 30분 미루기로 합니다.
# Summary for index None: #Person2#는 #Person1#에게 아이들이 휴가 캠프에서 다른 아이들을 잘 몰라서 처음에는 불행해했지만, 마지막 날에는 너무 즐거워서 집에 가고 싶지 않아 했다고 말했다.
# Summary for index None: #Person1#은 #Person2#가 대학 입학 요건에 대해 물었기 때문에 #Person2#가 사업을 시작하려고 한다는 것을 알게 되었습니다.
# Summary for index None: 칼리나가 클라크 교수님에게 전화를 걸어서 어제 차 사고로 인해 몇 일 동안 학교를 쉬어야 한다고 말한다.
# Summary for index None: #Person2#는 #Person1#에게 #Person2#의 집주인이 수리 비용에 대해 합의를 이루지 않는다고 말한다. #Person2#는 집에 대한 돈을 보냈고, 집주인이 화를 냈다.
# Summary for index None: #Person2#는 터너 인테리어에서 왔고, #Person1#은 그녀에게 수출용 L / C를 제공합니다.
# Summary for index None: 찰리는 미르달이 지갑을 잃어버린 이유를 찾기 위해 함께 핫도그 판매대로 가기로 합니다.
# Summary for index None: #Person1#은 설거지를 한 주 동안 했고, #Person2#에게 번갈아가며 설거지를 하기로 했다.
# Summary for index None: #Person1#은 #Person2#에게 자신이 #Person2#를 사랑하는지 물어봅니다. #Person2#는 대답하지만 #Person1#은 총을 들고 있습니다.
# Summary for index None: #Person1#과 #Person2#는 정부가 사회 문제를 효과적으로 해결하는 것이 어렵다는데 동의합니다.
# Summary for index None: #Person1#은 다음 토요일에 화려한 복장 파티에 참석하기 위한 복장을 구해야 하므로, #Person2#에게 쇼핑하러 가자고 제안한다.
# Summary for index None: #Person2#는 #Person1#에게 베이징의 야간 생활을 추천하고, 그들은 댄스홀에 가서 춤추기로 결정한다.
# Summary for index None: #Person1#은 농부가 되고 싶어하고 #Person2#는 농장에서 일하며 휴가를 보내는 것이 좋을 것이라고 생각한다.
# Summary for index None: #Person1#은 하이네켄 한 파인트와 버드 반 파인트, 나초와 모짜렐라 스틱을 주문한다.
# Summary for index None: 메리와 앤은 해변으로 가는 계획에 대해 큰 싸움을 했지만 결국 화해했다.
# Summary for index None: #Person1#은 #Person2#에게 담배, 기념품, 남자 화장실이 어디에 있는지 물어봅니다.
# Summary for index None: 톰은 캐서린에게 '패스트 푸드 네이션'에 대한 의견을 묻는다. 캐서린은 미국인들이 패스트푸드를 최대한 활용하는 방법을 찾아야 할 것이라고 생각한다.
# Summary for index None: #Person1#은 #Person2#에게 버스에서 물러나라고 요청하고, 버스 요금을 내라고 요청하며, #Person2#가 잘못된 버스를 타고 있음을 알려줍니다.
# Summary for index None: #Person1#과 #Person2#는 9-11 테러 공격에 대해 이야기하고 있습니다. #Person1#은 부모님 집에서 연기를 보았고, #Person1#의 삼촌은 사망했습니다.
# Summary for index None: 칼이 척 존스에게 인사를 하고, 그는 시카고 출신이지만 평화로운 공동체를 찾아 미네소타로 이사했다고 말합니다.
# Summary for index None: #Person1#은 #Person2#의 주문을 받아 삶은 계란, 진한 토스트, 그리고 나중에 오렌지 주스를 준비할 것입니다.
# Summary for index None: #Person1#은 피곤해서 잠자리에 들어가려고 하지만, #Person2#은 아직 가계 예산을 살펴보고 싶어한다.
# Summary for index None: #Person1#은 다음 주 회의 전에 제인과 만나서 아이디어를 논의하고 싶어한다.
# Summary for index None: #Person2#는 여자친구에게 줄 선물을 찾는 데 도움을 청했습니다. #Person1#은 #Person2#에게 몇 가지 제안을 합니다. #Person2#는 제시에게 결혼을 제안할 것입니다.
# Summary for index None: #Person1#은 새 차를 사고 싶어하고, #Person2#는 그에게 포드 포커스를 추천하며, 그것이 가볍지만 강력하다고 말합니다.
# Summary for index None: #Person1#은 발람씨에게 컴퓨터 엔지니어 직위를 제안하고, 발람씨는 월 4,000 위안을 받아들입니다.
# Summary for index None: #Person1#은 #Person2#에게 그룹 회사의 혜택에 대해 설명하고, #Person2#는 이 서비스를 받기로 결정합니다.
# Summary for index None: #Person1#은 저녁을 먹은 후에도 계속 배고픈 상태라서, #Person2#는 그녀에게 간식으로 피넛버터와 젤리 샌드위치를 만들 것을 제안한다.
# Summary for index None: #Person2#는 #Person1#의 피를 뽑아 백혈구 수치를 확인합니다. #Person1#은 아프지만 참아냅니다.
# Summary for index None: 스티븐이 전기 문제로 전화를 걸어 셀러에게 도움을 청하고, 셀러는 그에게 전기를 고치는 방법을 알려줍니다.
# Summary for index None: 파울라는 #Person2#에게 코너스 씨가 전체 임대료를 지불하지 않았다고 하여 그녀를 퇴거시키겠다고 위협했다고 말합니다. #Person2#는 그녀를 도울 것입니다.
# Summary for index None: #Person1#은 에어컨, 화장실 변기, 전기 배선, 그리고 외부의 배수로가 막힌 것을 댄이 수리하도록 요청할 것입니다.
# Summary for index None: #Person1#은 일자리를 찾고 있으며, #Person2#는 전기기사 수습생 프로그램에 지원하라고 제안한다.
# Summary for index None: #Person2#는 #Person1#에게 사장님과의 업무 관계, 그리고 그의 장점에 대해 이야기합니다.
# Summary for index None: #Person1#은 탕 씨에게 투어 가이드 자격증의 사본을 보여달라고 요청했고, 탕 씨는 두 가지 언어를 할 수 있다고 말했다.
# Summary for index None: #Person2#는 시계를 보고 싶어하고, #Person1#은 가격이 적당하다고 말하며 #Person2#는 사기로 결정한다.
# Summary for index None: #Person2#가 톰의 아들 켄을 돌봐주는 동안 톰은 아들을 돌보는 데 도움이 되었다는 사실에 감사한다.
# Summary for index None: #Person1#은 에이미에게 그녀의 첫 직장이 어디였는지, 그곳에서 얼마나 있었는지, 그리고 그 일을 즐겼는지 물었습니다.
# Summary for index None: 앤드류는 와푸 다이어트를 시작했지만, 그것은 사기일 수도 있다. 그의 누나는 그가 올바르게 먹는 법을 배워야 한다고 생각한다.
# Summary for index None: 그렉 손더스는 메리에게 전화를 걸어 대학 스포츠에 관심이 있는지 묻습니다. 메리는 그에게 그녀의 스포츠 경험을 소개합니다.
# Summary for index None: #Person2#는 출퇴근 시간에 길이 막혀서 #Person1#을 기차역으로 데려다 줍니다.
# Summary for index None: #Person1#은 브라이언에게 영어 실력, 미국 체류 기간, 그리고 미국 여행 경험에 대해 묻는다.
# Summary for index None: #Person2#는 건강검진을 받아 새로운 건강보험에 가입하려고 합니다. #Person1#은 #Person2#에게 기본적인 건강검진을 받도록 안내하고, #Person2#는 혈액 검사를 받을 것입니다.
# Summary for index None: #Person1#과 #Person2#는 복권에 당첨되면 무엇을 할 것인지에 대해 이야기하지만, 그들은 당첨될 가능성이 없다는 것을 깨닫고, 현실로 돌아가서 술을 마시기로 한다.
# Summary for index None: #Person1#은 결혼에 대해 무서워하고 불안해하며, #Person2#의 도움으로 결혼에 대한 자신감을 되찾는다.
# Summary for index None: #Person1#은 2,000장의 명함을 인쇄하려고 합니다. #Person2#는 3일 후에 완성할 수 있지만 약간의 추가 비용이 발생합니다.
# Summary for index None: 브라이언은 #Person1#에게 여행 준비가 거의 끝났다고 말하고, #Person1#은 브라이언에게 회의가 어떻게 되는지 물어봅니다.
# Summary for index None: #Person1#은 폴에게 추수감사절 저녁 파티에 초대한다. 폴은 빈손으로 가는 것이 싫어서 와인 한 병을 가져가기로 결정한다.
# Summary for index None: 존은 수잔에게 목요일에 올 사촌을 돌봐달라고 요청한다. 존은 금요일에 출근하기 때문에 도움을 청하고, 수잔은 동의한다.
# Summary for index None: #Person1#은 벤에게 저녁 수업 정보를 보여주고, 벤은 사진 과정이 흥미롭다고 생각하지만, 가격이 비싸다고 생각한다. 벤은 인도 요리 과정에 관심이 있다.
# Summary for index None: #Person1#과 #Person2#는 저녁 식사 장소에 대해 이야기한다. 그들은 결국 몇 번 갔던 캐롯츠에 가기로 결정한다.
# Summary for index None: 진은 직장 때문에 운전 면허 시험을 보러 가고, 그가 통과하면 안전 기능이 있는 혼다 어코드를 사려고 계획하고 있다.
# Summary for index None: #Person1#은 갈색 케이스에 있는 펜을 시험해 보고 싶어합니다. #Person2#은 펜을 보여주고 #Person1#은 그것을 선택합니다.
# Summary for index None: #Person2#는 #Person1#에게 회사의 기금 모금 행사가 어떻게 진행되었는지 이야기한다.
# Summary for index None: #Person1#은 #Person2#에게 피크 트램까지 가는 길을 묻습니다. #Person2#는 친절하게 길을 알려줍니다. #Person1#은 #Person2#에게 연필을 요청하여 길을 적어두기 위해 사용합니다.
# Summary for index None: #Person2#는 샌들우드 부채를 사고 싶어합니다. #Person1#은 작은 것 두 개와 큰 것 하나를 추천합니다.
# Summary for index None: #Person1#은 #Person2#에게 회사에 영향을 미치는 외부 요인과 내부 요인에 대해 묻는다.
# Summary for index None: #Person1#은 오늘 오후 2시에 시작하는 회의에 참석할 수 없지만, #Person2#은 시작할 수 있고 #Person1#은 3시쯤에 참석할 예정입니다.
# Summary for index None: #Person2#는 #Person1#에게 도시에서의 짧은 투어를 추천해달라고 요청합니다. #Person1#은 강을 따라가는 하루짜리 여행을 추천합니다.
# Summary for index None: #Person1#은 #Person2#의 주문을 받아 소고기 버거, 프렌치 프라이, 그리고 바나나 맛 밀크 쉐이크를 준비합니다.
# Summary for index None: #Person1#과 #Person2#는 등 축제에 왔습니다. 사람들은 전통적으로 등에 적힌 퍼즐을 풀어봅니다. #Person1#과 #Person2#는 거대한 중국 용 모양의 등을 보고 있습니다.
# Summary for index None: #Person1#은 티나에게 ABC 컴퍼니와의 첫 두 라운드 면접을 성공적으로 통과했고, 티나에게 축하 파티를 초대한다.
# Summary for index None: 팀이 늦었고 가야 하기 때문에 팀과 카렌은 이별 인사를 나눕니다.
# Summary for index None: #Person1#은 #Person2#에게 10시에 부서 회의가 있음을 알리고, 준비물을 준비하고, 몇 장의 사본을 만들어야 합니다.
# Summary for index None: #Person1#은 #Person2#에게 목욕탕의 사용 방법을 알려달라고 요청하고, #Person2#는 #Person1#을 도와준다.
# Summary for index None: #Person2#는 #Person1#에게 기차에서 시간을 보내기 위한 책으로 일본 소설가의 책을 추천합니다.
# Summary for index None: #Person1#는 #Person2#에게 78세의 남미 이민자에게 읽는 법을 가르쳐 달라고 부탁하며, #Person1#은 #Person2#에게 그를 가르치는 것을 도와달라고 요청한다.
# Summary for index None: #Person1#은 티켓을 사기 위해 예약 확인서와 티켓 예약 양식을 작성하고, $800을 카드로 지불합니다.
# Summary for index None: #Person1#은 #Person2#에게 건강한 음식을 만드는 법을 가르쳐주고, #Person2#는 매운 치킨 커리를 만들기로 합니다.
# Summary for index None: #Person2#는 #Person1#에게 IC 전화기와 동전 전화기의 사용법을 알려준다.
# Summary for index None: #Person1#은 돈이 부족해서 중고 컴퓨터를 사려고 생각하고, 톰은 중고 물품을 사는 데 조심해야 한다고 말한다.
# Summary for index None: #Person1#은 모건에게 중국 사람들이 식당에서 남은 음식을 집으로 가져가는지 묻는다. 모건은 중국의 전통이 사람들이 식당에서 많이 주문하는 것이라고 말한다.
# Summary for index None: 해리는 중국의 거리 시장에서 무언가를 사는 것을 꺼려하고, #Person2#는 그가 흥정을 무시했기 때문에 쉽게 속아서 비싼 대금을 지불했다고 말합니다.
# Summary for index None: #Person2#는 #Person1#에게 영어를 쓰는 것과 말하는 것 모두에 능숙하다고 말하고, 프랑스어와 일본어를 조금 안다고 말했습니다.
# Summary for index None: #Person2#는 새로운 계좌를 개설하고 싶어합니다. #Person1#은 #Person2#에게 당좌 계좌와 저축 계좌를 모두 개설하도록 도와줍니다.
# Summary for index None: #Person1#은 #Person2#에게 특별 할인 쿠폰을 어떻게 받을 수 있는지 묻습니다. #Person2#는 더 많은 상품을 구매하면 더 많은 쿠폰을 받을 수 있다고 말합니다.
# Summary for index None: 로빈슨 부인은 스티브에게 쟈니를 돌봐줘서 고마워하고, 그는 부엌을 청소하는 데 도움을 주었다.
# Summary for index None: #Person2#는 기차 표를 잃어버렸고, 스미스라는 이름과 여권 번호를 제공하지만 구매 증거가 없어서 다시 표를 사야 합니다. #Person1#은 돈이 부족하다고 말합니다. #Person2#는 지갑에서 돈을 찾아 4마오를 줍니다.
# Summary for index None: 앤은 #Person1#에게 미국으로 가는 비행기에서 한 항공 웰빙 프로그램이 효과가 있었다고 말한다. 그녀는 #Person1#에게 그들이 어떻게 했는지 알려준다.
# Summary for index None: 메리는 기분이 좋지만 일자리를 찾았기 때문에 파티에 갈 수 없다. 톰은 그녀에게 아버지의 건설 회사에서 일하라고 제안한다.
# Summary for index None: 해리는 #Person1#에게 차에 치일 뻔 했다고 말하고, 그 차의 운전자가 위험하다고 말한다.
# Summary for index None: #Person1#은 '비즈니스 월드'에 오신 것을 환영합니다. 스티븐 케인씨는 #Person1#에게 자신만의 자전거 상점을 운영하는 이유를 설명하고, 그들은 함께 일할 직원을 고용했습니다.
# Summary for index None: #Person1#과 #Person2#는 중년에 대해 논쟁하고 있다. #Person2#는 #Person1#이 늙었다고 생각한다.
# Summary for index None: #Person2#는 식사가 완벽했기 때문에 디저트를 주문하며, #Person1#은 #Person2#의 주문을 받아 준비하러 갑니다.
# Summary for index None: #Person1#과 #Person2#는 침대, 스테레오, 그리고 책상에 대해 동전 던지기를 통해 결정한다. #Person1#은 창가 옆의 책상을 가져가고, #Person2#는 아래쪽 침대를 가져간다.
# Summary for index None: 머레이 씨가 도서관 카드를 신청하고, #Person2#가 그에게 신청서를 작성하라고 요청한다.
# Summary for index None: #Person2#는 #Person1#에게 자신의 일자리가 보너스 지급, 점심 휴식 시간, 그리고 서류 작업을 포함하고 있다고 말합니다.
# Summary for index None: 앨리스는 닉에게 세탁기와 건조기를 어떻게 사용하는지 가르치고, 닉은 옷을 빨래해 본 적이 없다는 사실을 앨리스에게 알립니다. 닉의 엄마는 모든 일을 대신해줬기 때문에 그는 스스로 아무것도 할 수 없습니다. 앨리스는 닉에게 요리, 옷을 빨래하는 법, 집을 청소하는 법 등을 가르쳐줄 것입니다.
# Summary for index None: #Person1#과 #Person2#는 서로의 일상 생활에 대해 이야기하고, #Person1#은 나가야 한다.
# Summary for index None: #Person1#은 케이티의 평가서를 살펴보고, 케이티에게 늦게 도착하고, 고객이 없을 때 무관심하다는 점을 지적한다.
# Summary for index None: #Person1#은 할아버지 생신을 축하하기 위해 깜짝 파티를 계획하고, #Person2#에게 그 파티를 계획하는 데 도움을 청해요.
# Summary for index None: 지안은 지나에게 자기 소개를 하고, 지나는 프리랜서 기자로 일하고 있다. 지하는 로버트에게 지나를 소개한다.
# Summary for index None: #Person1#은 시골이 시끄럽다고 생각했지만, #Person2#는 새들이 울어서 그렇다고 말한다. #Person1#은 이것이 끔찍하다고 느낀다.
# Summary for index None: #Person2#는 대니스에서 샌드위치, 스프, 그리고 음료수를 주문합니다.
# Summary for index None: #Person1#은 제임스에게 TV를 끄고, 재킷을 기다리고, 카메라를 가방에 넣고, 쿠키를 가져가라고 말한다.
# Summary for index None: #Person1#은 테드에게 휴가 계획에 대해 묻는다. 테드는 집에 머무를 예정이지만 #Person1#은 중국에 가려고 한다.
# Summary for index None: #Person1#은 아빠에게 오후에 영화관에 가자고 제안하고, 그들은 영화를 보고 맥도날드에 가기로 결정한다.
# Summary for index None: #Person2#는 도둑들에게 집이 털려서 슬픈 상태입니다. #Person1#은 #Person2#를 위로합니다.
# Summary for index None: 잭은 찰리에게 새 게임을 보여주고 싶어하며, 그는 학교 끝나고 찰리에게 비디오 게임을 하자고 초대한다.
# Summary for index None: #Person2#는 컨트리 음악에 대한 관심을 어떻게 가지게 되었는지, 어떻게 라디오 방송국에서 일하게 되었는지, 그리고 도서관을 만들기 시작한 이유에 대해 #Person1#에게 이야기한다.
# Summary for index None: #Person1#은 옷을 빨아본 적이 없고, 비누를 너무 많이 사용한다. 앨리스는 #Person1#에게 옷을 빨아보라고 권한다.
# Summary for index None: 스티브는 매튜에게 새로운 아파트를 찾고 있다고 말한다. 매튜는 스티브에게 다우 부인이 아파트를 보여줄 수 있을지 물어보라고 제안한다.
# Summary for index None: 프랭크는 벳시에게 승진했으며, 그의 친구들을 위해 큰 파티를 열 것이라고 말한다.
# Submission file created: GPT_finetuned_1128_3.csv

# %%
submission_df = submission_df[['fname', 'summary']]
submission_df.to_csv('/data/ephemeral/home/GPT_finetuned_output_last.csv', index=True)

# %%
submission_df.to_csv('/data/ephemeral/home/GPT_output.csv', index=False)
print("Submission file created: GPT_output.csv")
# Out:
# Submission file created: GPT_output.csv

# %%
# dev summary 길이 통계
dev_df['summary_length'] = dev_df['summary'].apply(len)
dev_summary_stats = dev_df['summary_length'].describe()
print(dev_summary_stats)
# 예측한 dev summary 길이 통계
dev_df['predicted_summary_length'] = dev_df['predicted_summary'].apply(len)
dev_predicted_summary_stats = dev_df['predicted_summary_length'].describe()
print(dev_predicted_summary_stats)
