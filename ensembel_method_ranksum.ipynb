# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunaeee/upstage/blob/main/ensembel_method_ranksum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Let's begin!

# %% [markdown]
# ### 0. Prepare

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt
# Out:
# Collecting wandb==0.16.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1))
#   Downloading wandb-0.16.1-py3-none-any.whl.metadata (9.8 kB)
# Collecting tqdm==4.66.3 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 2))
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.3 MB/s eta 0:00:00
# Collecting pytorch-lightning>=2.1.2 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3))
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting transformers==4.45.0 (from transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4))
#   Downloading transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.2 MB/s eta 0:00:00
# Collecting accelerate==0.28.0 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 5))
#   Downloading accelerate-0.28.0-py3-none-any.whl.metadata (18 kB)
# Collecting rouge==1.0.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 6))
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter==1.0.0 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7))
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting jupyterlab==4.0.9 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyterlab-4.0.9-py3-none-any.whl.metadata (15 kB)
# Collecting evaluate>=0.4.3 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting rouge-score==0.1.2 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 10))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bitsandbytes==0.44.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 11))
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: peft==0.13.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 12)) (0.13.2)
# Collecting dataset==1.6.2 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13))
#   Downloading dataset-1.6.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting scipy==1.14.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 14))
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.6 MB/s eta 0:00:00
# Collecting trl==0.10.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15))
#   Downloading trl-0.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting bert-extractive-summarizer==0.10.1 (from -r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16))
#   Downloading bert_extractive_summarizer-0.10.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (3.1.43)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (75.1.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (4.25.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0->transformers[torch]==4.45.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 4)) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 5)) (2.5.1+cu121)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge==1.0.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (6.5.5)
# Collecting qtconsole (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7))
#   Downloading qtconsole-5.6.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (7.16.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (7.7.1)
# Collecting async-lru>=1.0.0 (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (5.7.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.19.0 (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.2.4)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (6.3.3)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (5.7.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 10)) (3.9.1)
# Collecting sqlalchemy<2.0.0,>=1.3.2 (from dataset==1.6.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13))
#   Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting alembic>=0.6.2 (from dataset==1.6.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13))
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting banal>=1.0.1 (from dataset==1.6.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13))
#   Downloading banal-1.0.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting datasets (from trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15))
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting tyro>=0.5.11 (from trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15))
#   Downloading tyro-0.9.2-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.5.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (3.7.5)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3)) (2024.10.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=2.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3))
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3)) (4.12.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning>=2.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3))
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting dill (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9)) (2.2.2)
# Collecting xxhash (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Collecting Mako (from alembic>=0.6.2->dataset==1.6.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13))
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (17.0.0)
# Collecting dill (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9))
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 3))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (3.11.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.3->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (23.1.0)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (4.3.6)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (2.16.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (4.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2.0.0,>=1.3.2->dataset==1.6.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.28.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15))
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (4.4.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (7.34.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (3.0.13)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (3.0.48)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score==0.1.2->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 10)) (1.4.2)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate>=0.4.3->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 9)) (2024.2)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7))
#   Downloading QtPy-2.4.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.13.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (2.9.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (3.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (4.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 1)) (5.0.1)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.21.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.4)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (2.20.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (7.0.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 7)) (0.8.4)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (24.11.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer==0.10.1->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8)) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.9->-r /content/drive/MyDrive/fastcampus/nlp_project/code/requirements.txt (line 8))
#   Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Downloading wandb-0.16.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.3 MB/s eta 0:00:00
# Downloading tqdm-4.66.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.4 MB/s eta 0:00:00
# Downloading transformers-4.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 115.7 MB/s eta 0:00:00
# Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 21.0 MB/s eta 0:00:00
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyterlab-4.0.9-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 8.9 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 18.8 MB/s eta 0:00:00
# Downloading dataset-1.6.2-py2.py3-none-any.whl (18 kB)
# Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 52.9 MB/s eta 0:00:00
# Downloading trl-0.10.1-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 26.0 MB/s eta 0:00:00
# Downloading bert_extractive_summarizer-0.10.1-py3-none-any.whl (25 kB)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 53.4 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.9 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 23.3 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading banal-1.0.6-py2.py3-none-any.whl (6.1 kB)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 37.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.8 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 19.1 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 7.5 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 10.6 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.5 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.54-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.0 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 53.2 MB/s eta 0:00:00
# Downloading tyro-0.9.2-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 kB 12.5 MB/s eta 0:00:00
# Downloading qtconsole-5.6.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 13.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.3 MB/s eta 0:00:00
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 13.6 MB/s eta 0:00:00
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading QtPy-2.4.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 10.1 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.5 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.4 MB/s eta 0:00:00
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.2 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=277bc110cdff22388e26c155aed97aaf1634bc26aa13976b62f114836a874be7
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: banal, appdirs, xxhash, uri-template, types-python-dateutil, tqdm, sqlalchemy, shtab, scipy, rouge, rfc3986-validator, rfc3339-validator, qtpy, python-json-logger, overrides, Mako, lightning-utilities, json5, jedi, fsspec, fqdn, dill, async-lru, multiprocess, jupyter-server-terminals, jupyter-client, arrow, alembic, wandb, tyro, torchmetrics, rouge-score, isoduration, dataset, bitsandbytes, accelerate, transformers, qtconsole, pytorch-lightning, jupyter-events, datasets, trl, evaluate, bert-extractive-summarizer, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.18.7
#     Uninstalling wandb-0.18.7:
#       Successfully uninstalled wandb-0.18.7
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.1.1
#     Uninstalling accelerate-1.1.1:
#       Successfully uninstalled accelerate-1.1.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# Successfully installed Mako-1.3.6 accelerate-0.28.0 alembic-1.14.0 appdirs-1.4.4 arrow-1.3.0 async-lru-2.0.4 banal-1.0.6 bert-extractive-summarizer-0.10.1 bitsandbytes-0.44.1 dataset-1.6.2 datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fqdn-1.5.1 fsspec-2024.9.0 isoduration-20.11.0 jedi-0.19.2 json5-0.10.0 jupyter-1.0.0 jupyter-client-7.4.9 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.0.9 jupyterlab-server-2.27.3 lightning-utilities-0.11.9 multiprocess-0.70.16 overrides-7.7.0 python-json-logger-2.0.7 pytorch-lightning-2.4.0 qtconsole-5.6.1 qtpy-2.4.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rouge-1.0.1 rouge-score-0.1.2 scipy-1.14.1 shtab-1.7.1 sqlalchemy-1.4.54 torchmetrics-1.6.0 tqdm-4.66.3 transformers-4.45.0 trl-0.10.1 types-python-dateutil-2.9.0.20241003 tyro-0.9.2 uri-template-1.3.0 wandb-0.16.1 xxhash-3.5.0

# %%
import pandas as pd
import os
import re
import json
import yaml
from glob import glob
from tqdm import tqdm
from pprint import pprint
import torch
import pytorch_lightning as pl
from rouge import Rouge # 모델의 성능을 평가하기 위한 라이브러리입니다.

from torch.utils.data import Dataset , DataLoader
import torch
import torch.nn as nn
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoConfig, DataCollatorForLanguageModeling
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import Trainer, TrainingArguments
from transformers import EarlyStoppingCallback

from trl import SFTTrainer, SFTConfig

from transformers import AutoModelForCausalLM, BitsAndBytesConfig
from datasets import Dataset, DatasetDict

import wandb # 모델 학습 과정을 손쉽게 Tracking하고, 시각화할 수 있는 라이브러리입니다.

from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model, PeftModel, PeftConfig

# %%
config_data = {
    "general": {
        "data_path": "/content/drive/MyDrive/fastcampus/nlp_project/data/",
        "model_name": "beomi/Llama-3-Open-Ko-8B", # meta-llama/Llama-2-7b-hf -> beomi/Llama-3-Open-Ko-8B
        # "t5_model_id": "eenzeenee/t5-small-korean-summarization",
        "output_dir": "/content/drive/MyDrive/fastcampus/nlp_project/output/",
    },
    "tokenizer": {
        # 특정 단어들이 분해되어 tokenization이 수행되지 않도록 special_tokens을 지정해줍니다.
        "special_tokens": ['#Person1#', '#Person2#', '#Person3#', '#PhoneNumber#', '#Address#', '#PassportNumber#',
                           '#DateOfBirth#', '#SSN#', '#CardNumber#', '#CarNumber#', '#Email#',
                           '#Person#', '#Person4#', '#Person5#', '#Person6#', '#Person7#']
    },
    "training": {
        "overwrite_output_dir": True,
        "max_input_length": 512,
        "max_target_length": 128,
        "num_train_epochs": 15,
        "batch_size": 8,
        "learning_rate": 1e-5, # 1e-5, optuna: 3e-5
        "per_device_train_batch_size": 10, # 50
        "per_device_eval_batch_size": 2, # 32
        "warmup_ratio": 0.1,
        "weight_decay": 0.01, # 0.01, optuna: 0.005
        "lr_scheduler_type": 'cosine',
        "metric_for_best_model": "loss",
        "optim": 'adamw_torch', # adamw_torch, optuna: adamw_hf
        "gradient_accumulation_steps": 3, # 1
        "evaluation_strategy": 'epoch',
        "save_strategy": 'epoch',
        "save_total_limit": 6, # 5
        "fp16": True,
        "load_best_model_at_end": True,
        "seed": 42,
        "logging_steps": 10,
        "logging_dir": "./logs",
        "logging_strategy": "epoch",
        "predict_with_generate": True,
        "generation_max_length": 200, # 100
        "do_train": True,
        "do_eval": True,
        "early_stopping_patience": 3, # 3
        "early_stopping_threshold": 0, # 0.001
        "report_to": "wandb" # (선택) wandb를 사용할 때 설정합니다.
    },
    "inference": {
        "ckt_path": "/content/drive/MyDrive/fastcampus/nlp_project/output/", # 사전 학습이 진행된 모델의 checkpoint를 저장할 경로를 설정합니다.
        "result_path": "/content/drive/MyDrive/fastcampus/nlp_project/prediction/",
    }
}

# %%
# 모델의 구성 정보를 YAML 파일로 저장합니다.
config_path = "/content/drive/MyDrive/fastcampus/nlp_project/code/config.yaml"
with open(config_path, "w") as file:
    yaml.dump(config_data, file, allow_unicode=True)

# %% [markdown]
# ### 1. Load Dataset

# %% [markdown]
# - RankSum의 실행 단계 설명:
#
# > 문장 평가: 각 문장은 길이(length), 위치(position), TF-IDF 점수(tfidf)와 같은 여러 특성으로 평가됩니다. 이 특성들은 문장이 얼마나 중요한지를 판단하는 데 사용됩니다.
#
# > 가중치 적용: 각 특성에 대해 설정된 가중치를 통해, 어떤 특성이 더 중요한지를 반영합니다. 예를 들어, TF-IDF 점수가 더 중요하다면 해당 가중치를 높게 설정할 수 있습니다.
#
# > 총점 계산: 각 문장의 특성 점수에 가중치를 곱하여 총점을 계산합니다. 이 총점은 문장의 중요성을 나타내며, 이후 요약에서 포함될 문장을 결정하는 데 사용됩니다.
#
# > 문장 정렬: 계산된 총점에 따라 문장을 내림차순으로 정렬하여 가장 중요한 문장을 선택합니다.
#
# > 요약 생성: 상위 문장들을 선택하여 최종 요약을 생성합니다.
#
# - RankSum의 장점:
#
# > 유연성: 사용자가 각 특성의 가중치를 조정할 수 있어, 특정 도메인이나 요구 사항에 맞게 요약의 품질을 개선할 수 있습니다.
#
# > 다양한 특성 반영: 단순히 TF-IDF 점수만 고려하는 것이 아니라, 문장의 길이와 위치와 같은 다양한 요소를 함께 고려함으로써 보다 균형 잡힌 요약을 생성합니다.
#
# > 병렬 처리: joblib를 사용한 병렬 처리를 통해 CPU의 성능을 극대화하여 문장 점수 계산 속도를 향상시킵니다. 이는 대량의 데이터 처리 시 유리합니다.
#
# > 직관적인 접근법: 각 문장의 중요성을 직관적으로 이해할 수 있는 방식으로 평가하기 때문에, 결과를 해석하기 쉽습니다.
#
# > 효율성: RankSum 방식은 상대적으로 간단하면서도 효과적인 방법으로, 복잡한 모델이나 알고리즘 없이도 좋은 품질의 요약을 생성할 수 있습니다.
#
# - RankSum을 사용한 배경:
#
# > 두 모델의 요약 결과가 상이하기에 하나의 요약으로 재작성해보고 싶은 생각이 들었다.
#
# > kbart로 단순 재요약: 33.1824(mistral model) + 49.4275(gpt model) => 30.2376(점수 하락)
#
# > RankSum 요약(파인튜닝 이전): 33.1824(mistral model) + 49.4275(gpt model) => 35.9586(점수 보정)
#
# > RankSum 요약(파인튜닝 이후): 35.9586 => 37.8467(점수 상승)

# %%
# 저장된 config 파일을 불러옵니다.
config_path = "/content/drive/MyDrive/fastcampus/nlp_project/code/config.yaml"

with open(config_path, "r") as file:
    loaded_config = yaml.safe_load(file)

# 불러온 config 파일의 전체 내용을 확인합니다.
pprint(loaded_config)
# Out:
# {'general': {'data_path': '/content/drive/MyDrive/fastcampus/nlp_project/data/',
#              'model_name': 'beomi/Llama-3-Open-Ko-8B',
#              'output_dir': '/content/drive/MyDrive/fastcampus/nlp_project/output/'},
#  'inference': {'ckt_path': '/content/drive/MyDrive/fastcampus/nlp_project/output/',
#                'result_path': '/content/drive/MyDrive/fastcampus/nlp_project/prediction/'},
#  'tokenizer': {'special_tokens': ['#Person1#',
#                                   '#Person2#',
#                                   '#Person3#',
#                                   '#PhoneNumber#',
#                                   '#Address#',
#                                   '#PassportNumber#',
#                                   '#DateOfBirth#',
#                                   '#SSN#',
#                                   '#CardNumber#',
#                                   '#CarNumber#',
#                                   '#Email#',
#                                   '#Person#',
#                                   '#Person4#',
#                                   '#Person5#',
#                                   '#Person6#',
#                                   '#Person7#']},
#  'training': {'batch_size': 8,
#               'do_eval': True,
#               'do_train': True,
#               'early_stopping_patience': 3,
#               'early_stopping_threshold': 0,
#               'evaluation_strategy': 'epoch',
#               'fp16': True,
#               'generation_max_length': 200,
#               'gradient_accumulation_steps': 3,
#               'learning_rate': 1e-05,
#               'load_best_model_at_end': True,
#               'logging_dir': './logs',
#               'logging_steps': 10,
#               'logging_strategy': 'epoch',
#               'lr_scheduler_type': 'cosine',
#               'max_input_length': 512,
#               'max_target_length': 128,
#               'metric_for_best_model': 'loss',
#               'num_train_epochs': 15,
#               'optim': 'adamw_torch',
#               'overwrite_output_dir': True,
#               'per_device_eval_batch_size': 2,
#               'per_device_train_batch_size': 10,
#               'predict_with_generate': True,
#               'report_to': 'wandb',
#               'save_strategy': 'epoch',
#               'save_total_limit': 6,
#               'seed': 42,
#               'warmup_ratio': 0.1,
#               'weight_decay': 0.01},
#  'wandb': {'name': 'llama-8b', 'project': 'nlp_3_team'}}

# %%
# Save results as a CSV file
result_path = loaded_config['inference']['result_path']

# %%
output_file_path1 = os.path.join(result_path, "output_mistral_finetuned.csv")

# CSV 파일 불러오기
df1 = pd.read_csv(output_file_path1)

# %%
output_file_path2 = os.path.join(result_path, "output_gpt2.csv")

# CSV 파일 불러오기
df2 = pd.read_csv(output_file_path2)

# %%
# test data의 구조와 내용을 확인합니다.
data_path = loaded_config['general']['data_path']
train_df = pd.read_csv(os.path.join(data_path,'train.csv'))
test_df = pd.read_csv(os.path.join(data_path,'test.csv'))

# %%
# Generate summaries
summaries1 = df1['summary'].tolist()
summaries2 = df2['summary'].tolist()
all_summaries = []
dash_line = '-'.join('' for x in range(100))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
from joblib import Parallel, delayed

nltk.download('punkt')
nltk.download('punkt_tab')

def calculate_sentence_score(sentence, index, tfidf_matrix):
    """주어진 문장의 점수를 계산합니다."""
    score = {
        'index': index,
        'text': sentence,
        'length': len(sentence.split()),
        'position': 1 / (index + 1),  # 위치 점수
        'tfidf': np.sum(tfidf_matrix[index])  # TF-IDF 점수
    }
    return score

def calculate_sentence_scores(sentences, tfidf_matrix):
    """cpu의 속도를 개선하고자 병렬로 계산합니다."""
    scores = Parallel(n_jobs=-1)(
        delayed(calculate_sentence_score)(sentence, i, tfidf_matrix)
        for i, sentence in enumerate(sentences)
    )
    return scores

def normalize_scores(scores):
    """점수를 정규화 계산합니다."""
    features = ['length', 'position', 'tfidf']
    for feature in features:
        values = np.array([score[feature] for score in scores])
        max_score = values.max()
        min_score = values.min()
        if max_score > min_score:
            for score in scores:
                score[feature] = (score[feature] - min_score) / (max_score - min_score)
        else:
            for score in scores:
                score[feature] = 0
    return scores

def rank_sum(scores, weights):
    total_scores = np.zeros(len(scores))

    for feature, weight in weights.items():
        total_scores += np.array([score[feature] * weight for score in scores])

    for i, score in enumerate(scores):
        score['total'] = total_scores[i]

    return sorted(scores, key=lambda x: x['total'], reverse=True)

def generate_summary_ranksum(text1, text2, num_sentences=3):
    # 두 텍스트 결합
    full_text = text1 + " " + text2

    # 문장 분리
    sentences = sent_tokenize(full_text)

    # TF-IDF 계산
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(sentences).toarray()

    # 문장 점수 계산 (병렬 처리)
    scores = calculate_sentence_scores(sentences, tfidf_matrix)

    # 점수 정규화
    normalized_scores = normalize_scores(scores)

    # 가중치 설정 (필요에 따라 조정 가능)
    weights = {
        'length': 0.1,
        'position': 0.4,
        'tfidf': 0.5
    }

    # RankSum 적용
    ranked_sentences = rank_sum(normalized_scores, weights)

    # 상위 문장 선택
    top_sentences = sorted(ranked_sentences[:num_sentences], key=lambda x: x['index'])

    # 요약 생성
    summary = ' '.join(sentence['text'] for sentence in top_sentences)

    return summary
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
for idx in range(len(summaries1)):
    # Generate the combined summary
    final_summary = generate_summary_ranksum(summaries1[idx], summaries2[idx])

    print(f"\n##{idx}")
    print('\n')
    print(dash_line)
    print('\n')
    print("Mistral Summary:")
    print(summaries1[idx])
    print('\n')
    print("GPT Summary:")
    print(summaries2[idx])
    print('\n')
    print(dash_line)
    print('\n')
    print("Generated Summary:")
    print(final_summary)
    all_summaries.extend([final_summary])
    print('\n')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# #Person1#은 자리에서 잠을 자려고 한다. #Person2#은 전화기를 놓아 둬야 한다고 말한다. #Person1#은 깨어나는 시간을 놓치지 않도록 한다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 전화기를 뽑고, #Person1#은 #Person2#가 깨울 것이라고 생각합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#은 전화기를 놓아 둬야 한다고 말한다. #Person1#은 깨어나는 시간을 놓치지 않도록 한다. #Person1#과 #Person2#는 전화기를 뽑고, #Person1#은 #Person2#가 깨울 것이라고 생각합니다.
#
#
#
# ##279
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 선생님과 중국 음식과 서양 음식 중 어떤 것을 드시고 싶으신가요?
# #Person2#는 중국 음식을 먹고 싶어요.
# #Person1#은 이 세트 메뉴를 드실건가요, 아니면 식당에서 식사하실 건가요?
# #Person2#는 여기서 먹을게요.
# #Person1#은 앞에 있는 테이블을 내려주세요. 그게 더 편합니다.
# #Person2#는 아, 감사합니다. 정말 친절하시네요.
# #Person1#은 어떤 걸 마시고 싶으신가요, 우유, 차, 커피, 오렌지 주스, 아니면
#
#
# GPT Summary:
# #Person1#이 #Person2#에게 중국 음식을 추천하고, #Person2#가 2인분 식사를 주문하는 데 도움을 줍니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 선생님과 중국 음식과 서양 음식 중 어떤 것을 드시고 싶으신가요? #Person1#은 이 세트 메뉴를 드실건가요, 아니면 식당에서 식사하실 건가요? #Person1#은 어떤 걸 마시고 싶으신가요, 우유, 차, 커피, 오렌지 주스, 아니면 #Person1#이 #Person2#에게 중국 음식을 추천하고, #Person2#가 2인분 식사를 주문하는 데 도움을 줍니다.
#
#
#
# ##280
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 식사를 위해 필요한 식기를 가져와 줄을 서서 식당에 도착했다. #Person1#은 자신이 가져온 식기를 확인하고, #Person2#는 줄을 서서 식당에 도착했다. #Person1#은 냄새가 좋은 음식을 먹고 싶어하고, #Person2#는 그런 음식을 좋아하지 않는다고 말한다.
#
#
# GPT Summary:
# #Person2#와 #Person1#은 식사를 위해 줄을 서고 있습니다. #Person1#은 크림 케이크를 좋아하지만, #Person2#는 달다고 생각합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 식사를 위해 필요한 식기를 가져와 줄을 서서 식당에 도착했다. #Person1#은 자신이 가져온 식기를 확인하고, #Person2#는 줄을 서서 식당에 도착했다. #Person1#은 냄새가 좋은 음식을 먹고 싶어하고, #Person2#는 그런 음식을 좋아하지 않는다고 말한다.
#
#
#
# ##281
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 루시와 그의 친구가 노래를 부르기 위해 준비를 하고 있습니다. 그러나 루시는 노래를 부르기 전에 스탠리의 노래를 듣고 싶어합니다. 따라서 그의 친구는 루시의 요청에 따라 엘비스의 노래를 틀어줍니다.
#
#
# GPT Summary:
# 루시는 노래를 듣는 것을 좋아하고, 노래 부를 사람이 없기 때문에 스탠리가 노래하는 것을 기다립니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 루시와 그의 친구가 노래를 부르기 위해 준비를 하고 있습니다. 따라서 그의 친구는 루시의 요청에 따라 엘비스의 노래를 틀어줍니다. 루시는 노래를 듣는 것을 좋아하고, 노래 부를 사람이 없기 때문에 스탠리가 노래하는 것을 기다립니다.
#
#
#
# ##282
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 영화관의 영향력을 높이기 위해 DVD 산업의 도전에 대해 이야기합니다. #Person2#는 영화관이 사람들을 만나는 공간이어야 한다고 생각하며, 영화 상영의 개념을 혁신해야 한다고 말합니다.
#
#
# GPT Summary:
# #Person2#는 홈 비디오 플레이어가 영화관을 대체할 것이라고 생각합니다. 그래서 그는 영화 상영의 개념을 혁신해야 한다고 생각합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 영화관의 영향력을 높이기 위해 DVD 산업의 도전에 대해 이야기합니다. #Person2#는 영화관이 사람들을 만나는 공간이어야 한다고 생각하며, 영화 상영의 개념을 혁신해야 한다고 말합니다. 그래서 그는 영화 상영의 개념을 혁신해야 한다고 생각합니다.
#
#
#
# ##283
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 이 갈색 드레스에 대해 이야기하고 다른 소재로는 뭐가 있는지 물어봅니다. #Person2#는 흰색을 원하며, #Person1#은 봄에는 면 드레스가 적합하다고 설명합니다.
#
#
# GPT Summary:
# #Person2#가 갈색 드레스를 입고 있지만 #Person1#은 흰색 드레스를 추천합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 이 갈색 드레스에 대해 이야기하고 다른 소재로는 뭐가 있는지 물어봅니다. #Person2#는 흰색을 원하며, #Person1#은 봄에는 면 드레스가 적합하다고 설명합니다. #Person2#가 갈색 드레스를 입고 있지만 #Person1#은 흰색 드레스를 추천합니다.
#
#
#
# ##284
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 아빠와 아들이 아빠가 매주 토요일마다 잊어버리는 돈을 대화하며, 은행에 가서 돈을 받아 일부를 저금하고 나머지는 가난한 사람들에게 주고 나머지는 책을 사려고 한다는 내용을 요약한다.
#
#
# GPT Summary:
# 조슈아가 아빠에게 13달러의 용돈을 받으려고 하지만, 아빠는 그것을 잊어버렸다. 그들은 돈을 어떻게 사용할지에 대해 이야기한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 아빠와 아들이 아빠가 매주 토요일마다 잊어버리는 돈을 대화하며, 은행에 가서 돈을 받아 일부를 저금하고 나머지는 가난한 사람들에게 주고 나머지는 책을 사려고 한다는 내용을 요약한다. 조슈아가 아빠에게 13달러의 용돈을 받으려고 하지만, 아빠는 그것을 잊어버렸다. 그들은 돈을 어떻게 사용할지에 대해 이야기한다.
#
#
#
# ##285
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 마이크의 생일 파티에 초대받았다. #Person2#도 초대받았다. #Person1#은 파티 시작 시간을 물어본다. #Person2#는 차로 파티에 갈 것이다. #Person1#은 고마워한다.
#
#
# GPT Summary:
# #Person1#은 마이크의 파티에 초대받았지만 시간을 알지 못한다. #Person2#는 #Person1#에게 차로 같이 가자고 제안한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 마이크의 생일 파티에 초대받았다. #Person1#은 마이크의 파티에 초대받았지만 시간을 알지 못한다. #Person2#는 #Person1#에게 차로 같이 가자고 제안한다.
#
#
#
# ##286
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 소포를 우등 우편으로 보내고 싶어요.
# #Person2#: 보험을 원하시나요?
# #Person1#: 네, 50달러로 부탁드려요. 그리고 우표도 좀 필요한데요--22장짜리 한 권이랑 항공 우표 세 장이요.
# #Person2#: 그건 저기 일반 배송 옆에 있는 우표 창구에서 받아야 해요.
# #Person1#: 그곳에서도 제가 현금으로 주문할 수 있죠?
# #Person2#: 아니요, 그건 왼쪽으로 창구 세 개를 지나가면 있어요.
#
# #Person1#은 소포를 우등 우편으로 보내고 ��
#
#
# GPT Summary:
# #Person1#은 #Person2#의 도움을 받아 우편물을 보내고 우표를 구입합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 소포를 우등 우편으로 보내고 싶어요. #Person2#: 그건 저기 일반 배송 옆에 있는 우표 창구에서 받아야 해요. #Person1#은 소포를 우등 우편으로 보내고 �� #Person1#은 #Person2#의 도움을 받아 우편물을 보내고 우표를 구입합니다.
#
#
#
# ##287
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 태풍과 지진에 대해 이야기하며 중국의 역사적인 자연 재해에 대해 이야기합니다. #Person2#는 중국의 지진 경험과 그들이 마주했던 어려움에 대해 이야기합니다. 이 대화는 인간 간의 사랑과 생명의 중요성에 대해 이야기하며, 인간들이 어려움을 극복하고 협력하는 가치를 강조합니다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 지진에 대해 이야기하고, #Person2#는 중국의 지진에 대한 경험을 공유합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 태풍과 지진에 대해 이야기하며 중국의 역사적인 자연 재해에 대해 이야기합니다. #Person2#는 중국의 지진 경험과 그들이 마주했던 어려움에 대해 이야기합니다. 이 대화는 인간 간의 사랑과 생명의 중요성에 대해 이야기하며, 인간들이 어려움을 극복하고 협력하는 가치를 강조합니다.
#
#
#
# ##288
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 장마가 시작되면서 비가 심하게 내리고 있는 날씨에 대해 이야기합니다. #Person2#는 장마가 곧 끝날 것으로 예상하며, 이 날씨에 대해 신경 쓰지 않는 것 같습니다. #Person1#은 이런 습하고 추운 날씨를 견디기 힘들어하지만, #Person2#는 이런 날씨에 익숙하다고 말합니다.
#
#
# GPT Summary:
# #Person1#은 날씨가 좋지 않다고 생각하지만, #Person2#는 이 날씨에 익숙하다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 장마가 시작되면서 비가 심하게 내리고 있는 날씨에 대해 이야기합니다. #Person2#는 장마가 곧 끝날 것으로 예상하며, 이 날씨에 대해 신경 쓰지 않는 것 같습니다. #Person1#은 이런 습하고 추운 날씨를 견디기 힘들어하지만, #Person2#는 이런 날씨에 익숙하다고 말합니다.
#
#
#
# ##289
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 배구 경기 후에 올림픽 기념품 가게에 가서 선물을 사러 둘러보기로 결정합니다. #Person1#은 가족들에게 선물을 사는 것을 생각하고, #Person2#도 마찬가지로 올림픽 마스코트를 구매하기 위해 준비했습니다. 그들은 올림픽 마스코트가 인기가 많고 가격이 비싸다는 것을 알고 있으며, 세트를 구매할 때 할인을 받을 수 있는지 물어봅니다. 그러나 상인은 올림픽 기념품이 인기가 많아 할인을 주지 않는다고 답합니
#
#
# GPT Summary:
# #Person1#과 #Person2#는 배구 경기 후에 올림픽 기념품 가게에 가서 둘러보기로 계획하고, 그들은 어떤 것을 살지 결정하지 못했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 배구 경기 후에 올림픽 기념품 가게에 가서 선물을 사러 둘러보기로 결정합니다. 그들은 올림픽 마스코트가 인기가 많고 가격이 비싸다는 것을 알고 있으며, 세트를 구매할 때 할인을 받을 수 있는지 물어봅니다. 그러나 상인은 올림픽 기념품이 인기가 많아 할인을 주지 않는다고 답합니 #Person1#과 #Person2#는 배구 경기 후에 올림픽 기념품 가게에 가서 둘러보기로 계획하고, 그들은 어떤 것을 살지 결정하지 못했습니다.
#
#
#
# ##290
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 팬을 구매하기 위해 상품의 크기와 무게에 대해 이야기합니다. #Person2#는 알루미늄 팬을 제안하고, 나무 핸들이 달린 팬을 보여줍니다. 결제 방법에 대해 논의하고, 뚜껑의 상태에 대해 이야기합니다.
#
#
# GPT Summary:
# #Person1#은 팬을 사고 싶어합니다. #Person2#는 #Person1#에게 16인치 알루미늄 팬을 추천하고, #Person1#은 그것을 구매합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 팬을 구매하기 위해 상품의 크기와 무게에 대해 이야기합니다. #Person2#는 알루미늄 팬을 제안하고, 나무 핸들이 달린 팬을 보여줍니다. #Person2#는 #Person1#에게 16인치 알루미늄 팬을 추천하고, #Person1#은 그것을 구매합니다.
#
#
#
# ##291
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 일하러 돌아가야 하는데 할 일이 쌓여 있어서 퇴근 후에 만나기로 합니다. #Person2#도 같은 시간에 만나기로 합의하고 5시에 만납니다.
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 퇴근 후에 만나자고 말합니다. 설정된 시간은 5시입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 일하러 돌아가야 하는데 할 일이 쌓여 있어서 퇴근 후에 만나기로 합니다. #Person2#도 같은 시간에 만나기로 합의하고 5시에 만납니다. #Person1#은 #Person2#에게 퇴근 후에 만나자고 말합니다.
#
#
#
# ##292
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 베커 씨에게 워싱턴의 공무원들이 자신들의 일을 즐기는 이유를 이해할 수 있을 것이라고 말합니다. #Person2#는 그 이유에 대해 설명하고, 많은 사람들이 성인이 된 후로 평생 연방 정부에서 일하는 것이 보람 있고 안정적인 경력이라고 말합니다. #Person1#은 대부분의 관료들이 게으르다고 생각했지만, #Person2#는 대부분의 연방 직원들은 정직하고 열심히 일하는 전문가들이라고 말합니다.
#
#
# GPT Summary:
# 베커 씨가 #Person1#에게 정부 서비스는 보람 있고 안정적인 경력이며 금전적으로 보수가 좋다고 말하고, #Person1#은 베커 씨에게 대부분의 관료들이 게으르다고 생각한다고 말한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 베커 씨에게 워싱턴의 공무원들이 자신들의 일을 즐기는 이유를 이해할 수 있을 것이라고 말합니다. #Person2#는 그 이유에 대해 설명하고, 많은 사람들이 성인이 된 후로 평생 연방 정부에서 일하는 것이 보람 있고 안정적인 경력이라고 말합니다. 베커 씨가 #Person1#에게 정부 서비스는 보람 있고 안정적인 경력이며 금전적으로 보수가 좋다고 말하고, #Person1#은 베커 씨에게 대부분의 관료들이 게으르다고 생각한다고 말한다.
#
#
#
# ##293
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 피트와 헨리 존슨이 만나기를 원하는 피트는 존슨 씨가 1년 넘게 근무하고 있는 베이징 사무소에서 도움을 줄 수 있다고 말합니다. 그들은 같은 도시 출신인 것 같다고 생각하며, 존슨 씨는 브루클린에서 태어나고 자랐다고 합니다. 피트와 존슨은 중국에서 생활하는 외국인이라고 말하며, 중국에서 생활하는 것은 어떤 것인지에 대해 이야기합니다. 그들은 노래방에서 놀러 갈 계획이 있다고 말하며, 노래방에서
#
#
# GPT Summary:
# 피트는 헨리 존슨을 만나고, 헨리는 중국에서 생활하고 있다. 그들은 저녁 식사를 하러 가고, 그 후에 노래방에 가기로 결정했다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 피트와 헨리 존슨이 만나기를 원하는 피트는 존슨 씨가 1년 넘게 근무하고 있는 베이징 사무소에서 도움을 줄 수 있다고 말합니다. 그들은 같은 도시 출신인 것 같다고 생각하며, 존슨 씨는 브루클린에서 태어나고 자랐다고 합니다. 그들은 노래방에서 놀러 갈 계획이 있다고 말하며, 노래방에서 피트는 헨리 존슨을 만나고, 헨리는 중국에서 생활하고 있다.
#
#
#
# ##294
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 존스 선생님은 줄리에게 일주일 동안 수업에서 볼 수 없었던 이유에 대해 물어봅니다. 줄리는 아파서 이유로 수업을 듣지 못했다고 말합니다. 존스 선생님은 그녀가 식중독이라고 생각하고, 그녀는 다른 사람들과 같이 좋은 식당에서 점심을 먹었지만 프라이드 치킨을 사서 먹었다고 합니다. 존스 선생님은 프라이드 치킨이 병의 원인이라고 생각하고, 다른 사람들은 아프지 않았다고 합니다. 그러나 지금은 좀 나아진 것
#
#
# GPT Summary:
# 존스 선생님은 줄리가 일주일 동안 아프다는 것을 알게 되고, 그녀는 식중독이었고, 수업을 따라갈 수 있도록 노트를 받았다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 존스 선생님은 줄리에게 일주일 동안 수업에서 볼 수 없었던 이유에 대해 물어봅니다. 존스 선생님은 그녀가 식중독이라고 생각하고, 그녀는 다른 사람들과 같이 좋은 식당에서 점심을 먹었지만 프라이드 치킨을 사서 먹었다고 합니다. 그러나 지금은 좀 나아진 것 존스 선생님은 줄리가 일주일 동안 아프다는 것을 알게 되고, 그녀는 식중독이었고, 수업을 따라갈 수 있도록 노트를 받았다.
#
#
#
# ##295
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 마이크, 이리 와보렴.
# #Person2#: 가고 있어요, 엄마. 엄마가 정말 바쁜 것 같네요. 오늘 저녁에 누가 오나요?
# #Person1#: 그래, 오늘 저녁에 친구들이 몇 명 올 예정이야. 아직 준비할 게 많아.
# #Person2#: 도와줄 수 있는 게 있을까요?
# #Person1#: 그럼, 아직 음료를 준비해야 해. 커피, 물, 과일 주스, 콜라가 필요하단다.
# #Person2#: 제가 과일 주스랑 콜라를 사러 간 다음에 커피를 내릴게
#
#
# GPT Summary:
# 마이크는 엄마에게 도움을 제안한다. 엄마는 음료를 준비하라고 요청하고, 마이크는 커피를 내릴 수 있다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 마이크, 이리 와보렴. #Person2#: 제가 과일 주스랑 콜라를 사러 간 다음에 커피를 내릴게 마이크는 엄마에게 도움을 제안한다. 엄마는 음료를 준비하라고 요청하고, 마이크는 커피를 내릴 수 있다.
#
#
#
# ##296
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 베를린에 오신 것을 환영하며 다시 만난다. #Person2#는 19시간 밖에 안 됐으니까 꽤 불편한 여행이었다고 말한다. #Person1#은 비행기보다 친환경적이라는 이유로 버스를 탔다고 한다.
#
#
# GPT Summary:
# #Person1#은 베를린에 도착한 #Person2#를 맞이하고, #Person2#는 19시간이 걸린 버스 여행에 대해 불평한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 베를린에 오신 것을 환영하며 다시 만난다. #Person2#는 19시간 밖에 안 됐으니까 꽤 불편한 여행이었다고 말한다. #Person1#은 베를린에 도착한 #Person2#를 맞이하고, #Person2#는 19시간이 걸린 버스 여행에 대해 불평한다.
#
#
#
# ##297
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 이런 종류의 일을 해본 적이 있나요?
# #Person2#: 아니요, 없어요. 그런데 잘할 수 있을 거라 확신해요.
# #Person1#: 알다시피 이 일을 맡게 되면 주말에도 일해야 해요.
# #Person2#: 오, 괜찮습니다.
# #Person1#: 여행을 좋아하고 사람들을 만나는 것을 좋아하나요?
# #Person2#: 오. 네. 사실 그래서 이 직업이 정말로 흥미로워요.
# #Person1#: 외국어를 할 줄 아나요?
# #Person2#: 네, 독일어랑 프랑스어를 꽤 잘하고, 일본어를 대략
#
#
# GPT Summary:
# #Person2#는 일과 관련된 질문에 대답하고 있습니다. 그는 외국어를 할 줄 알며, 목소리도 맑습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 이런 종류의 일을 해본 적이 있나요? #Person1#: 알다시피 이 일을 맡게 되면 주말에도 일해야 해요. #Person2#: 네, 독일어랑 프랑스어를 꽤 잘하고, 일본어를 대략 #Person2#는 일과 관련된 질문에 대답하고 있습니다.
#
#
#
# ##298
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 어제 전화를 받지 못했다고 말하며, #Person2#은 소풍 일정에 대해 이야기한다. 소풍은 베이하이 공원에서 먹었으며, 점심 먹은 다음에는 강가를 따라 산책하고 아름다운 경치를 봤다. 그 다음에는 카페에서 만나 책을 돌려주려고 했다.
#
#
# GPT Summary:
# 에이미는 어제 지미에게 전화를 했지만 지미가 전화를 받지 않았다. 왜냐하면 지미는 베이하이 공원에서 제니와 빌과 함께 놀았기 때문이다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 어제 전화를 받지 못했다고 말하며, #Person2#은 소풍 일정에 대해 이야기한다. 소풍은 베이하이 공원에서 먹었으며, 점심 먹은 다음에는 강가를 따라 산책하고 아름다운 경치를 봤다. 왜냐하면 지미는 베이하이 공원에서 제니와 빌과 함께 놀았기 때문이다.
#
#
#
# ##299
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 피터에게 차 한잔 하지 않으실래요?
# #Person2#: 아직 안 돼요, 먼저 정원에 물을 줘야 해요.
# #Person1#: 지금 바로 물을 줘야 하는 건가요?
# #Person2#: 걱정돼서 그래요. 너무 건조하잖아요.
# #Person1#: 정말 귀찮네요!
# #Person2#: 작년 여름에도 무척 건조했어요. 기억 안 나세요? 매일 물을 줘야 했어요.
# #Person1#: 그럼, 혼자 차를 마실래요. 그거 빨리 끝났네요! 이미 다 끝냈나요?
#
#
# GPT Summary:
# 피터는 정원에 물을 주려고 하지만, 비가 내리기 때문에 차를 마실 수 있게 됩니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 피터에게 차 한잔 하지 않으실래요? #Person2#: 아직 안 돼요, 먼저 정원에 물을 줘야 해요. 피터는 정원에 물을 주려고 하지만, 비가 내리기 때문에 차를 마실 수 있게 됩니다.
#
#
#
# ##300
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 비상 회의를 소집하여 문제를 해결하기 위해 노력하고 있습니다. #Person2#는 회의 메모를 보내주기로 합의하고, 켄이 돌아오면 오후로 일정을 잡아주기로 합니다. 이 주문을 잃어선 안 되는 상황에서 대화의 주제는 비상 회의와 주문 잃어 있음입니다.
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 켄이 돌아오면 오늘 오후로 회의 일정을 잡으라고 지시하지만, 그는 돌아오지 않을 것입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#는 회의 메모를 보내주기로 합의하고, 켄이 돌아오면 오후로 일정을 잡아주기로 합니다. 이 주문을 잃어선 안 되는 상황에서 대화의 주제는 비상 회의와 주문 잃어 있음입니다. #Person1#은 #Person2#에게 켄이 돌아오면 오늘 오후로 회의 일정을 잡으라고 지시하지만, 그는 돌아오지 않을 것입니다.
#
#
#
# ##301
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 도움을 요청하고, #Person2#는 우표를 구매하기 위해 편지에 붙일 우표가 필요하다고 말합니다. #Person1#은 우편물의 무게를 알아야 하며, 등기로 보내기를 원하는 경우 총 비용이 7달러이며, 10달러 지폐를 지불하고 영수증과 거스름돈을 받습니다.
#
#
# GPT Summary:
# #Person2#는 편지에 우표가 필요하다. #Person1#는 #Person2#에게 무게를 재서 7달러의 등기를 추천한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 도움을 요청하고, #Person2#는 우표를 구매하기 위해 편지에 붙일 우표가 필요하다고 말합니다. #Person1#은 우편물의 무게를 알아야 하며, 등기로 보내기를 원하는 경우 총 비용이 7달러이며, 10달러 지폐를 지불하고 영수증과 거스름돈을 받습니다. #Person1#는 #Person2#에게 무게를 재서 7달러의 등기를 추천한다.
#
#
#
# ##302
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 스미스 씨에게 심한 감염이 있다고 말하고, 의사 선생님이 치료할 수 있는 약을 처방한다. 약은 병원 내 약국에서 구매할 수 있으며, 처방전을 받아 4층 약국으로 가져가면 된다.
#
#
# GPT Summary:
# 스미스 씨가 심한 감염을 치료하기 위한 약을 처방받았다. #Person1#은 병원의 약국을 추천했다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 스미스 씨에게 심한 감염이 있다고 말하고, 의사 선생님이 치료할 수 있는 약을 처방한다. 약은 병원 내 약국에서 구매할 수 있으며, 처방전을 받아 4층 약국으로 가져가면 된다. 스미스 씨가 심한 감염을 치료하기 위한 약을 처방받았다.
#
#
#
# ##303
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 중국의 예술과 공예품에 대해 설명하고자 합니다. #Person2#는 집으로 가져갈 수 있는 가볍고 훌륭한 품질의 중국 특유의 상품을 찾고 있습니다. #Person1#은 자수, 바틱, 종이절편 등 다양한 상품들을 추천하며, #Person2#는 자수품 몇 가지를 보고 싶어합니다.
#
#
# GPT Summary:
# #Person1#은 중국 예술과 공예품을 추천하고, #Person2#는 자수품 몇 가지를 보기로 결정했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#는 집으로 가져갈 수 있는 가볍고 훌륭한 품질의 중국 특유의 상품을 찾고 있습니다. #Person1#은 자수, 바틱, 종이절편 등 다양한 상품들을 추천하며, #Person2#는 자수품 몇 가지를 보고 싶어합니다. #Person1#은 중국 예술과 공예품을 추천하고, #Person2#는 자수품 몇 가지를 보기로 결정했습니다.
#
#
#
# ##304
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 에펠탑에 대해 이야기하며 그 설계자인 구스타브 에펠의 이름을 언급합니다. 이 건물은 1930년까지 세계에서 가장 높은 구조물로 기록되어 있었습니다.
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 에펠탑이 1889년 세계 박람회를 위해 지어졌으며, 그 설계자인 구스타브 에펠의 이름을 딴 것이라고 설명했다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 에펠탑에 대해 이야기하며 그 설계자인 구스타브 에펠의 이름을 언급합니다. 이 건물은 1930년까지 세계에서 가장 높은 구조물로 기록되어 있었습니다. #Person1#은 #Person2#에게 에펠탑이 1889년 세계 박람회를 위해 지어졌으며, 그 설계자인 구스타브 에펠의 이름을 딴 것이라고 설명했다.
#
#
#
# ##305
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 영어를 할 줄 아는 브라이언과 대화를 나누고 있습니다. 브라이언은 대학에서 배웠다고 말하며, 영어를 잘 하고 있다는 것을 입증합니다. 그는 미국에 3주 동안 있었다고 밝히고, 아내도 같이 계셨다고 합니다. 그러나 캘리포니아에 가본 적이 없다고 말합니다.
#
#
# GPT Summary:
# 브라이언은 대학에서 영어를 배웠고, 아내와 함께 3주 동안 미국에 머물렀습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 브라이언은 대학에서 배웠다고 말하며, 영어를 잘 하고 있다는 것을 입증합니다. 그는 미국에 3주 동안 있었다고 밝히고, 아내도 같이 계셨다고 합니다. 브라이언은 대학에서 영어를 배웠고, 아내와 함께 3주 동안 미국에 머물렀습니다.
#
#
#
# ##306
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 마치 뜨거운 벽돌 위의 고양이처럼, 당신이 말하듯이. 전혀 듣고 있지 않은 것 같아요.
# #Person2#: 미안해요, 그를 걱정해서 그래요. 알잖아요, 그는 한 시간 전에 여기 있어야 했어요.
# #Person1#: 그를 걱정하지 마세요, 그는 이미 성인이고 제 생각에는 그 스스로를 잘 챙길 수 있을 거예요.
# #Person2#: 하지만 그는 아직 돌아오지 않았어요.
# #Person1#: 아마 지금 집으로 오는 길일지도 몰라요.
#
# 대화의 주제:
#
#
# GPT Summary:
# #Person1#은 #Person2#가 불안해하는 이유에 대해 이해하지 못하며, #Person2#는 그를 걱정하고 있다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 마치 뜨거운 벽돌 위의 고양이처럼, 당신이 말하듯이. #Person1#: 그를 걱정하지 마세요, 그는 이미 성인이고 제 생각에는 그 스스로를 잘 챙길 수 있을 거예요. 대화의 주제: #Person1#은 #Person2#가 불안해하는 이유에 대해 이해하지 못하며, #Person2#는 그를 걱정하고 있다.
#
#
#
# ##307
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 그걸 하면 큰 문제에 휘말릴 거야.
# #Person2#: 왜 그렇게 생각해?
# #Person1#: 우리가 하는 일에 아무 문제가 없다고 보지 않아! 그게 바로 문제야. 이런 종류의 일에서는 문제가 처음에는 항상 나타나지 않아.
# #Person2#: 하지만 모든 것이 너무 쉽게 진행되었어.
# #Person1#: 모든 것이 순조롭게 진행되었어. 우리가 계획한 대로! 그건 사실일 수 있지만, 네가 그걸 하면 앞으로 문제가 생길 거야. 넌 항상 그�
#
#
# GPT Summary:
# #Person1#은 #Person2#가 하면 큰 문제에 휘말릴 것이라고 생각하지만, #Person2#는 일의 긍정적인 면을 보지 않기 때문에 동의하지 않는다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 그걸 하면 큰 문제에 휘말릴 거야. #Person1#: 우리가 하는 일에 아무 문제가 없다고 보지 않아! 넌 항상 그� #Person1#은 #Person2#가 하면 큰 문제에 휘말릴 것이라고 생각하지만, #Person2#는 일의 긍정적인 면을 보지 않기 때문에 동의하지 않는다.
#
#
#
# ##308
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 존이 일주일에 일곱 번 그녀와 데이트를 하고 있다. 그녀는 그를 좋아하고 있다. 그들은 서로 잘 어울려 완벽한 짝이다.
#
#
# GPT Summary:
# #Person1#은 존이 그녀와 일주일에 일곱 번 데이트를 한다고 말하고, #Person2#는 그들이 완벽한 짝이라고 생각한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 존이 일주일에 일곱 번 그녀와 데이트를 하고 있다. 그들은 서로 잘 어울려 완벽한 짝이다. #Person1#은 존이 그녀와 일주일에 일곱 번 데이트를 한다고 말하고, #Person2#는 그들이 완벽한 짝이라고 생각한다.
#
#
#
# ##309
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 런던의 역사적인 장소에 대해 설명하고 있습니다. 그는 런던의 역사적인 인물들과 그들의 업적에 대해 이야기하고 있습니다. 그는 런던 타워를 방문하고 싶어하고 있습니다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 런던의 역사적인 장소들을 방문하는 것을 기대하고 있습니다. #Person1#은 유명한 성과 감옥을, #Person2#는 밀랍 인형 박물관을 보고 싶어합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 그는 런던의 역사적인 인물들과 그들의 업적에 대해 이야기하고 있습니다. #Person1#과 #Person2#는 런던의 역사적인 장소들을 방문하는 것을 기대하고 있습니다. #Person1#은 유명한 성과 감옥을, #Person2#는 밀랍 인형 박물관을 보고 싶어합니다.
#
#
#
# ##310
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 학년에 새로운 과목이 추가되어 숙제를 더 많이 해야 한다고 말합니다. #Person2#는 다니엘이 가장 좋아하는 과목이 과학인 것을 놀랍게 여깁니다. #Person1#은 과학에 관심이 있다고 말하며, 이 과목을 통해 세계를 더 명확하게 알 수 있다고 설명합니다.
#
#
# GPT Summary:
# 다니엘은 과학을 좋아하는 것에 놀란 #Person2#에게, 과학을 통해 더욱 명확하게 주변 세계를 이해할 수 있기 때문이라고 말합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 학년에 새로운 과목이 추가되어 숙제를 더 많이 해야 한다고 말합니다. #Person1#은 과학에 관심이 있다고 말하며, 이 과목을 통해 세계를 더 명확하게 알 수 있다고 설명합니다. 다니엘은 과학을 좋아하는 것에 놀란 #Person2#에게, 과학을 통해 더욱 명확하게 주변 세계를 이해할 수 있기 때문이라고 말합니다.
#
#
#
# ##311
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 베이비 샤워에 참석한 첫 번째 경험이었다. #Person2#는 선물을 준비해줬다. #Person1#은 선물을 받고 감사한다.
#
#
# GPT Summary:
# #Person1#은 멋진 베이비 샤워를 준비해준 #Person2#에게 감사하고, #Person1#이 양수가 터졌다는 것을 알리고 병원에 데려가달라고 요청한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 베이비 샤워에 참석한 첫 번째 경험이었다. #Person1#은 선물을 받고 감사한다. #Person1#은 멋진 베이비 샤워를 준비해준 #Person2#에게 감사하고, #Person1#이 양수가 터졌다는 것을 알리고 병원에 데려가달라고 요청한다.
#
#
#
# ##312
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 중국에 관광하러 가고 싶어하지만, #Person2#는 지금은 안돼.
#
#
# GPT Summary:
# #Person1#은 중국에 가고 싶어하고, #Person2#는 그것이 좋은 생각이라고 생각하지만, 지금은 바빠서 갈 수 없다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 중국에 관광하러 가고 싶어하지만, #Person2#는 지금은 안돼. #Person1#은 중국에 가고 싶어하고, #Person2#는 그것이 좋은 생각이라고 생각하지만, 지금은 바빠서 갈 수 없다.
#
#
#
# ##313
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 카렌과 함께 대화를 나누며 즐거움을 느꼈다. 두 사람은 다음에 다시 만날 것을 약속하고 이별을 하였다.
#
#
# GPT Summary:
# 팀은 카렌에게 인사를 하고 어디선가 다시 만날 것이라고 말한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 카렌과 함께 대화를 나누며 즐거움을 느꼈다. 두 사람은 다음에 다시 만날 것을 약속하고 이별을 하였다. 팀은 카렌에게 인사를 하고 어디선가 다시 만날 것이라고 말한다.
#
#
#
# ##314
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 어제 밤에 마이클과 오토바이를 타고 갔다. #Person2#는 마이클에게 타보게 해준 것에 대해 꽤 좋아했다. #Person1#은 자전거를 사고 싶어하는 이유에 대해 물었고, #Person2#는 자전거가 더 안전하기 때문이라고 말했다.
#
#
# GPT Summary:
# #Person1#은 어제 밤에 마이클을 만나러 갔다. 마이클은 #Person2#에게 자신의 새로운 오토바이를 시도하게 했다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 어제 밤에 마이클과 오토바이를 타고 갔다. #Person2#는 마이클에게 타보게 해준 것에 대해 꽤 좋아했다. #Person1#은 자전거를 사고 싶어하는 이유에 대해 물었고, #Person2#는 자전거가 더 안전하기 때문이라고 말했다.
#
#
#
# ##315
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 언어 실력에 대해 이야기하고 있습니다. #Person2#는 중국어, 영어, 프랑스어를 모두 할 수 있지만, 프랑스어는 간단한 대화 정도만 할 수 있습니다. #Person1#은 영어를 잘 읽고 쓸 수 있다고 생각하며, 영어 실력이 사무 업무를 수행하는 데 충분하다고 말합니다.
#
#
# GPT Summary:
# #Person2#는 #Person1#에게 중국어 외에도 영어와 프랑스어를 할 수 있다고 말하며, 이전에 통역사였다고 말한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#는 중국어, 영어, 프랑스어를 모두 할 수 있지만, 프랑스어는 간단한 대화 정도만 할 수 있습니다. #Person1#은 영어를 잘 읽고 쓸 수 있다고 생각하며, 영어 실력이 사무 업무를 수행하는 데 충분하다고 말합니다. #Person2#는 #Person1#에게 중국어 외에도 영어와 프랑스어를 할 수 있다고 말하며, 이전에 통역사였다고 말한다.
#
#
#
# ##316
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 타일러는 낸시의 여동생입니다. 앤디가 전화했다고 메시지를 전달해주세요.
#
#
# GPT Summary:
# 낸시는 앤디로부터 전화를 받아 메시지를 전달한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 타일러는 낸시의 여동생입니다. 앤디가 전화했다고 메시지를 전달해주세요. 낸시는 앤디로부터 전화를 받아 메시지를 전달한다.
#
#
#
# ##317
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 뉴욕행 513편 비행기 취소에 대해 알게 되었다. #Person2#는 다른 항공사로 예약할 수 있다고 말했다. #Person1#은 줄을 서 있는 것을 싫어한다. #Person2#는 내일 비행기 예약을 할 수 있다고 약속했다.
#
#
# GPT Summary:
# #Person1#은 뉴욕행 513편 비행기가 취소되어 대기열에 섰지만, #Person2#은 #Person1#에게 내일 비행기를 예약하도록 도와줍니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 뉴욕행 513편 비행기 취소에 대해 알게 되었다. #Person2#는 다른 항공사로 예약할 수 있다고 말했다. #Person1#은 뉴욕행 513편 비행기가 취소되어 대기열에 섰지만, #Person2#은 #Person1#에게 내일 비행기를 예약하도록 도와줍니다.
#
#
#
# ##318
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 치즈버거와 밀크쉐이크를 주문하기 위해 버거퀸에 가서 대화를 나눈다. #Person1#은 치즈버거의 인기에 대해 이야기하고, #Person2#는 기다려야 하는 것에 대해 이야기한다. #Person1#은 치즈버거와 프렌치 프라이의 맛을 추천하고, #Person2#는 튀김 음식에 대한 살찌움을 언급한다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 점심에 버거퀸에서 식사를 하기로 결정하고, 그들은 그들의 음식에 대해 이야기하고 있다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 치즈버거와 밀크쉐이크를 주문하기 위해 버거퀸에 가서 대화를 나눈다. #Person1#은 치즈버거와 프렌치 프라이의 맛을 추천하고, #Person2#는 튀김 음식에 대한 살찌움을 언급한다. #Person1#과 #Person2#는 점심에 버거퀸에서 식사를 하기로 결정하고, 그들은 그들의 음식에 대해 이야기하고 있다.
#
#
#
# ##319
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 8킬로그램 초과 수하물을 가지고 있습니다.
# #Person2#는 초과 수하물 요금을 내야 합니다.
# #Person1#은 취약한 물품 표시를 제공하고 가방을 보관할 수 있습니다.
#
#
# GPT Summary:
# #Person2#의 짐이 8킬로그램을 초과하고 #Person1#은 #Person2#에게 초과 수하물 요금을 내라고 요청합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 8킬로그램 초과 수하물을 가지고 있습니다. #Person1#은 취약한 물품 표시를 제공하고 가방을 보관할 수 있습니다. #Person2#의 짐이 8킬로그램을 초과하고 #Person1#은 #Person2#에게 초과 수하물 요금을 내라고 요청합니다.
#
#
#
# ##320
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 목마름을 해소하기 위해 물을 마시고 싶어했다. #Person2#는 소다가 몸에 안 좋다는 것을 알리고, 목마름을 해소하기 위해서는 물을 마시는 것이 좋다고 말했다.
#
#
# GPT Summary:
# #Person1#은 소다를 마시려고 생각했지만, #Person2#는 물을 마시는 것이 더 나을 것이라고 제안합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 목마름을 해소하기 위해 물을 마시고 싶어했다. #Person2#는 소다가 몸에 안 좋다는 것을 알리고, 목마름을 해소하기 위해서는 물을 마시는 것이 좋다고 말했다. #Person1#은 소다를 마시려고 생각했지만, #Person2#는 물을 마시는 것이 더 나을 것이라고 제안합니다.
#
#
#
# ##321
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 매니저 량의 사무실에서 그린 씨의 긴급 사항을 전해야 합니다. 그린 씨는 오늘 해외로 가야 하고, 돌아오면 다시 약속을 잡을 것입니다. 전화주셔서 감사합니다.
#
#
# GPT Summary:
# 왕 묘이 매니저 량에게 전화를 걸어 그린 씨의 일정 변경을 알리고 사과의 말을 전하라고 요청합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 매니저 량의 사무실에서 그린 씨의 긴급 사항을 전해야 합니다. 그린 씨는 오늘 해외로 가야 하고, 돌아오면 다시 약속을 잡을 것입니다. 왕 묘이 매니저 량에게 전화를 걸어 그린 씨의 일정 변경을 알리고 사과의 말을 전하라고 요청합니다.
#
#
#
# ##322
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 30사이즈의 유광 가죽 신발을 원합니다. #Person2#는 신발이 사용하면서 약간 늘어납니다. #Person1#은 이걸로 하겠습니다.
#
#
# GPT Summary:
# #Person1#은 유광 가죽 신발을 구매하고, #Person2#는 신발이 사용하면서 늘어날 수 있다고 말합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 30사이즈의 유광 가죽 신발을 원합니다. #Person2#는 신발이 사용하면서 약간 늘어납니다. #Person1#은 유광 가죽 신발을 구매하고, #Person2#는 신발이 사용하면서 늘어날 수 있다고 말합니다.
#
#
#
# ##323
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 프로젝트 보고서 작성에 대해 상담을 받고 있습니다. #Person2#는 어떻게 보고서를 작성해야 하는지 모르는 것으로 보입니다. #Person1#은 보고서를 웃기게 만들기 위해 노력하고 있습니다.
#
#
# GPT Summary:
# 벤자민은 프로젝트 보고서를 어떻게 써야 하는지 모르고 워커홀릭이다. #Person1#은 벤자민에게 보고서의 구성과 형식에 대해 알려준다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 프로젝트 보고서 작성에 대해 상담을 받고 있습니다. #Person2#는 어떻게 보고서를 작성해야 하는지 모르는 것으로 보입니다. 벤자민은 프로젝트 보고서를 어떻게 써야 하는지 모르고 워커홀릭이다.
#
#
#
# ##324
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 피자 하우스의 마티입니다. 주문을 도와드릴까요?
# #Person2#: 네, 페퍼로니, 올리브, 그리고 치즈 추가한 중간 사이즈 피자 하나 주세요.
# #Person1#: 대형 피자로 변경하시겠어요?
# #Person2#: 아니요, 저 혼자 먹을 거라서요. 피자가 너무 많으면 안 돼요.
# #Person1#: 알겠습니다! 어떤 종류를 원하세요? 오늘의 특별 메뉴가 있습니다. 25% 할인됩니다.
# #Person2#: 해산물 피자로 할게요. 아, 그리고 도우는 얇게
#
#
# GPT Summary:
# #Person2#는 마티의 도움으로 페퍼로니, 올리브, 치즈 추가한 중간 사이즈 피자와 해산물 피자를 주문합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 피자 하우스의 마티입니다. #Person2#: 네, 페퍼로니, 올리브, 그리고 치즈 추가한 중간 사이즈 피자 하나 주세요. 아, 그리고 도우는 얇게 #Person2#는 마티의 도움으로 페퍼로니, 올리브, 치즈 추가한 중간 사이즈 피자와 해산물 피자를 주문합니다.
#
#
#
# ##325
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 메뉴를 보여주시겠습니까?
# #Person2#: 네, 여기 있습니다.
# #Person1#: 저는 새우 칵테일과 토마토 수프를 주문하고 싶고, 메인 코스로는 양파 스테이크를, 그리고 식사 후에는 블랙 커피를 원합니다.
# #Person2#: 죄송합니다만, 오늘은 토마토 수프를 제공하지 않고 있습니다. 하지만 우리는 계란 수프를 제공하고 있습니다, 매우 맛있습니다. 오늘 한번 시도해 보시겠습니까?
# #Person1#: 좋아 보입니다. 시도해 보겠습니다.
# #Person2
#
#
# GPT Summary:
# #Person1#은 오늘의 메뉴를 보고 새우 칵테일, 양파 스테이크, 블랙 커피와 미네랄 워터를 주문합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#: 저는 새우 칵테일과 토마토 수프를 주문하고 싶고, 메인 코스로는 양파 스테이크를, 그리고 식사 후에는 블랙 커피를 원합니다. #Person2#: 죄송합니다만, 오늘은 토마토 수프를 제공하지 않고 있습니다. #Person2 #Person1#은 오늘의 메뉴를 보고 새우 칵테일, 양파 스테이크, 블랙 커피와 미네랄 워터를 주문합니다.
#
#
#
# ##326
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 집에 대해 설명합니다. 집은 멋진 거실, 넓은 식당, 그리고 편안한 침실 3개가 있습니다. 부엌은 현대적이며 냉장고, 전기 스토브, 그리고 식기세척기가 있습니다. 집 안에는 편리하게 사용할 수 있는 화장실이 두 개 있습니다.
#
#
# GPT Summary:
# #Person2#는 집에 대해 #Person1#에게 묻습니다. #Person1#는 그 집을 소개합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 집은 멋진 거실, 넓은 식당, 그리고 편안한 침실 3개가 있습니다. 부엌은 현대적이며 냉장고, 전기 스토브, 그리고 식기세척기가 있습니다. 집 안에는 편리하게 사용할 수 있는 화장실이 두 개 있습니다.
#
#
#
# ##327
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 도움을 요청한 #Person2#에게 부탁을 합니다. #Person2#는 동의하고 작은 봉지 설탕, 여섯 개의 오렌지, 그리고 우유 반 갤런을 사다 줍니다.
#
#
# GPT Summary:
# #Person2#가 3일 전에 구입한 개인용 스테레오에 문제가 있습니다. #Person1#은 #Person2#에게 책임을 묻습니다. #Person2#는 환불을 요청합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 도움을 요청한 #Person2#에게 부탁을 합니다. #Person2#는 동의하고 작은 봉지 설탕, 여섯 개의 오렌지, 그리고 우유 반 갤런을 사다 줍니다. #Person2#가 3일 전에 구입한 개인용 스테레오에 문제가 있습니다.
#
#
#
# ##328
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 기숙사 보증금 내기 시간이 한 시간 남았다는 사실을 알게 되었다. #Person2#는 아직 결정하지 못했다고 말했다. #Person1#은 마감일이 5월 1일로 2주 후에 도래한다는 사실을 알리고, 돈이 부족하지 않는지 물었다. #Person2#는 비용이 더 들 것을 알고 있다고 말했다.
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 주택 사무소에서 줄을 서야 했고, #Person2#는 기숙사방을 원하지 않는다는 것을 알린다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 기숙사 보증금 내기 시간이 한 시간 남았다는 사실을 알게 되었다. #Person1#은 마감일이 5월 1일로 2주 후에 도래한다는 사실을 알리고, 돈이 부족하지 않는지 물었다. #Person1#은 #Person2#에게 주택 사무소에서 줄을 서야 했고, #Person2#는 기숙사방을 원하지 않는다는 것을 알린다.
#
#
#
# ##329
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 중고 서점을 둘러보는 것을 즐겨, 그리고 이 오래된 어린이 이야기 책을 봤다. #Person2#는 이 책들 중에는 그렇게 오래되지 않은 것들도 있다고 말했다. #Person1#은 이 책을 선물로 주고, 앞표지 안쪽에 메모를 썼다는 것을 알게 되었다.
#
#
# GPT Summary:
# #Person1#은 중고 서점을 둘러보는 것을 좋아하고, #Person1#의 시집에는 유명한 사람의 서명이 있을 수도 있다. #Person2#는 그것이 더 나은 구매라고 생각한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 중고 서점을 둘러보는 것을 즐겨, 그리고 이 오래된 어린이 이야기 책을 봤다. #Person1#은 이 책을 선물로 주고, 앞표지 안쪽에 메모를 썼다는 것을 알게 되었다. #Person1#은 중고 서점을 둘러보는 것을 좋아하고, #Person1#의 시집에는 유명한 사람의 서명이 있을 수도 있다.
#
#
#
# ##330
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 베이징 맛있는 레스토랑에 오신 것을 환영합니다. 창가 옆 테이블을 보여주실 수 있나요? #Person2#는 중앙에 테이블이 하나 있다는 것을 알고 그곳으로 이동합니다. #Person1#은 메뉴를 받아 치킨, 생선, 야채, 콜라 두 병, 그리고 밥 두 그릇을 주문합니다. #Person2#는 베이징 오리를 시도하기 위해 이를 주문합니다. #Person1#은 음식이 20분 후에 준비될 것이라고 알려줍니다.
#
#
# GPT Summary:
# #Person2#는 창가 옆 테이블을 요청하지만 없어서, 중앙 테이블을 선택하고 음식을 20분 후에 주문한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 베이징 맛있는 레스토랑에 오신 것을 환영합니다. #Person1#은 메뉴를 받아 치킨, 생선, 야채, 콜라 두 병, 그리고 밥 두 그릇을 주문합니다. #Person2#는 창가 옆 테이블을 요청하지만 없어서, 중앙 테이블을 선택하고 음식을 20분 후에 주문한다.
#
#
#
# ##331
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 아들에게 중요한 증명서를 보내기 위해 공인 우편이나 등기 우편을 이용할 수 있다는 것을 알려주고, #Person2#는 소포 안에 있는 시계의 가치에 따라 보험을 구매하고 더 안전한 방법으로 등기 우편으로 보내야 한다는 것을 설명한다.
#
#
# GPT Summary:
# #Person1#은 중요한 증명서를 아들에게 보내고 싶어합니다. #Person2#는 공인 우편이나 등기 우편을 추천합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 아들에게 중요한 증명서를 보내기 위해 공인 우편이나 등기 우편을 이용할 수 있다는 것을 알려주고, #Person2#는 소포 안에 있는 시계의 가치에 따라 보험을 구매하고 더 안전한 방법으로 등기 우편으로 보내야 한다는 것을 설명한다. #Person1#은 중요한 증명서를 아들에게 보내고 싶어합니다. #Person2#는 공인 우편이나 등기 우편을 추천합니다.
#
#
#
# ##332
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다. #Person2#는 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다. #Person1#은 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다.
#
#
# GPT Summary:
# 톰이 샐리에게 보낸 편지를 #Person1#이 읽어줍니다. 톰은 샐리와 존에게 간단히 답장을 적습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다. #Person2#는 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다. #Person1#은 편지를 읽어 주고 손이 다 젖어 있어서 알아 듣기 어려워 보냈다.
#
#
#
# ##333
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 도서관의 컴퓨터에 접근하는데 어려움을 겪고 있습니다. #Person2#는 스스로 컴퓨터를 구입할 수 있는 날을 기대하고 있습니다.
#
#
# GPT Summary:
# #Person1#은 컴퓨터로 과제를 하기 위해 도서관의 컴퓨터에 접근하는 데 어려움을 겪고 있습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 도서관의 컴퓨터에 접근하는데 어려움을 겪고 있습니다. #Person2#는 스스로 컴퓨터를 구입할 수 있는 날을 기대하고 있습니다. #Person1#은 컴퓨터로 과제를 하기 위해 도서관의 컴퓨터에 접근하는 데 어려움을 겪고 있습니다.
#
#
#
# ##334
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 날씨에 대해 이야기하며 소풍을 계획하고 있습니다. #Person1#은 비가 올 것 같다고 생각하지만, #Person2#는 그런 생각을 하지 않습니다. 그들은 소풍 때 날씨가 괜찮을 것으로 기대하고 있습니다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 가을에 대해 이야기하고 있습니다. #Person1#은 비가 올 것이라고 생각하지만, #Person2#는 그렇지 않다고 생각합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 날씨에 대해 이야기하며 소풍을 계획하고 있습니다. #Person1#은 비가 올 것 같다고 생각하지만, #Person2#는 그런 생각을 하지 않습니다. #Person1#은 비가 올 것이라고 생각하지만, #Person2#는 그렇지 않다고 생각합니다.
#
#
#
# ##335
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 참고자료실에서 컴퓨터에 대한 일반적인 정보를 찾고 싶습니다. #Person2#는 그에게 컴퓨터에 관한 많은 잡지를 보여주며 도움을 주고 있습니다.
#
#
# GPT Summary:
# #Person1#은 참고자료실에서 컴퓨터에 대한 일반적인 정보를 찾고 싶어하고, #Person2#는 #Person1#에게 잡지를 보여줄 것입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 참고자료실에서 컴퓨터에 대한 일반적인 정보를 찾고 싶습니다. #Person2#는 그에게 컴퓨터에 관한 많은 잡지를 보여주며 도움을 주고 있습니다. #Person1#은 참고자료실에서 컴퓨터에 대한 일반적인 정보를 찾고 싶어하고, #Person2#는 #Person1#에게 잡지를 보여줄 것입니다.
#
#
#
# ##336
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#: 안녕하세요, 프렌치 가든 레스토랑에 오신 것을 환영합니다. 몇 분이세요?
# #Person2#: 혼자입니다.
# #Person1#: 이쪽으로 오세요. 잠시만 앉아 계세요. 웨이트리스가 곧 찾아갈 것입니다.
# #Person3#: 안녕하세요, 주문하시겠어요?
# #Person2#: 네, 부탁드립니다.
# #Person3#: 무엇을 마시겠어요?
# #Person2#: 뭐가 있나요?
# #Person3#: 우리는 생수, 주스, 콜라가 있습니다.
# #Person2#: 물 한 병
#
#
# GPT Summary:
# #Person2#는 혼자 와서 물 한 병과 참치 샌드위치와 야채 수프를 주문했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#: 안녕하세요, 프렌치 가든 레스토랑에 오신 것을 환영합니다. #Person3#: 우리는 생수, 주스, 콜라가 있습니다. #Person2#: 물 한 병 #Person2#는 혼자 와서 물 한 병과 참치 샌드위치와 야채 수프를 주문했습니다.
#
#
#
# ##337
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 마실 것 좀 드릴까요?
# #Person2#: 네, 부탁드립니다. 레모네이드 한 잔 주시겠어요?
# #Person1#: 애피타이저는 어떠신가요?
# #Person2#: 바비큐 윙을 주문할 수 있을까요?
# #Person1#: 네, 다른 것은 필요하신가요?
# #Person2#: 지금은 이 정도면 괜찮습니다, 감사합니다.
# #Person1#: 알겠습니다, 나머지 음식을 주문하실 때 알려주세요.
# #Person2#: 실례합니다. 주문하려고 합니다.
# #Person1#: 무엇을 드시겠어요?
# #Person2#
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 마실 것과 애피타이저를 추천한다. #Person2#은 레모네이드, 바비큐 윙, 베이비 백 립을 주문한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#: 알겠습니다, 나머지 음식을 주문하실 때 알려주세요. #Person2# #Person1#은 #Person2#에게 마실 것과 애피타이저를 추천한다. #Person2#은 레모네이드, 바비큐 윙, 베이비 백 립을 주문한다.
#
#
#
# ##338
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 다른 것도 필요하신가요, 선생님?
# #Person2#: 물 좀 주시겠어요?
# #Person1#: 네. 커피는 저녁식사와 함께 드시겠어요, 아니면 나중에 드시겠어요?
# #Person2#: 저녁식사와 함께 주세요. 그리고 디저트 주문은 나중에 할 수 있을까요?
# #Person1#: 물론입니다.
#
#
# GPT Summary:
# #Person2#는 저녁식사와 함께 커피를 주문하고, 디저트는 나중에 주문할 것입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 다른 것도 필요하신가요, 선생님? 커피는 저녁식사와 함께 드시겠어요, 아니면 나중에 드시겠어요? #Person2#는 저녁식사와 함께 커피를 주문하고, 디저트는 나중에 주문할 것입니다.
#
#
#
# ##339
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 에릭이 데이트에 초대하면 어떻게 대답할 것인지 물어봅니다. #Person2#은 로또에 당첨된다면 세계 여행을 위한 티켓을 사겠다고 말합니다. #Person1#은 엄마에게 결혼하려고 한다고 말하면 그녀는 기절하고 나를 강제로 입원시킬 것이라고 말합니다.
#
#
# GPT Summary:
# #Person2#는 에릭이 그녀를 데이트에 초대하면 '예'라고 대답할 것이다. #Person1#는 로또에 당첨되면 티켓을 사줄 것이다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 에릭이 데이트에 초대하면 어떻게 대답할 것인지 물어봅니다. #Person2#은 로또에 당첨된다면 세계 여행을 위한 티켓을 사겠다고 말합니다. #Person1#은 엄마에게 결혼하려고 한다고 말하면 그녀는 기절하고 나를 강제로 입원시킬 것이라고 말합니다.
#
#
#
# ##340
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 새로운 아기 사진을 보여주고 싶어하며, #Person2#는 귀여움을 느끼고 아기의 나이를 물어봅니다.
#
#
# GPT Summary:
# #Person1#은 잭에게 새로운 아기의 사진을 보여준다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 새로운 아기 사진을 보여주고 싶어하며, #Person2#는 귀여움을 느끼고 아기의 나이를 물어봅니다. #Person1#은 잭에게 새로운 아기의 사진을 보여준다.
#
#
#
# ##341
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 자전거를 사줬다고 말하며 톰의 자전거에 대한 애정을 표현합니다. #Person2#는 자전거를 보고 톰이 예의 바르다는 것을 알게 되고, 자전거가 내 것보다 좋다는 것을 알게 됩니다. 그러나 버스 대기 시간이 길다는 것을 알게 되고, 대화의 주제는 차를 사는 것에 대한 이야기로 변합니다. 이후 대화는 비행기를 사는 것에 대한 이야기로 이어집니다.
#
#
# GPT Summary:
# #Person1#은 엄마에게 제인 이모가 톰에게 새 자전거를 사줬다고 말한다. #Person2#는 #Person1#에게 자신의 차를 사달라고 부탁한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 자전거를 사줬다고 말하며 톰의 자전거에 대한 애정을 표현합니다. #Person2#는 자전거를 보고 톰이 예의 바르다는 것을 알게 되고, 자전거가 내 것보다 좋다는 것을 알게 됩니다. 그러나 버스 대기 시간이 길다는 것을 알게 되고, 대화의 주제는 차를 사는 것에 대한 이야기로 변합니다.
#
#
#
# ##342
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 치마를 찾고 있는 사람에게 도움을 요청합니다. #Person2#는 최신 유행 치마를 찾고 있으며, #Person1#은 그에게 해당 치마를 제안합니다. #Person2#는 치마를 입어보고 싶어하고, #Person1#은 그에게 구매할 수 있는 가격을 알려줍니다.
#
#
# GPT Summary:
# #Person2#는 치마를 찾고 있고, #Person1#은 그것을 추천합니다. #Person2#는 그것이 귀엽다고 생각하지만 너무 비싸다고 생각합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 치마를 찾고 있는 사람에게 도움을 요청합니다. #Person2#는 최신 유행 치마를 찾고 있으며, #Person1#은 그에게 해당 치마를 제안합니다. #Person2#는 치마를 입어보고 싶어하고, #Person1#은 그에게 구매할 수 있는 가격을 알려줍니다.
#
#
#
# ##343
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 도시의 성장 이유와 주변 마을의 흡수에 대해 이야기합니다. #Person2#은 석탄 발견과 대량의 산업 이전으로 인해 도시가 성장했다고 설명하며, 도시에는 200년 이상 된 건물들이 남아 있다고 말합니다.
#
#
# GPT Summary:
# #Person2#는 #Person1#에게 도시가 대량의 석탄 발견으로 인해 성장하고, 그 후에는 주변의 많은 마을을 흡수했다고 말한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 도시의 성장 이유와 주변 마을의 흡수에 대해 이야기합니다. #Person2#은 석탄 발견과 대량의 산업 이전으로 인해 도시가 성장했다고 설명하며, 도시에는 200년 이상 된 건물들이 남아 있다고 말합니다. #Person2#는 #Person1#에게 도시가 대량의 석탄 발견으로 인해 성장하고, 그 후에는 주변의 많은 마을을 흡수했다고 말한다.
#
#
#
# ##344
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 세계 지도자들이 행동 계획에 동의할 수 없을 것이라고 말합니다. 그러나 대기 오염 문제를 해결하기 위해 깨끗하고 현대적인 기술을 사용해야 한다고 주장합니다. 개발 중인 국가들은 환경 보호보다 경제 발전에 더 많은 중점을 둡니다.
# #Person2#는 모두가 장기적인 문제에 주목하고 있으며, 숲이 중요한 자연 서식지라는 것을 기억해야 한다고 말합니다. 그러나 사막화 문제는 아프리카에서 발생하고 있으며, 기후 변화와 과도한
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 세계의 환경 문제를 논의하며, 세계 지도자들이 행동 계획에 동의할 수 있기를 바랍니다. #Person2#은 개인적으로 환경 보호에 헌신하고 싶어합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 세계 지도자들이 행동 계획에 동의할 수 없을 것이라고 말합니다. 그러나 대기 오염 문제를 해결하기 위해 깨끗하고 현대적인 기술을 사용해야 한다고 주장합니다. 그러나 사막화 문제는 아프리카에서 발생하고 있으며, 기후 변화와 과도한 #Person1#은 #Person2#에게 세계의 환경 문제를 논의하며, 세계 지도자들이 행동 계획에 동의할 수 있기를 바랍니다.
#
#
#
# ##345
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 채팅방에서 많은 사람들과 대화하고 있으며, 100명 이상의 사람들이 그를 찾아와 이야기하고 싶어했다. 그 중 한 명은 그가 꿈에 그리던 여자친구라고 말했다. 그러나 그는 16살 소녀로 가장했다. 그는 새로운 온라인 친구를 만나게 되었고, 그 사람은 그를 여자로 생각하고 있다. 그는 이 사람과 금요일 밤에 만나기로 했다. 그러나 그는 그를 여자로 생각하고 있지 않다. 그는 그를 친구로 지내고 싶지 않다.
#
#
# GPT Summary:
# 데니스는 채팅방에서 여자로서 사람들과 대화하기 위해 16살 소녀로 가장하고 있습니다. 데니스는 새로운 온라인 친구를 사귀기로 결정했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 채팅방에서 많은 사람들과 대화하고 있으며, 100명 이상의 사람들이 그를 찾아와 이야기하고 싶어했다. 그는 새로운 온라인 친구를 만나게 되었고, 그 사람은 그를 여자로 생각하고 있다. 데니스는 채팅방에서 여자로서 사람들과 대화하기 위해 16살 소녀로 가장하고 있습니다.
#
#
#
# ##346
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 시카고로 연습하러 갈 준비가 된 것 같다고 말하며, 그들은 네가 여기 없으면 너를 그리워할 거라고 말한다. #Person2#는 여름이 너무 설레고 슬퍼하지 않도록 말하며, 겨울방학이 되면 기억하기 힘들 것이라고 말한다. #Person1#은 연습을 하는 것은 단지 회사가 이익을 내기 위한 것만은 아니라고 말하며, 경험을 쌓는 것도 중요하다고 말한다. #Person2#는 타고난 호기심이 많고 사교적이라고 말하며, 그들은 편집을 잘하고, �����
#
#
# GPT Summary:
# 네이선은 시카고로 연습하러 간다. 그의 엄마는 걱정하지만 그는 걱정하지 않는다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 시카고로 연습하러 갈 준비가 된 것 같다고 말하며, 그들은 네가 여기 없으면 너를 그리워할 거라고 말한다. #Person2#는 여름이 너무 설레고 슬퍼하지 않도록 말하며, 겨울방학이 되면 기억하기 힘들 것이라고 말한다. #Person1#은 연습을 하는 것은 단지 회사가 이익을 내기 위한 것만은 아니라고 말하며, 경험을 쌓는 것도 중요하다고 말한다.
#
#
#
# ##347
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 차를 빌려 3일 동안 사용하고 싶습니다. 검정색, 빨간색, 그리고 은색의 토요타 캐롤라가 있으며, 다른 색상을 선택할 수 있습니다. 신분증을 보여주시면 복사하겠습니다. 신청서에 서명하시고, 이것이 차 키입니다. 셋째 날 정오에 반납해야 합니다. 감사합니다.
#
#
# GPT Summary:
# #Person2#는 3일 동안 토요타 캐롤라를 빌립니다. #Person1#는 #Person2#에게 차 색상을 선택하고, 신분증과 서명을 요청합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 차를 빌려 3일 동안 사용하고 싶습니다. 검정색, 빨간색, 그리고 은색의 토요타 캐롤라가 있으며, 다른 색상을 선택할 수 있습니다. #Person1#는 #Person2#에게 차 색상을 선택하고, 신분증과 서명을 요청합니다.
#
#
#
# ##348
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 다음 주에 뉴욕에 가서 사업 계약을 체결하려고 합니다. 그곳에서 볼 것을 추천하시나요? #Person2#는 반드시 UN 건물을 봐야 합니다. 그리고 거기서 브로드웨이로 걸어가서 영화나 드라마를 볼 수 있습니다. #Person1#은 뉴욕의 대학교는 어떨까요? 특히 그곳의 학교와 그들이 제공하는 과정에 대해 알고 싶습니다. #Person2#는 컬럼비아 대학교와 뉴욕 대학교는 도시에서 가장 좋은 학교 중 두 곳입니다.
#
#
# GPT Summary:
# #Person1#은 사업 계약을 체결하기 위해 뉴욕에 갈 예정이다. #Person2#는 #Person1#에게 UN 건물을 보는 것을 제안한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 다음 주에 뉴욕에 가서 사업 계약을 체결하려고 합니다. 특히 그곳의 학교와 그들이 제공하는 과정에 대해 알고 싶습니다. #Person2#는 컬럼비아 대학교와 뉴욕 대학교는 도시에서 가장 좋은 학교 중 두 곳입니다.
#
#
#
# ##349
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 필름을 현상해 줄 수 있는지 물어봅니다. #Person2#는 물론입니다. 6시간이 걸리나요. 만약 서두르신다면 3시간 안에 할 수 있습니다. #Person1#은 내일 다시 올게요.
#
# 대화 내용: 인물들은 필름을 현상해 줄 수 있는지 묻고, 시간이 얼마나 걸리는지 물어봅니다. 인물들은 내일 다시 올 것을 약속합니다.
#
# 주제: 필름 현상
# 주된 내용: 필름 현상 가능성, 시간 소요, 내일 다시 올 것
# 지시사항: 필름 현상 요청
# 행동: 필름 현상
#
#
# GPT Summary:
# #Person1#은 #Person2#에게 필름 현상을 요청하고, #Person2#는 내일까지 6시간이 걸릴 것이라고 말합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 필름을 현상해 줄 수 있는지 물어봅니다. 대화 내용: 인물들은 필름을 현상해 줄 수 있는지 묻고, 시간이 얼마나 걸리는지 물어봅니다. 주제: 필름 현상
# 주된 내용: 필름 현상 가능성, 시간 소요, 내일 다시 올 것
# 지시사항: 필름 현상 요청
# 행동: 필름 현상 #Person1#은 #Person2#에게 필름 현상을 요청하고, #Person2#는 내일까지 6시간이 걸릴 것이라고 말합니다.
#
#
#
# ##350
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 비행기 지연 안내를 받았다. #Person2#는 지연 사유를 알려주고, 지연 정도를 알 수 없다고 말한다. #Person1#은 기다려야 하고, 비가 그칠 가능성이 있다는 정보를 알려준다.
#
#
# GPT Summary:
# #Person1#은 지연된 비행기에 대한 추가 정보를 요청합니다. #Person2#은 폭우 때문에 지연이 발생했으며, 최근 일기예보에 따르면, 곧 날씨가 변화할 것이라고 말합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# ...
#
#
# Generated Summary:
# #Person1#과 #Person2#는 파티에 가지 못한 이유와 일자리에 대해 이야기합니다. #Person1#은 건설 회사에서 일할 사람들이 필요하다는 아버지의 말을 전해줍니다. 톰은 메리에게 존의 파티에 초대하지만, 메리는 일자리를 찾았기 때문에 갈 수 없다.
#
#
#
# ##476
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 해리와 다니엘은 길을 건너다가 차에 치일 뻔 했던 경험을 나누며 대화를 나눕니다. 해리는 차 번호를 기억하고 경찰에 신고할 수 있도록 하고, 다니엘은 이 경험을 잊지 못할 것이라고 말합니다. 이후 해리는 신문을 읽으면서 길을 건너지 않을 것을 조심하라고 조언합니다.
#
#
# GPT Summary:
# 해리는 #Person1#에게 차에 치일 뻔했다고 말한다. 해리는 끔찍한 경험이라고 생각하고 그 사람을 경찰에 신고하고 싶어한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 해리와 다니엘은 길을 건너다가 차에 치일 뻔 했던 경험을 나누며 대화를 나눕니다. 해리는 차 번호를 기억하고 경찰에 신고할 수 있도록 하고, 다니엘은 이 경험을 잊지 못할 것이라고 말합니다. 이후 해리는 신문을 읽으면서 길을 건너지 않을 것을 조심하라고 조언합니다.
#
#
#
# ##477
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 스티븐 케인씨는 자전거 상점을 인수하고 설립하여 자신만의 사업을 시작했습니다. 그는 레이싱 자전거를 타고 수리하는 것을 좋아했으며, 전문 판매원으로 일하면서 충분한 돈을 모아서 시작할 수 있을 때까지 기다렸습니다. 은행에 가서 사업 대출을 받았을 때, 그는 사장이 되고 싶다는 것을 알았습니다. 그는 정규 근무 시간을 지키지 않고, 사업이 부진하면 문을 잠그고 일찍 퇴근할 수 있습니다. 또한, 자전거를 좋아하는 몇
#
#
# GPT Summary:
# #Person1#은 스티븐 케인씨를 인터뷰하고, 케인씨는 레이싱 자전거를 타고 수리하는 것을 좋아하기 때문에 자신만의 상점을 운영하고 싶어했다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 그는 레이싱 자전거를 타고 수리하는 것을 좋아했으며, 전문 판매원으로 일하면서 충분한 돈을 모아서 시작할 수 있을 때까지 기다렸습니다. 그는 정규 근무 시간을 지키지 않고, 사업이 부진하면 문을 잠그고 일찍 퇴근할 수 있습니다. 또한, 자전거를 좋아하는 몇 #Person1#은 스티븐 케인씨를 인터뷰하고, 케인씨는 레이싱 자전거를 타고 수리하는 것을 좋아하기 때문에 자신만의 상점을 운영하고 싶어했다.
#
#
#
# ##478
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 중년의 정의에 대해 이야기합니다. #Person1#은 중년이 중간, 에델, 인생의 중간을 의미한다고 주장하지만, #Person2#는 사람들은 150살까지 살지 않는다고 반박합니다. #Person1#은 중년의 가장자리 부분이라고 말하지만, #Person2#는 그들은 중년이 아니라고 밝힙니다. 이후 #Person1#은 자신과 #Person2#의 나이를 밝히고, 이 대화에 대해 오후 내내 다툴 생각이라고 말합니다.
#
#
# GPT Summary:
# 에델은 #Person1#에게 그들이 중년이 아니라고 말하고, 그들이 늙어간다고 생각한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 중년이 중간, 에델, 인생의 중간을 의미한다고 주장하지만, #Person2#는 사람들은 150살까지 살지 않는다고 반박합니다. #Person1#은 중년의 가장자리 부분이라고 말하지만, #Person2#는 그들은 중년이 아니라고 밝힙니다. 이후 #Person1#은 자신과 #Person2#의 나이를 밝히고, 이 대화에 대해 오후 내내 다툴 생각이라고 말합니다.
#
#
#
# ##479
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 디저트 목록을 제시하고, #Person2#는 사과 크리스프를 선택하고 초콜릿 무스 케이크도 주문하고 싶다고 말합니다. 그리고 커피와 차를 가져다 주시면 좋겠다고 요청합니다.
#
#
# GPT Summary:
# #Person2#가 디저트를 주문하고, #Person1#은 뜨거운 음료를 먼저 가져다 줄 것입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 디저트 목록을 제시하고, #Person2#는 사과 크리스프를 선택하고 초콜릿 무스 케이크도 주문하고 싶다고 말합니다. 그리고 커피와 차를 가져다 주시면 좋겠다고 요청합니다. #Person2#가 디저트를 주문하고, #Person1#은 뜨거운 음료를 먼저 가져다 줄 것입니다.
#
#
#
# ##480
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 #Person2#에게 부탁을 합니다. #Person2#는 동의하고 작은 봉지 설탕, 여섯 개의 오렌지, 그리고 우유 반 갤런을 사다 줍니다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 아래침대와 창가 옆 책상을 두고 동전 던지기로 결정한다. #Person2#는 운이 잘 풀리는 사람이라고 주장하고, #Person1#은 #Person2#에게 배우고 싶어한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#는 동의하고 작은 봉지 설탕, 여섯 개의 오렌지, 그리고 우유 반 갤런을 사다 줍니다. #Person1#과 #Person2#는 아래침대와 창가 옆 책상을 두고 동전 던지기로 결정한다. #Person2#는 운이 잘 풀리는 사람이라고 주장하고, #Person1#은 #Person2#에게 배우고 싶어한다.
#
#
#
# ##481
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 도서관 카드를 발급받고 싶어 신청서를 제출했습니다. #Person2#는 신청서를 확인하고 카운터에서 작성할 수 있도록 안내했습니다. #Person1#은 신청서와 면허증을 제출했고, #Person2#는 신청서를 확인하고 규정과 벌금에 대해 설명했습니다.
#
#
# GPT Summary:
# #Person1#은 도서관 카드를 발급받고 싶어한다. #Person2#는 #Person1#의 운전 면허증을 확인하고, #Person1#은 규정과 벌금에 대해 알고 있다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 도서관 카드를 발급받고 싶어 신청서를 제출했습니다. #Person1#은 신청서와 면허증을 제출했고, #Person2#는 신청서를 확인하고 규정과 벌금에 대해 설명했습니다. #Person2#는 #Person1#의 운전 면허증을 확인하고, #Person1#은 규정과 벌금에 대해 알고 있다.
#
#
#
# ##482
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 전형적인 9시부터 5시까지 일하는 직장인이며, 대부분의 날은 9시부터 5시보다 조금 더 오래 일해요. 초과근무 수당을 받지 않고, 매달 고객과 체결한 계약의 가치에 따라 보너스를 받습니다. 우리는 12시부터 1시까지 한 시간의 점심 휴식 시간이 있습니다. 서류 작업이 조금 있지만, 대부분의 경우 정보를 컴퓨터에 입력하고 이메일이나 네트워크를 통해 정보를 보낼 수 있습니다. 저는 칸막이 사무실에서 일하나요.
#
#
# GPT Summary:
# #Person2#는 #Person1#에게 #Person2#의 근무 시간, 보너스, 휴식 시간 및 #Person2#의 사무실 환경에 대해 이야기합니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 전형적인 9시부터 5시까지 일하는 직장인이며, 대부분의 날은 9시부터 5시보다 조금 더 오래 일해요. 초과근무 수당을 받지 않고, 매달 고객과 체결한 계약의 가치에 따라 보너스를 받습니다. 서류 작업이 조금 있지만, 대부분의 경우 정보를 컴퓨터에 입력하고 이메일이나 네트워크를 통해 정보를 보낼 수 있습니다.
#
#
#
# ##483
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 #Person2#에게 기계 사용법을 알려주고 싶어하지만, #Person2#는 기계에 대한 이해가 부족하다고 느껴져 설명을 거부한다.
#
#
# GPT Summary:
# 닉은 기계를 처음 사용해봐서 앨리스에게 도움을 청한 뒤 비누를 삽니다. 그 후, 앨리스는 닉에게 옷을 빨래하는 방법을 가르칩니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 #Person2#에게 기계 사용법을 알려주고 싶어하지만, #Person2#는 기계에 대한 이해가 부족하다고 느껴져 설명을 거부한다. 닉은 기계를 처음 사용해봐서 앨리스에게 도움을 청한 뒤 비누를 삽니다. 그 후, 앨리스는 닉에게 옷을 빨래하는 방법을 가르칩니다.
#
#
#
# ##484
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 대화를 나누며 일상에 대해 이야기합니다. #Person1#은 바쁜 일정을 가지고 있지만, #Person2#도 마치 일을 하는 것 뿐인 것 같다고 말합니다. #Person1#은 오늘 밤에 전화해야 한다고 하며, #Person2#는 나중에 만날 것을 약속합니다.
#
#
# GPT Summary:
# #Person1#과 #Person2#는 서로 전화를 걸기로 약속하고 헤어졌다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 대화를 나누며 일상에 대해 이야기합니다. #Person1#은 바쁜 일정을 가지고 있지만, #Person2#도 마치 일을 하는 것 뿐인 것 같다고 말합니다. #Person1#은 오늘 밤에 전화해야 한다고 하며, #Person2#는 나중에 만날 것을 약속합니다.
#
#
#
# ##485
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 상품의 배송 일정에 대해 이야기합니다. #Person1#은 확정된 월별 주문에 대해 5%의 할인을 제안하고, 그들은 오랫동안의 협력을 바탕으로 최종적으로 합의에 이릅니다.
#
#
# GPT Summary:
# #Person1#은 케이티에게 그녀의 일에 대해 피드백하고, 케이티는 개선을 약속한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 상품의 배송 일정에 대해 이야기합니다. #Person1#은 확정된 월별 주문에 대해 5%의 할인을 제안하고, 그들은 오랫동안의 협력을 바탕으로 최종적으로 합의에 이릅니다. #Person1#은 케이티에게 그녀의 일에 대해 피드백하고, 케이티는 개선을 약속한다.
#
#
#
# ##486
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 다음 주에 할아버지 생신이에요. 깜짝 파티를 해야겠어요.
# #Person2#: 파티요? 큰 소리로 음악을 틀고 음식을 펼쳐놓는 걸 말하는 건가요?
# #Person1#: 그런 건 아니지만, 할아버지가 재즈를 좋아하실 거예요. 호텔은 비싸고, 이 시기에는 정원 파티를 하기에 너무 추워요. 우리 집에서 하는 게 최선이에요.
# #Person2#: 네, 그게 맞는 것 같아요. 음식은 뭐를 준비해야 할까요?
# #Person1#: 아, 저는 피자를
#
#
# GPT Summary:
# #Person1#과 #Person2#는 #Person1#의 할아버지 생신을 위한 파티를 계획하고 있습니다. #Person1#은 음식을 준비하고 #Person2#는 책을 선물할 예정입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 다음 주에 할아버지 생신이에요. 호텔은 비싸고, 이 시기에는 정원 파티를 하기에 너무 추워요. #Person1#: 아, 저는 피자를 #Person1#과 #Person2#는 #Person1#의 할아버지 생신을 위한 파티를 계획하고 있습니다.
#
#
#
# ##487
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 자신을 소개하고 스페인 출신임을 알린 후, #Person2#에게 자신이 프리랜서인 것을 알린다. #Person2#는 회사에 속하지 않고 기자로서 잡지에 기사를 씁니다. #Person1#은 이탈리아 서비스 제공업체에서 일하는 친구를 소개해 주고, #Person2#는 그를 기다리고 있다.
#
#
# GPT Summary:
# 지안과 지나는 서로 소개를 한다. 지나는 프리랜서 기자이고, 지안은 그녀의 친구에게 그녀를 소개한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 자신을 소개하고 스페인 출신임을 알린 후, #Person2#에게 자신이 프리랜서인 것을 알린다. #Person2#는 회사에 속하지 않고 기자로서 잡지에 기사를 씁니다. #Person1#은 이탈리아 서비스 제공업체에서 일하는 친구를 소개해 주고, #Person2#는 그를 기다리고 있다.
#
#
#
# ##488
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 시골이 매우 조용하지만, 올해는 새들의 울음소리로 인해 시끄러워졌다. #Person2#는 이 소리는 매년 17년에 한 번씩 나타나는 것이며, 대부분의 시간을 산 근처에서 보낸다고 설명한다.
#
#
# GPT Summary:
# 캐시는 시골이 시끄럽다고 생각하지만, #Person2#는 17년에 한 번씩 나타나는 새들의 울음소리 때문이라고 말한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 시골이 매우 조용하지만, 올해는 새들의 울음소리로 인해 시끄러워졌다. #Person2#는 이 소리는 매년 17년에 한 번씩 나타나는 것이며, 대부분의 시간을 산 근처에서 보낸다고 설명한다. 캐시는 시골이 시끄럽다고 생각하지만, #Person2#는 17년에 한 번씩 나타나는 새들의 울음소리 때문이라고 말한다.
#
#
#
# ##489
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# 대화의 주제: 음식 주문
# 주된 내용: 대니스가 샌드위치와 함께 다른 음식을 원하고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다.
# 지시사항: 대니스에게 주문을 도와드리고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다.
# 하고자 하는 행동: 대니스에게 주문을 도와드리고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다.
#
#
# GPT Summary:
# #Person2#는 칠면조 샌드위치, 채소가 들어간 소고기 스프, 다이어트 콜라를 주문한다. 총 금액은 $9이다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# 대화의 주제: 음식 주문
# 주된 내용: 대니스가 샌드위치와 함께 다른 음식을 원하고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다. 지시사항: 대니스에게 주문을 도와드리고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다. 하고자 하는 행동: 대니스에게 주문을 도와드리고, 대니스가 채소가 들어간 소고기 스프와 다이어트 콜라를 주문한다.
#
#
#
# ##490
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 제임스, 왜 TV를 보고 있어? 너의 기차는 4시 30분에 출발해. 단지 2시간밖에 남지 않았어. 짐 다 싸놨어?
# #Person2#: 거의 다 싸놨어. 지금은 지난 주에 데이비드에게 빌려준 재킷을 기다리고 있어.
# #Person1#: 회색 재킷과 파란색 재킷 중 어떤 것이야?
# #Person2#: 둘 다 아니야, 검은색이야. 내가 제일 좋아하는 거야. 나는 그곳에서 사진을 찍고 싶어서 그 재킷을 입고 싶어.
#
#
# GPT Summary:
# 제임스는 TV를 보고 있지만, 그의 기차는 2시간 후에 출발한다. 그는 지난 주에 데이비드에게 빌려준 검은색 재킷을 기다리고 있다. #Person1#은 제임스에게 쿠키를 가져가라고 요청한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 제임스, 왜 TV를 보고 있어? 제임스는 TV를 보고 있지만, 그의 기차는 2시간 후에 출발한다. 그는 지난 주에 데이비드에게 빌려준 검은색 재킷을 기다리고 있다.
#
#
#
# ##491
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 휴가 계획에 대해 이야기하며 중국에서 몇 주를 보낼 예정이라고 말합니다. #Person2#는 아내의 부모님과 함께 사는 것을 좋아하지 않아 집에 머무를 것으로 예상하고 있습니다.
#
#
# GPT Summary:
# 테드는 아내의 부모님과 함께 가고 싶지 않아서 휴가를 집에서 보낼 예정이다. #Person1#은 중국에서 휴가를 보낼 예정이다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#과 #Person2#는 휴가 계획에 대해 이야기하며 중국에서 몇 주를 보낼 예정이라고 말합니다. #Person2#는 아내의 부모님과 함께 사는 것을 좋아하지 않아 집에 머무를 것으로 예상하고 있습니다. 테드는 아내의 부모님과 함께 가고 싶지 않아서 휴가를 집에서 보낼 예정이다.
#
#
#
# ##492
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 영화관에 가볼까요?
# #Person2#: 영화관에? 음, 잘 모르겠네.
# #Person1#: 헬렌 아주머니는 항상 저를 영화관에 데려가요.
# #Person2#: 음, 헬렌 이모가 항상 너를 데려가는 건 알지만, 오늘 상영하는 영화는 무엇이야?
# #Person1#: '노인을 위한 나라는 없다'에요.
# #Person2#: 노인을 위한 나라는 없다? 좋아, 흥미로운 영화고 오스카 상도 받았어. 언제 시작하니?
# #Person1#: 신문을 보면, 오후 3시에 시작해요.
# #Person2#: 그
#
#
# GPT Summary:
# #Person1#은 아빠에게 영화를 보러 가자고 제안하고, 아빠는 헬렌 이모가 #Person1#을 데려가는 것을 알고, 오늘 상영하는 영화를 묻는다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 영화관에 가볼까요? #Person2#: 음, 헬렌 이모가 항상 너를 데려가는 건 알지만, 오늘 상영하는 영화는 무엇이야? #Person2#: 그 #Person1#은 아빠에게 영화를 보러 가자고 제안하고, 아빠는 헬렌 이모가 #Person1#을 데려가는 것을 알고, 오늘 상영하는 영화를 묻는다.
#
#
#
# ##493
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 문제가 있는 것 같아 보인다. #Person2#은 집이 털렸고, 도둑들이 가구를 훔쳐갔다고 말한다. #Person1#은 경찰에 전화하라고 조언한다.
#
#
# GPT Summary:
# #Person2#의 집에서 도둑이 들었습니다. #Person2#는 #Person1#에게 그것을 말했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 문제가 있는 것 같아 보인다. #Person2#은 집이 털렸고, 도둑들이 가구를 훔쳐갔다고 말한다. #Person2#는 #Person1#에게 그것을 말했습니다.
#
#
#
# ##494
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 헤이와 비디오 게임을 할 것을 제안하고, 새로운 게임을 소개한다. #Person2#는 게임의 특징을 듣고 흥미를 느낀다.
#
#
# GPT Summary:
# 잭이 새로운 게임을 플레이하고 싶어하며, 찰리에게 그것을 보여주기 위해 집에 오라고 초대한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 헤이와 비디오 게임을 할 것을 제안하고, 새로운 게임을 소개한다. #Person2#는 게임의 특징을 듣고 흥미를 느낀다. 잭이 새로운 게임을 플레이하고 싶어하며, 찰리에게 그것을 보여주기 위해 집에 오라고 초대한다.
#
#
#
# ##495
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 #Person2#에게 컨트리 음악에 대한 관심 이유를 묻고, #Person2#은 레코드 플레이어 구입 시작과 함께 컨트리 음악 레코드를 더 많이 사는 것을 발견했다고 말합니다. #Person1#은 #Person2#가 CBC에서 컨트리 음악 프로그램을 시작하게 된 계기가 되었다고 묻고, #Person2#은 그 프로그램이 '골든 컨트리 타임'이라고 말합니다. 그리고 #Person1#은 #Person2#에게 노래들의 배경을 설명하는 기사를 쓰라는 요청을 받았다고 묻고, #Person2#은 도서관에 달려가
#
#
# GPT Summary:
# #Person2#는 처음에 컨트리 음악 레코드를 사기 시작했고, 그 후 라디오 방송국에서 일하기 시작했습니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 #Person2#에게 컨트리 음악에 대한 관심 이유를 묻고, #Person2#은 레코드 플레이어 구입 시작과 함께 컨트리 음악 레코드를 더 많이 사는 것을 발견했다고 말합니다. #Person1#은 #Person2#가 CBC에서 컨트리 음악 프로그램을 시작하게 된 계기가 되었다고 묻고, #Person2#은 그 프로그램이 '골든 컨트리 타임'이라고 말합니다. 그리고 #Person1#은 #Person2#에게 노래들의 배경을 설명하는 기사를 쓰라는 요청을 받았다고 묻고, #Person2#은 도서관에 달려가 #Person2#는 처음에 컨트리 음악 레코드를 사기 시작했고, 그 후 라디오 방송국에서 일하기 시작했습니다.
#
#
#
# ##496
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 세탁기와 건조기에 대해 설명을 요청합니다. #Person2#은 세탁기와 건조기의 사용법을 설명하고, 비누를 사용해야 하는 이유를 설명합니다. #Person1#은 비누를 샀으며, 옷을 빨아본 적이 없다고 말합니다. #Person2#은 미국 아이들이 독립적이라는 사실을 알려주고, 엄마가 아이들을 대신해 해주는 사실을 설명합니다.
#
#
# GPT Summary:
# 앨리스는 #Person1#에게 기계를 사용하는 방법을 알려주고, #Person1#은 옷을 빨아본 적이 없다는 놀라운 사실을 발견한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#은 세탁기와 건조기의 사용법을 설명하고, 비누를 사용해야 하는 이유를 설명합니다. #Person2#은 미국 아이들이 독립적이라는 사실을 알려주고, 엄마가 아이들을 대신해 해주는 사실을 설명합니다. 앨리스는 #Person1#에게 기계를 사용하는 방법을 알려주고, #Person1#은 옷을 빨아본 적이 없다는 놀라운 사실을 발견한다.
#
#
#
# ##497
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#과 #Person2#는 집을 찾기 위해 이야기합니다. #Person2#는 다우 부인의 딸이 아기를 가지게 돼서 함께 살면서 돕기로 했다고 말합니다. #Person1#은 다우 부인에게 아파트를 보여줄 수 있는 날짜와 시간을 알려주고 전화번호를 알려주기를 바랍니다.
#
#
# GPT Summary:
# 스티브는 매튜에게 새로운 아파트를 찾고 있으며, 그의 계약이 끝나면서 갱신하고 싶지 않다고 말합니다. 매튜는 스티브를 도울 수 있을 것 같다고 말하고, 다우 부인에게 아파트를 보여줄 것입니다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person2#는 다우 부인의 딸이 아기를 가지게 돼서 함께 살면서 돕기로 했다고 말합니다. #Person1#은 다우 부인에게 아파트를 보여줄 수 있는 날짜와 시간을 알려주고 전화번호를 알려주기를 바랍니다. 스티브는 매튜에게 새로운 아파트를 찾고 있으며, 그의 계약이 끝나면서 갱신하고 싶지 않다고 말합니다.
#
#
#
# ##498
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Mistral Summary:
# #Person1#은 승진하여 파티를 열기로 했으며, 파티는 토요일에 열리고 150명 정도 참석할 것으로 예상한다. #Person2#는 파티에 참석하고 싶어하며, 이 일은 큰 승진이라고 말한다.
#
#
# GPT Summary:
# 프랭크는 벳시에게 그가 승진했고, 친구들을 위한 파티를 열 것이라고 말한다. 벳시는 파티에 가기로 결정한다.
#
#
# ---------------------------------------------------------------------------------------------------
#
#
# Generated Summary:
# #Person1#은 승진하여 파티를 열기로 했으며, 파티는 토요일에 열리고 150명 정도 참석할 것으로 예상한다. #Person2#는 파티에 참석하고 싶어하며, 이 일은 큰 승진이라고 말한다. 프랭크는 벳시에게 그가 승진했고, 친구들을 위한 파티를 열 것이라고 말한다.

# %%
# Save results as a CSV file
result_path = loaded_config['inference']['result_path']
if not os.path.exists(result_path):
    os.makedirs(result_path)



# Create a DataFrame with 'fname' and 'generated_summary'
output_csv = pd.DataFrame({
    'fname': test_df['fname'],
    'summary':  all_summaries
})

# Save the DataFrame to CSV
output_file_path = os.path.join(result_path, "output_finetuned_ensemble.csv")
output_csv.to_csv(output_file_path, index=False)

# Log to W&B (assuming you have initialized wandb)
wandb.log({"final_summaries": wandb.Table(dataframe=output_csv)})

print(f"Generated summaries saved to {output_file_path}")
# Out:
# Generated summaries saved to /content/drive/MyDrive/fastcampus/nlp_project/prediction/output.csv
